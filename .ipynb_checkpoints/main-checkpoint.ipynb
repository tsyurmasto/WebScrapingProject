# %%
from articles_library import Articles
from selenium_wrapper import SeleniumWrapper
from nltk import WordNetLemmatizer

# %% [markdown]
# ## create an object of class Articles

# %%
articles = Articles()
# number of articles in a dataset
articles.nrows()
# Out:
# 10117

# %% [markdown]
# # preprocessing

# %%
# convert into lowercase
for col in ['Title','Abstract']: articles.to_lower(col) 
# remove punctuation 
for col in ['Title','Abstract']: articles.remove_punctuation(col) 
# remove stopwords
for col in ['Title','Abstract']: articles.remove_stopwords(col) 
# lemmatize
for col in ['Title','Abstract']: articles.lemmatize(col) 
# pick a random sample of 10 articles
articles.sample(10)
# Out:
#                                                Abstract  \
# 8247  family gradient descent algorithm learning lin...
# 3765  paper propose learning approach mixture hidden...
# 2886  present new boosting algorithm key scenario bi...
# 1719                                   abstract missing
# 4377  paper provides first best knowledge analysis o...
# 4275  multiple hypothesis testing significant proble...
# 1119  introduce efficient algorithmic framework mode...
# 9852  work interested problem supervised learning va...
# 4242  fitting highdimensional statistical model ofte...
# 8358  develop method estimating wellconditioned spar...
#
#                                                 Authors Journal_Conference  \
# 8247             Robert E. Mahony, Robert C. Williamson               JMLR
# 3765          Cem Subakan,Johannes Traa,Paris Smaragdis               NIPS
# 2886        Corinna Cortes,Giulia DeSalvo,Mehryar Mohri               NIPS
# 1719                                   Judy A. Franklin               NIPS
# 4377                                     Liva Ralaivola               NIPS
# 4275  Chris Hinrichs,Vamsi K. Ithapu,Qinyuan Sun,Ste...               NIPS
# 1119  Dylan J. Foster,Satyen Kale,Mehryar Mohri,Kart...               NIPS
# 9852  Lorenzo Rosasco, Silvia Villa, Sofia Mosci, Ma...               JMLR
# 4242                    Adel Javanmard,Andrea Montanari               NIPS
# 8358                                     Ashwini Maurya               JMLR
#
#                                                 Pdf_url  \
# 8247            http://jmlr.org/papers/v1/mahony01a.pdf
# 3765  https://papers.nips.cc/paper/5518-spectral-lea...
# 2886  https://papers.nips.cc/paper/6336-boosting-wit...
# 1719  https://papers.nips.cc/paper/2079-improvisatio...
# 4377  https://papers.nips.cc/paper/4676-confusion-ba...
# 4275  https://papers.nips.cc/paper/4924-speeding-up-...
# 1119  https://papers.nips.cc/paper/7183-parameter-fr...
# 9852          http://jmlr.org/papers/v14/rosasco13a.pdf
# 4242  https://papers.nips.cc/paper/4931-confidence-i...
# 8358              http://jmlr.org/papers/v17/15-345.pdf
#
#                                                   Title Volume  Year
# 8247  prior knowledge preferential structure gradien...      1  2000
# 3765      spectral learning mixture hidden markov model      -  2014
# 2886                                boosting abstention      -  2016
# 1719                             improvisation learning      -  2001
# 4377  confusionbased online learning passiveaggressi...      -  2012
# 4275          speeding permutation testing neuroimaging      -  2013
# 1119  parameterfree online learning via model selection      -  2017
# 9852              nonparametric sparsity regularization     14  2013
# 4242  confidence interval hypothesis testing highdim...      -  2013
# 8358  wellconditioned sparse estimation covariance i...     17  2016

# %% [markdown]
# # most popular authors by number of articles

# %%
articles.authors_freq()
# Out:
# [('Yoshua Bengio', 24),
#  ('Koby Crammer', 18),
#  ('Elad Hazan', 17),
#  ('Michael C. Mozer', 16),
#  ('Ofer Dekel', 15),
#  ('Peter Dayan', 15),
#  ('Francis R. Bach', 15),
#  ('Tong Zhang', 15),
#  ('Corinna Cortes', 14),
#  ('David Barber', 13),
#  ('Kenji Fukumizu', 13),
#  ('Han Liu', 12),
#  ('Zoubin Ghahramani', 12),
#  ('Manfred Opper', 12),
#  ('Peter L. Bartlett', 12),
#  ('Ping Li', 11),
#  ('Geoffrey E. Hinton', 11),
#  ('Kamalika Chaudhuri', 11),
#  ('Olivier Chapelle', 11),
#  ('Richard S. Zemel', 11),
#  ('Wolfgang Maass', 11),
#  ('Gal Chechik', 11),
#  ('Peter Sollich', 11),
#  ('Brendan J. Frey', 11),
#  ('Prateek Jain', 11),
#  ('John C. Platt', 10),
#  ('Sham M. Kakade', 9),
#  ('Pierre Baldi', 9),
#  ('Masashi Sugiyama', 9),
#  ('Thomas L. Griffiths', 9),
#  ('Zeyuan Allen-Zhu', 9),
#  ('Ohad Shamir', 9),
#  ('Ingo Steinwart', 9),
#  ('Yee W. Teh', 9),
#  ('Jun Zhu', 9),
#  ('Qiang Liu', 9),
#  ('Sebastian Thrun', 8),
#  ('Charles Kemp', 8),
#  ('Alekh Agarwal', 8),
#  ('Mark Herbster', 8),
#  ('Ricardo Silva', 8),
#  ('Julien Mairal', 8),
#  ('Max Welling', 8),
#  ('Volker Tresp', 8),
#  ('Eunho Yang', 8),
#  ('Joshua B. Tenenbaum', 8),
#  ('Bartlett W. Mel', 8),
#  ('Mehryar Mohri', 8),
#  ('Claudio Gentile', 8),
#  ('Jason D. Lee', 8),
#  ('Lawrence K. Saul', 8),
#  ('Martin J. Wainwright', 8),
#  ('Nicolò Cesa-bianchi', 8),
#  ('Shinichi Nakajima', 8),
#  ('Yining Wang', 8),
#  ('Nicol N. Schraudolph', 8),
#  ('Alex J. Smola', 8),
#  ('Sanjoy Dasgupta', 8),
#  ('Nicolò Cesa-Bianchi', 8),
#  ('Christopher K. I. Williams', 8),
#  ('Sivan Sabato', 8),
#  ('Arthur Gretton', 8),
#  ('Richard S. Sutton', 7),
#  ('Maria-Florina F. Balcan', 7),
#  ('Xinhua Zhang', 7),
#  ('Le Song', 7),
#  ('Terence D. Sanger', 7),
#  ('Shusen Wang', 7),
#  ('Shumeet Baluja', 7),
#  ('Tommi Jaakkola', 7),
#  ('Matthias Hein', 7),
#  ('Hagai Attias', 7),
#  ('John Langford', 7),
#  ('Aapo Hyvärinen', 7),
#  ('Satinder P. Singh', 7),
#  ('Ralf Herbrich', 7),
#  ('Zhihua Zhang', 7),
#  ('Padhraic Smyth', 7),
#  ('Javier R. Movellan', 7),
#  ('Francesco Orabona', 7),
#  ('Adam Kowalczyk', 7),
#  ('Shie Mannor', 7),
#  ('Tony Jebara', 7),
#  ('Yuchen Zhang', 7),
#  ('Gal Elidan', 7),
#  ('Alan L. Yuille', 6),
#  ('Nir Ailon', 6),
#  ('Shih-Chii Liu', 6),
#  ('Marina Meila', 6),
#  ('Joris M. Mooij', 6),
#  ('Trevor Hastie', 6),
#  ('Garvesh Raskutti', 6),
#  ('Sumio Watanabe', 6),
#  ('Liam Paninski', 6),
#  ('Guy Lebanon', 6),
#  ('Samory Kpotufe', 6),
#  ('Andreas Krause', 6),
#  ('Novi Quadrianto', 6),
#  ('Emile Richard', 6),
#  ('Léon Bottou', 6),
#  ('Tor Lattimore', 6),
#  ('Xi Chen', 6),
#  ('Mingyuan Zhou', 6),
#  ('Sepp Hochreiter', 6),
#  ('Saharon Rosset', 6),
#  ('Amir Globerson', 6),
#  ('Gerald Tesauro', 6),
#  ('Zhaoping Li', 6),
#  ('Raman Arora', 6),
#  ('Christopher M. Bishop', 6),
#  ('Neil D. Lawrence', 6),
#  ('Alessandro Rudi', 6),
#  ('Yoram Singer', 6),
#  ('Josip Djolonga', 6),
#  ('Andrew W. Moore', 6),
#  ('Wouter M. Koolen', 6),
#  ('Ashish Khetan', 6),
#  ('Kenji Doya', 6),
#  ('Thore Graepel', 6),
#  ('Marco Cuturi', 6),
#  ('Ian En-Hsu Yen', 6),
#  ('Gunnar Rätsch', 6),
#  ('Bill Baird', 6),
#  ('David A. Cohn', 6),
#  ('Andreas Argyriou', 6),
#  ('Gilles Blanchard', 6),
#  ('Nuno Vasconcelos', 6),
#  ('Mario Marchand', 6),
#  ('Jie Wang', 5),
#  ('Michael E. Tipping', 5),
#  ('Emanuel Todorov', 5),
#  ('Mijung Park', 5),
#  ('Tamir Hazan', 5),
#  ('Matthias Seeger', 5),
#  ('Simon S. Du', 5),
#  ('Liwei Wang', 5),
#  ('Fang Han', 5),
#  ('Yves Grandvalet', 5),
#  ('Alexandra Carpentier', 5),
#  ('Justin Domke', 5),
#  ('Yuhong Guo', 5),
#  ('Daniil Ryabko', 5),
#  ('Huan Xu', 5),
#  ('Cynthia Rudin', 5),
#  ('Gert Cauwenberghs', 5),
#  ('Daniel D. Lee', 5),
#  ('Andreas Maurer', 5),
#  ('Siwei Lyu', 5),
#  ('Rajesh P. N. Rao', 5),
#  ('David P. Helmbold', 5),
#  ('Thomas Hofmann', 5),
#  ('Amit Daniely', 5),
#  ('Aryan Mokhtari', 5),
#  ('Koji Tsuda', 5),
#  ('Francis Bach', 5),
#  ('Steven J. Nowlan', 5),
#  ('Mikhail Belkin', 5),
#  ('Dylan J. Foster', 5),
#  ('Anders Krogh', 5),
#  ('Suzanna Becker', 5),
#  ('Xin Wang', 5),
#  ('Kai Yu', 5),
#  ('Tom Heskes', 5),
#  ('John Duchi', 5),
#  ('Mohammad Ghavamzadeh', 5),
#  ('Ian Osband', 5),
#  ('Suvrit Sra', 5),
#  ('Anqi Wu', 5),
#  ('Jieping Ye', 5),
#  ('Kirthevasan Kandasamy', 5),
#  ('Chong Wang', 5),
#  ('Sahand Negahban', 5),
#  ('Baback Moghaddam', 5),
#  ('Tzu-Kuo Huang', 5),
#  ('Maneesh Sahani', 5),
#  ('Tuo Zhao', 5),
#  ('Durk P. Kingma', 5),
#  ('Ricardo Henao', 5),
#  ('Jacob D. Abernethy', 5),
#  ('Sébastien Bubeck', 5),
#  ('Eric Balkanski', 5),
#  ('Jayadev Acharya', 5),
#  ('Ran El-Yaniv', 5),
#  ('Jason Weston', 5),
#  ('Marius Kloft', 5),
#  ('Shai Shalev-Shwartz', 5),
#  ('Richard Socher', 5),
#  ('Timothy X. Brown', 5),
#  ('Olivier Bousquet', 5),
#  ('Thomas G. Dietterich', 5),
#  ('Dengyong Zhou', 5),
#  ('Alexandre Pouget', 5),
#  ('Nathan Srebro', 5),
#  ('Subutai Ahmad', 5),
#  ('Rémi Munos', 5),
#  ('Nan Du', 5),
#  ('Kevin G. Jamieson', 5),
#  ('Murat A. Erdogdu', 5),
#  ('Patrice Simard', 5),
#  ('Sergey Levine', 5),
#  ('Todd K. Leen', 5),
#  ('Avrim Blum', 5),
#  ('Yiming Ying', 5),
#  ('Chi Jin', 5),
#  ('Richard Nock', 4),
#  ('Baharan Mirzasoleiman', 4),
#  ('Eric B. Baum', 4),
#  ('Nihar B. Shah', 4),
#  ('Vladimir Koltchinskii', 4),
#  ('Steve Hanneke', 4),
#  ('Tianbao Yang', 4),
#  ('Andrew G. Wilson', 4),
#  ('Xiangyu Wang', 4),
#  ('Dan Alistarh', 4),
#  ('Michael J. Kearns', 4),
#  ('Vinayak Rao', 4),
#  ('Dan Garber', 4),
#  ('Alexander Clark', 4),
#  ('Vikas Garg', 4),
#  ('Nebojsa Jojic', 4),
#  ('Aaron van den Oord', 4),
#  ('Mehrdad Mahdavi', 4),
#  ('Ryota Tomioka', 4),
#  ('Steven Gold', 4),
#  ('Emmanuel Abbe', 4),
#  ('Hugo Larochelle', 4),
#  ('Eric I. Chang', 4),
#  ('Jimmy Ba', 4),
#  ('Pranjal Awasthi', 4),
#  ('Ralph Etienne-Cummings', 4),
#  ('Shai Ben-David', 4),
#  ('Dörthe Malzahn', 4),
#  ('Konrad Rieck', 4),
#  ('Aviv Tamar', 4),
#  ('Hervé Bourlard', 4),
#  ('Shashank Singh', 4),
#  ('Peter Schulam', 4),
#  ('Hariharan Narayanan', 4),
#  ('Yi Xu', 4),
#  ('Amir-massoud Farahmand', 4),
#  ('Peter Sykacek', 4),
#  ('Akshay Krishnamurthy', 4),
#  ('K. Wong', 4),
#  ('Amit Dhurandhar', 4),
#  ('Adel Javanmard', 4),
#  ('Christopher Williams', 4),
#  ('Kevin Ellis', 4),
#  ('Behnam Neyshabur', 4),
#  ('Laurent Itti', 4),
#  ('John Shawe-Taylor', 4),
#  ('Indraneel Mukherjee', 4),
#  ('Arindam Banerjee', 4),
#  ('Fernando J. Pineda', 4),
#  ('Animashree Anandkumar', 4),
#  ('Jürgen Schmidhuber', 4),
#  ('Weiwei Liu', 4),
#  ('Huishuai Zhang', 4),
#  ('Stefan Schaal', 4),
#  ('Dirk Ormoneit', 4),
#  ('Michael Collins', 4),
#  ('Sheng Chen', 4),
#  ('Yair Weiss', 4),
#  ('Michael I. Jordan', 4),
#  ('Marek Petrik', 4),
#  ('Jeffrey Pennington', 4),
#  ('Mikio L. Braun', 4),
#  ('Trevor Darrell', 4),
#  ('Marius Pachitariu', 4),
#  ('Nathan Intrator', 4),
#  ('Peter Auer', 4),
#  ('Iain Murray', 4),
#  ('Michalis Titsias RC AUEB', 4),
#  ('Yinlam Chow', 4),
#  ('Alyson K. Fletcher', 4),
#  ('Cho-Jui Hsieh', 4),
#  ('Kilian Q. Weinberger', 4),
#  ('Victor Gabillon', 4),
#  ('Andrew Y. Ng', 4),
#  ('David P. Wipf', 4),
#  ('Cristina Savin', 4),
#  ('Zhengdong Lu', 4),
#  ('Piyush Rai', 4),
#  ('Yann LeCun', 4),
#  ('Alessandro Lazaric', 4),
#  ('Stefan Wager', 4),
#  ('Phil Long', 4),
#  ('Ernst Niebur', 4),
#  ('Steve R. Waterhouse', 4),
#  ('Howard Hua Yang', 4),
#  ('Po-Ling Loh', 4),
#  ('Yossi Arjevani', 4),
#  ('Yan Karklin', 4),
#  ('Hongjing Lu', 4),
#  ('Pascal Germain', 4),
#  ('John G. Harris', 4),
#  ('Stephen Jose Hanson', 4),
#  ('Sören Sonnenburg', 4),
#  ('Vladimir Vapnik', 4),
#  ('Ben Taskar', 4),
#  ('Gérard Biau', 4),
#  ('Marcus Hutter', 4),
#  ('Ashish Kapoor', 4),
#  ('Martin Zinkevich', 4),
#  ('Bernhard Schölkopf', 4),
#  ('Moritz Hardt', 4),
#  ('James Petterson', 4),
#  ('John S. Bridle', 4),
#  ('Nathan Kallus', 4),
#  ('Lorenzo Rosasco', 4),
#  ('Wei Chen', 4),
#  ('John Lazzaro', 4),
#  ('Martin Slawski', 4),
#  ('Alexander T. Ihler', 4),
#  ('Nan Ding', 4),
#  ('Ronan Collobert', 4),
#  ('Pascal Vincent', 4),
#  ('Bruno Scherrer', 4),
#  ('Xingguo Li', 4),
#  ('Shun-ichi Amari', 4),
#  ('Lijun Zhang', 4),
#  ('Grégoire Montavon', 4),
#  ('David S. Touretzky', 4),
#  ('Shivani Agarwal', 4),
#  ('Eric Mjolsness', 4),
#  ('Geoffrey J. Goodhill', 4),
#  ('Yu Zhang', 4),
#  ('Xinghao Pan', 4),
#  ('Alexander Rakhlin', 4),
#  ('Antonio Torralba', 4),
#  ('Samy Bengio', 4),
#  ('Malik Magdon-Ismail', 4),
#  ('Aaron C. Courville', 4),
#  ('Rich Caruana', 4),
#  ('Carl Edward Rasmussen', 4),
#  ('Daphna Weinshall', 4),
#  ('Nitish Srivastava', 4),
#  ('Ji Liu', 4),
#  ('Arya Mazumdar', 4),
#  ('Ilya Sutskever', 4),
#  ('Dmitri B. Chklovskii', 4),
#  ('Paul W. Munro', 4),
#  ('Ofer Meshi', 4),
#  ('Volker Roth', 4),
#  ('Christoph Dann', 4),
#  ('Maxim Raginsky', 4),
#  ('Shai Shalev-shwartz', 4),
#  ('Suriya Gunasekar', 4),
#  ('Yoshinobu Kawahara', 4),
#  ('Vikas Sindhwani', 4),
#  ('Chiwoo Park', 4),
#  ('Risi Kondor', 4),
#  ('Nicholas Ruozzi', 4),
#  ('Ali Rahimi', 4),
#  ('Clayton Scott', 4),
#  ('Alexandre Bouchard-côté', 4),
#  ('Mladen Kolar', 4),
#  ('Ery Arias-Castro', 4),
#  ('Oriol Vinyals', 4),
#  ('Daniel J. Hsu', 4),
#  ('Odelia Schwartz', 4),
#  ('Anima Anandkumar', 4),
#  ('Anton Schwaighofer', 4),
#  ('Jiajun Wu', 4),
#  ('Joshua Alspector', 4),
#  ('Christopher G. Atkeson', 4),
#  ('Gergely Neu', 4),
#  ('Ehsan Elhamifar', 4),
#  ('Junhong Lin', 4),
#  ('Alina Beygelzimer', 4),
#  ('George Konidaris', 4),
#  ('Yu-Xiang Wang', 4),
#  ('Jonathan Huang', 4),
#  ('Jacob Steinhardt', 4),
#  ('Pieter Abbeel', 4),
#  ('Xinyang Yi', 4),
#  ('Abhishek Kumar', 4),
#  ('Guy Bresler', 4),
#  ('Jean-philippe Vert', 4),
#  ('Amnon Shashua', 4),
#  ('Jian Zhang', 4),
#  ('Sam T. Roweis', 4),
#  ('Bo Dai', 4),
#  ('Andriy Mnih', 4),
#  ('Yang Wang', 4),
#  ('Rina Foygel', 4),
#  ('Geoffrey J. Gordon', 4),
#  ('Alan A. Stocker', 4),
#  ('Kush Bhatia', 4),
#  ('Michael S. Lewicki', 4),
#  ('David Sontag', 4),
#  ('Umar Syed', 4),
#  ('Vladimir Vovk', 4),
#  ('Babak Hassibi', 4),
#  ('Anthony J. Bell', 4),
#  ('Nicolas Boumal', 3),
#  ('Christos Boutsidis', 3),
#  ('Daniel Vainsencher', 3),
#  ('Akshay Balsubramani', 3),
#  ('Stephen M. Omohundro', 3),
#  ('Aleksandrs Slivkins', 3),
#  ('Eytan Ruppin', 3),
#  ('Te-Won Lee', 3),
#  ('Ying Zhao', 3),
#  ('XuanLong Nguyen', 3),
#  ('Finale Doshi-velez', 3),
#  ('Blake E. Woodworth', 3),
#  ('David M. Blei', 3),
#  ('Vitaly Kuznetsov', 3),
#  ('Chunhua Shen', 3),
#  ('Ke Chen', 3),
#  ('Zhengyuan Zhou', 3),
#  ('Flavio Chierichetti', 3),
#  ('Mohammad Norouzi', 3),
#  ('Lei Shi', 3),
#  ('Eyal Even-dar', 3),
#  ('William T. Freeman', 3),
#  ('Stéphan Clémençon', 3),
#  ('Herbert Jaeger', 3),
#  ('David DeMers', 3),
#  ('Anthony Kuh', 3),
#  ('Fabian Pedregosa', 3),
#  ('Nicolas L. Roux', 3),
#  ('Debarghya Ghoshdastidar', 3),
#  ('Alex Graves', 3),
#  ('Yichuan Zhang', 3),
#  ('Justin A. Boyan', 3),
#  ('Daniel Russo', 3),
#  ('Damien Scieur', 3),
#  ('David Wingate', 3),
#  ('Daniele Calandriello', 3),
#  ('Jean-Bastien Grill', 3),
#  ('Luigi Acerbi', 3),
#  ('Daniel Zoran', 3),
#  ('Parikshit Ram', 3),
#  ('Aurko Roy', 3),
#  ("Marc'aurelio Ranzato", 3),
#  ('Timothy K. Horiuchi', 3),
#  ('Janet Wiles', 3),
#  ('Dale Schuurmans', 3),
#  ('John R. Hershey', 3),
#  ('Maxim Likhachev', 3),
#  ('Ralph Linsker', 3),
#  ('Philipp Hennig', 3),
#  ('Christof Koch', 3),
#  ('Yangqing Jia', 3),
#  ('Wei Sun', 3),
#  ('Michael Schmitt', 3),
#  ('Jasper Snoek', 3),
#  ('Jiashi Feng', 3),
#  ('Zhirong Yang', 3),
#  ('Angela J. Yu', 3),
#  ('John Moody', 3),
#  ('Tal Grossman', 3),
#  ('Fajwel Fogel', 3),
#  ('Wyeth Bair', 3),
#  ('Haim Avron', 3),
#  ('Cong Han Lim', 3),
#  ('Jordan B. Pollack', 3),
#  ('Dana Angluin', 3),
#  ('Yi Zhang', 3),
#  ('Kai-Yeung Siu', 3),
#  ('Ralph Neuneier', 3),
#  ('Matthew D. Hoffman', 3),
#  ('Se-Young Yun', 3),
#  ('Vitaly Feldman', 3),
#  ('Aryeh Kontorovich', 3),
#  ('Prem K. Gopalan', 3),
#  ('Bernd Fischer', 3),
#  ('William Bialek', 3),
#  ('Charles Lee Isbell Jr.', 3),
#  ('Tim V. Erven', 3),
#  ('Hannes Nickisch', 3),
#  ('Özgür Şimşek', 3),
#  ('Benjamin V. Roy', 3),
#  ('Lucas Theis', 3),
#  ('Shinji Ito', 3),
#  ('Chuanyi Ji', 3),
#  ('Thomas Natschläger', 3),
#  ('Emily L. Denton', 3),
#  ('Jennifer A. Gillenwater', 3),
#  ('Peng Xu', 3),
#  ('Doina Precup', 3),
#  ('Richard Rohwer', 3),
#  ('Nagarajan Natarajan', 3),
#  ('Ilias Diakonikolas', 3),
#  ('Haipeng Luo', 3),
#  ('Virginia R. de Sa', 3),
#  ('Joonseok Lee', 3),
#  ('Dustin Tran', 3),
#  ('Michal Derezinski', 3),
#  ('Neil Burgess', 3),
#  ('Elias Bareinboim', 3),
#  ('Graham W. Taylor', 3),
#  ('Peter Carbonetto', 3),
#  ('Ambuj Tewari', 3),
#  ('Shalabh Bhatnagar', 3),
#  ('Alain Rakotomamonjy', 3),
#  ('Thang D. Bui', 3),
#  ('Les E. Atlas', 3),
#  ('Richard Coggins', 3),
#  ('Pradeep Shenoy', 3),
#  ('Rong Jin', 3),
#  ('Xiangru Lian', 3),
#  ('Fabian L. Wauthier', 3),
#  ('Lehel Csató', 3),
#  ('Ryan Kiros', 3),
#  ('Arno Onken', 3),
#  ('Yoav Freund', 3),
#  ('David Newman', 3),
#  ('Jerry Zhu', 3),
#  ('Leonidas Lefakis', 3),
#  ('Mohammad E. Khan', 3),
#  ('Kevin Swersky', 3),
#  ('Hongzhou Lin', 3),
#  ('Harris Drucker', 3),
#  ('Lei Xu', 3),
#  ('Toshiyuki Tanaka', 3),
#  ('Philip S. Thomas', 3),
#  ('Makoto Hirayama', 3),
#  ('Peter Kairouz', 3),
#  ('Jörg Lücke', 3),
#  ('Pietro Berkes', 3),
#  ('Jaedeug Choi', 3),
#  ('Vince Lyzinski', 3),
#  ('Jianqing Fan', 3),
#  ('Sanjiv Kumar', 3),
#  ('James Hensman', 3),
#  ('David Rogers', 3),
#  ('Chicheng Zhang', 3),
#  ('Harald Steck', 3),
#  ('Marian Stewart Bartlett', 3),
#  ('Nisheeth Srivastava', 3),
#  ('Chiranjib Bhattacharyya', 3),
#  ('Antoine Bordes', 3),
#  ('James M. Bower', 3),
#  ('Yaser S. Abu-Mostafa', 3),
#  ('Hilbert J. Kappen', 3),
#  ('Sebastian Gerwinn', 3),
#  ('Kareem Amin', 3),
#  ('Lin Xiao', 3),
#  ('Rizal Fathony', 3),
#  ('Xiaohui Xie', 3),
#  ('Guy Shani', 3),
#  ('Manfred K. Warmuth', 3),
#  ('Asela Gunawardana', 3),
#  ('David Horn', 3),
#  ('Maksims Volkovs', 3),
#  ('Gale Martin', 3),
#  ('Miguel A. Carreira-Perpinan', 3),
#  ('Cameron Musco', 3),
#  ('John N. Tsitsiklis', 3),
#  ('Sundeep Rangan', 3),
#  ('Christian Borgs', 3),
#  ('Zenglin Xu', 3),
#  ('Sebastian Mika', 3),
#  ('Luis E. Ortiz', 3),
#  ('Hossein Azari Soufiani', 3),
#  ('Yizhe Zhang', 3),
#  ('Yuanzhi Li', 3),
#  ('Lucas C. Parra', 3),
#  ('Wittawat Jitkrittum', 3),
#  ('Alon Gonen', 3),
#  ('Paul A. Viola', 3),
#  ('Zhuo Wang', 3),
#  ('Kuzman Ganchev', 3),
#  ('Mingsheng Long', 3),
#  ('Karthik Mohan', 3),
#  ('Yudong Chen', 3),
#  ('Aaron Defazio', 3),
#  ('Girish N. Patel', 3),
#  ('Isabelle Guyon', 3),
#  ('Liva Ralaivola', 3),
#  ('Philip M. Long', 3),
#  ('Malte Kuss', 3),
#  ('Pinghua Gong', 3),
#  ('Stefano Ermon', 3),
#  ('Peter Meinicke', 3),
#  ('John S. Denker', 3),
#  ('Srikanth Jagabathula', 3),
#  ('Viren Jain', 3),
#  ('Francois Caron', 3),
#  ('M. Pawan Kumar', 3),
#  ('Pannagadatta K. Shivaswamy', 3),
#  ('Lars Buesing', 3),
#  ('Noga Alon', 3),
#  ('Vinod Nair', 3),
#  ('Lee-Ad Gottlieb', 3),
#  ('Gustavo Malkomes', 3),
#  ('Assaf Glazer', 3),
#  ('Genevieve B. Orr', 3),
#  ('Jun Wang', 3),
#  ('Patrice Y. Simard', 3),
#  ('Patrik O. Hoyer', 3),
#  ('David Lopez-Paz', 3),
#  ('Máté Lengyel', 3),
#  ('Pan Li', 3),
#  ('Lavi Shpigelman', 3),
#  ('Dimitris Bertsimas', 3),
#  ('Ulrike V. Luxburg', 3),
#  ('Ayan Chakrabarti', 3),
#  ('Daniel B. Neill', 3),
#  ('Stella X. Yu', 3),
#  ('Matthias Bethge', 3),
#  ('J. A. Bagnell', 3),
#  ('Pascal Poupart', 3),
#  ('Ulrike von Luxburg', 3),
#  ('Jack D. Cowan', 3),
#  ('David E. Carlson', 3),
#  ('Christian R. Shelton', 3),
#  ('Moein Falahatgar', 3),
#  ('Matey Neykov', 3),
#  ('James M. Coughlan', 3),
#  ('Zoltán Szabó', 3),
#  ('Emily Fox', 3),
#  ('Jacob Goldberger', 3),
#  ('Guido Dornhege', 3),
#  ('Fabian Sinz', 3),
#  ('Emilie Kaufmann', 3),
#  ('David Cohn', 3),
#  ('Jenna Wiens', 3),
#  ('Nello Cristianini', 3),
#  ('Ichiro Takeuchi', 3),
#  ('Matthew Brand', 3),
#  ('Ashok Cutkosky', 3),
#  ('Eugene Ndiaye', 3),
#  ('Tim van Erven', 3),
#  ('Jeremy S. De Bonet', 3),
#  ('Abhinav Gupta', 3),
#  ('Fei Sha', 3),
#  ('Konrad P. Körding', 3),
#  ('Brian Sallans', 3),
#  ('Quanquan Gu', 3),
#  ('Yves Chauvin', 3),
#  ('Davi Geiger', 3),
#  ('Zeeshan Syed', 3),
#  ('Michael E. Hasselmo', 3),
#  ('Shantanu Chakrabartty', 3),
#  ('Purushottam Kar', 3),
#  ('Eizaburo Doi', 3),
#  ('Elad Schneidman', 3),
#  ('Shuheng Zhou', 3),
#  ('Daniele Durante', 3),
#  ('Liu Yang', 3),
#  ('Qirong Ho', 3),
#  ('Jiecao Chen', 3),
#  ('Christian Walder', 3),
#  ('Clay Spence', 3),
#  ('Yash Deshpande', 3),
#  ('Yang Song', 3),
#  ('Amit Manwani', 3),
#  ('Adith Swaminathan', 3),
#  ('Lorenzo Torresani', 3),
#  ('David B. Grimes', 3),
#  ('Huahua Wang', 3),
#  ('Michael C. Hughes', 3),
#  ('Guo-Zheng Sun', 3),
#  ('Theodore J. Perkins', 3),
#  ('Kevin P. Murphy', 3),
#  ('Mahito Sugiyama', 3),
#  ("Randall C. O'Reilly", 3),
#  ('Rodolphe Jenatton', 3),
#  ('Yishay Mansour', 3),
#  ('Sridhar Mahadevan', 3),
#  ('Honglak Lee', 3),
#  ('Scott Linderman', 3),
#  ('Tomer Koren', 3),
#  ('Ian Goodfellow', 3),
#  ('Eyal Krupka', 3),
#  ('Esther Levin', 3),
#  ('Kai-Yang Chiang', 3),
#  ('Mehrdad Farajtabar', 3),
#  ('Khashayar Rohanimanesh', 3),
#  ('Zhao Song', 3),
#  ('Balázs Kégl', 3),
#  ('Shay B. Cohen', 3),
#  ('Andreas Christmann', 3),
#  ('Mark A. Gluck', 3),
#  ('Ilya Shpitser', 3),
#  ('Daniel Lowd', 3),
#  ('Martin Szummer', 3),
#  ('K. Y. Michael Wong', 3),
#  ('Ahmed M. Alaa', 3),
#  ('Yevgeny Seldin', 3),
#  ('Steffen Bickel', 3),
#  ('Yarin Gal', 3),
#  ('Fredrik Lindsten', 3),
#  ('Michael S. Gray', 3),
#  ('Kihyuk Sohn', 3),
#  ('Ilya O. Tolstikhin', 3),
#  ('Dahua Lin', 3),
#  ('Zelda E. Mariet', 3),
#  ('Constantinos Daskalakis', 3),
#  ('Walid Krichene', 3),
#  ('Changyou Chen', 3),
#  ('Sham Kakade', 3),
#  ('Miguel Lázaro-Gredilla', 3),
#  ('Noam Brown', 3),
#  ('Jie Shen', 3),
#  ('Youssef Mroueh', 3),
#  ('Judy Hoffman', 3),
#  ('Chen Yanover', 3),
#  ('Daniel J. Lizotte', 3),
#  ('Tomoharu Iwata', 3),
#  ('Xiaofei He', 3),
#  ('Charles A. Micchelli', 3),
#  ('Binbin Lin', 3),
#  ('David Maxwell Chickering', 3),
#  ('Ron Meir', 3),
#  ('Jonathan W. Pillow', 3),
#  ('Naonori Ueda', 3),
#  ('Vasilis Syrgkanis', 3),
#  ('Gunwoong Park', 3),
#  ('Sung-Soo Ahn', 3),
#  ('Mahdi Milani Fard', 3),
#  ('Margareta Ackerman', 3),
#  ('Yuanqing Lin', 3),
#  ('Han Zhao', 3),
#  ('Boaz Nadler', 3),
#  ('Shiau Hong Lim', 3),
#  ('Kristen Grauman', 3),
#  ('Wenye Li', 3),
#  ('Kari Torkkola', 3),
#  ('Sashank J. Reddi', 3),
#  ('Bernd Fritzke', 3),
#  ('Nader H. Bshouty', 3),
#  ('Yair Wiener', 3),
#  ('Noam Slonim', 3),
#  ('Mohammad Saberian', 3),
#  ('Harikrishna Narasimhan', 3),
#  ('Takafumi Kanamori', 3),
#  ('Paramveer S. Dhillon', 3),
#  ('Shohei Shimizu', 3),
#  ('Rafael Frongillo', 3),
#  ('Been Kim', 3),
#  ('Carl Vondrick', 3),
#  ('Jonathan Huggins', 3),
#  ('Oliver Williams', 3),
#  ('Sophie Denève', 3),
#  ('Isaac Meilijson', 3),
#  ('Harish G. Ramaswamy', 3),
#  ('Igor V. Cadez', 3),
#  ('Kwang-Sung Jun', 3),
#  ('Isabel Valera', 3),
#  ('Pierre Garrigues', 3),
#  ('Gavin C. Cawley', 3),
#  ('Alberto Bietti', 3),
#  ('Liefeng Bo', 3),
#  ('Pan Xu', 3),
#  ('Kohei Hayashi', 3),
#  ('Trevor Campbell', 3),
#  ('Christoph Bregler', 3),
#  ('Xiaoxiao Guo', 3),
#  ('Rie Johnson', 3),
#  ('Stéphan J. Clémençcon', 3),
#  ('Joseph L. Austerweil', 3),
#  ('Philip Bachman', 3),
#  ('Mikhail Yurochkin', 3),
#  ('Il Memming Park', 3),
#  ('Eiji Mizutani', 3),
#  ('Jianfei Chen', 3),
#  ('Robert C. Williamson', 3),
#  ('Anshumali Shrivastava', 3),
#  ('Yunwen Lei', 3),
#  ('Vikas C. Raykar', 3),
#  ('J. Z. Kolter', 3),
#  ('Jacob Abernethy', 3),
#  ('Olvi L. Mangasarian', 3),
#  ('Chao Gao', 3),
#  ('Krzysztof M. Choromanski', 3),
#  ('André van Schaik', 3),
#  ('Ling Huang', 3),
#  ('Oluwasanmi O. Koyejo', 3),
#  ('John E. Moody', 3),
#  ('Mingrui Liu', 3),
#  ('Kaushik Sinha', 2),
#  ('Andrew Guillory', 2),
#  ('Vijaykumar Gullapalli', 2),
#  ('Zhihui Zhu', 2),
#  ('Zhe Gan', 2),
#  ('Sewoong Oh', 2),
#  ('Mark Steyvers', 2),
#  ('Jure Leskovec', 2),
#  ('Yiwen Guo', 2),
#  ('Adam Kosiorek', 2),
#  ('Guillaume Desjardins', 2),
#  ('Minhyung Cho', 2),
#  ('Yuxin Chen', 2),
#  ('Syama Sundar Rangapuram', 2),
#  ('Andreas G. Andreou', 2),
#  ('Ronan Fruit', 2),
#  ('Robert R. Snapp', 2),
#  ('Quan Zhang', 2),
#  ('Ming Yuan', 2),
#  ('Chang Liu', 2),
#  ('Jarmo Hurri', 2),
#  ('Clay D. Spence', 2),
#  ('David Saad', 2),
#  ('Hao Li', 2),
#  ('Rémi Bardenet', 2),
#  ('Alan D. Marrs', 2),
#  ('Farzan Farnia', 2),
#  ('Huma Lodhi', 2),
#  ('Gabriele Farina', 2),
#  ('Rudy R. Bunel', 2),
#  ('Nino Shervashidze', 2),
#  ('Koosha Khalvati', 2),
#  ('Geremy Heitz', 2),
#  ('Marcin Andrychowicz', 2),
#  ('José Carlos Príncipe', 2),
#  ('Roger B. Grosse', 2),
#  ('Yuesheng Xu', 2),
#  ('Ruitong Huang', 2),
#  ('Jianxin Wu', 2),
#  ('Lyndsey C. Pickup', 2),
#  ('Bharath Sriperumbudur', 2),
#  ('Zhi Yang', 2),
#  ('Armand Joulin', 2),
#  ('Michael Fink', 2),
#  ('Georgios Theocharous', 2),
#  ('Felix A. Wichmann', 2),
#  ('Jim C. Huang', 2),
#  ('Ivor W. Tsang', 2),
#  ('Odalric Maillard', 2),
#  ('Anitha Kannan', 2),
#  ('Balaji Lakshminarayanan', 2),
#  ('Xuerui Wang', 2),
#  ('Adam Santoro', 2),
#  ('Eric A. Wan', 2),
#  ('Alexander Kirillov', 2),
#  ('Dashan Gao', 2),
#  ('Valerio Perrone', 2),
#  ('William W. Cohen', 2),
#  ('Hongseok Namkoong', 2),
#  ('Christoforos Christoforou', 2),
#  ('Soumya Ghosh', 2),
#  ('Harm van Seijen', 2),
#  ('Stephane Ross', 2),
#  ('Patrick O. Perry', 2),
#  ('David I. Inouye', 2),
#  ('Ofir Nachum', 2),
#  ('Quoc Tran-Dinh', 2),
#  ('Celestine Dünner', 2),
#  ('Steffen Grünewälder', 2),
#  ('Guillaume Rabusseau', 2),
#  ('Chaitanya Ryali', 2),
#  ('Quoc V. Le', 2),
#  ('Alexander J. Ratner', 2),
#  ('Tianyi Zhou', 2),
#  ('Cong Fang', 2),
#  ('Sennay Ghebreab', 2),
#  ('Jiarong Jiang', 2),
#  ('Hong Chen', 2),
#  ('Yasin Abbasi', 2),
#  ('Sohail Bahmani', 2),
#  ('Changfeng Wang', 2),
#  ('Aditya Grover', 2),
#  ('Ernesto De Vito', 2),
#  ('Christiane Linster', 2),
#  ('Dominik Endres', 2),
#  ('András Antos', 2),
#  ('Xinghua Lou', 2),
#  ('Matthew Joseph', 2),
#  ('Quanming Yao', 2),
#  ('Steven J. Bradtke', 2),
#  ('Jakob H. Macke', 2),
#  ('William R. Softky', 2),
#  ('Charlie Frogner', 2),
#  ('Falk Lieder', 2),
#  ('Stanislav Minsker', 2),
#  ('Yi HAO', 2),
#  ('Alp Yurtsever', 2),
#  ('Hiroyuki Nakahara', 2),
#  ('Régis Vert', 2),
#  ('Andrea Montanari', 2),
#  ('Shakir Mohamed', 2),
#  ('Ryotaro Kamimura', 2),
#  ('Guo-Xun Yuan', 2),
#  ('Si Wu', 2),
#  ('Purnamrita Sarkar', 2),
#  ('Xavier Bresson', 2),
#  ('Heinrich Jiang', 2),
#  ('Kate Saenko', 2),
#  ('Zhenwen Dai', 2),
#  ('Xiao-ming Wu', 2),
#  ('Stephen Gould', 2),
#  ('Ramya Korlakai Vinayak', 2),
#  ('Meisam Razaviyayn', 2),
#  ('Michail G. Lagoudakis', 2),
#  ('Zohar S. Karnin', 2),
#  ('Mark Craven', 2),
#  ('Gang Wang', 2),
#  ('Ting Liu', 2),
#  ('Florian Steinke', 2),
#  ('Shahin Shahrampour', 2),
#  ('Kyle R. Ulrich', 2),
#  ('Michael P. Perrone', 2),
#  ('Yonatan Amit', 2),
#  ('Yingzhen Li', 2),
#  ('J.D. Cowan', 2),
#  ('Gang Niu', 2),
#  ('Brian McWilliams', 2),
#  ('Rob Fergus', 2),
#  ('Brendan McMahan', 2),
#  ('Amin Jalali', 2),
#  ('Sujay Sanghavi', 2),
#  ('Haichao Zhang', 2),
#  ('Daniel B. Schwartz', 2),
#  ('Tsuyoshi Ueno', 2),
#  ('Raef Bassily', 2),
#  ('Liang Zhang', 2),
#  ('Jake Bouvrie', 2),
#  ('Ajay N. Jain', 2),
#  ('Kai Fan', 2),
#  ('Hermann Hild', 2),
#  ('Itay Gat', 2),
#  ('Hachem Kadri', 2),
#  ('Dan Feldman', 2),
#  ('Aaron Wilson', 2),
#  ('William M. Campbell', 2),
#  ('Anand Rangarajan', 2),
#  ('Ho Chung Law', 2),
#  ('Steve Renals', 2),
#  ('Hayit K. Greenspan', 2),
#  ('Hong C. Leung', 2),
#  ('Eric Saund', 2),
#  ('Tadashi Shibata', 2),
#  ('Onur Teymur', 2),
#  ('Marcus Held', 2),
#  ('Chao Zhang', 2),
#  ('Takayuki Osogami', 2),
#  ('Andrea Tirinzoni', 2),
#  ('Xiaohan Wei', 2),
#  ('Cha Zhang', 2),
#  ('Eric A. Hansen', 2),
#  ('James Thewlis', 2),
#  ('Grace Wahba', 2),
#  ('Simon Tong', 2),
#  ('Inderjit S. Dhillon', 2),
#  ('Gerhard Paass', 2),
#  ('Keerthiram Murugesan', 2),
#  ('Veit Elser', 2),
#  ('Giacomo Indiveri', 2),
#  ('Wataru Kumagai', 2),
#  ('Zhongwen Xu', 2),
#  ('Marcelo Fiori', 2),
#  ('Jamie Hayes', 2),
#  ('Ryota Kobayashi', 2),
#  ('Rachel Cummings', 2),
#  ('Tim Roughgarden', 2),
#  ('Jinbo Bi', 2),
#  ('John D. Lafferty', 2),
#  ('Erik B. Sudderth', 2),
#  ('Oliver Stegle', 2),
#  ('Mahdi M. Fard', 2),
#  ('S. Sathiya Keerthi', 2),
#  ('Maja Rudolph', 2),
#  ('Vinay Jethava', 2),
#  ('Hiroyuki Kasai', 2),
#  ('Alex', 2),
#  ('Abhishek Sharma', 2),
#  ('Shandian Zhe', 2),
#  ('Vincent Q. Vu', 2),
#  ('Amir M. Farahmand', 2),
#  ('Xiang Zhang', 2),
#  ('Yuanyuan Mi', 2),
#  ('Animashree An', 2),
#  ('Diana Cai', 2),
#  ('Mert Pilanci', 2),
#  ('Divyanshu Vats', 2),
#  ('Maya Gupta', 2),
#  ('Arthur Guez', 2),
#  ('Alp Kucukelbir', 2),
#  ('Jiquan Ngiam', 2),
#  ('Guillaume Lecué', 2),
#  ('M. P. Kumar', 2),
#  ('Sreerupa Das', 2),
#  ('Kristin P. Bennett', 2),
#  ('Julien Audiffren', 2),
#  ('Pan Zhou', 2),
#  ('Dean Pomerleau', 2),
#  ('Daniel Soudry', 2),
#  ('Iris Ginzburg', 2),
#  ('Marc Boullé', 2),
#  ('Yuanjun Gao', 2),
#  ('Evan W. Archer', 2),
#  ('Xubo B. Song', 2),
#  ('Itay Hubara', 2),
#  ('Andreas S. Weigend', 2),
#  ('Christopher R. Dance', 2),
#  ('Teng Zhang', 2),
#  ('Botond Cseke', 2),
#  ('Junhyuk Oh', 2),
#  ('Charles F. Stevens', 2),
#  ('Giorgio Corani', 2),
#  ('Jiaming Song', 2),
#  ('David Kauchak', 2),
#  ('Paul Wagner', 2),
#  ('Jeffrey W. Miller', 2),
#  ('Wolf Kienzle', 2),
#  ('Robert A. Legenstein', 2),
#  ...]

# %% [markdown]
# # most popular words used in title

# %%
articles.title_freq(ngrams_lst=[1])
# Out:
# [('learning', 2268),
#  ('model', 1150),
#  ('network', 1104),
#  ('neural', 784),
#  ('using', 601),
#  ('algorithm', 508),
#  ('bayesian', 435),
#  ('data', 421),
#  ('analysis', 380),
#  ('kernel', 376),
#  ('via', 375),
#  ('process', 365),
#  ('inference', 362),
#  ('optimization', 345),
#  ('method', 334),
#  ('classification', 330),
#  ('sparse', 306),
#  ('deep', 304),
#  ('estimation', 304),
#  ('gaussian', 287),
#  ('stochastic', 281),
#  ('regression', 273),
#  ('online', 272),
#  ('feature', 265),
#  ('machine', 257),
#  ('function', 252),
#  ('linear', 251),
#  ('clustering', 249),
#  ('efficient', 246),
#  ('image', 245),
#  ('dynamic', 242),
#  ('graph', 231),
#  ('approach', 229),
#  ('reinforcement', 228),
#  ('gradient', 225),
#  ('optimal', 215),
#  ('application', 209),
#  ('bound', 203),
#  ('recognition', 203),
#  ('fast', 198),
#  ('representation', 198),
#  ('matrix', 197),
#  ('adaptive', 195),
#  ('selection', 190),
#  ('information', 190),
#  ('variational', 183),
#  ('system', 180),
#  ('prediction', 177),
#  ('markov', 174),
#  ('random', 169),
#  ('visual', 168),
#  ('structure', 164),
#  ('problem', 164),
#  ('probabilistic', 163),
#  ('robust', 158),
#  ('vector', 157),
#  ('sampling', 155),
#  ('approximation', 153),
#  ('training', 152),
#  ('modeling', 144),
#  ('recurrent', 142),
#  ('based', 141),
#  ('mixture', 140),
#  ('detection', 139),
#  ('time', 139),
#  ('convex', 136),
#  ('large', 136),
#  ('structured', 136),
#  ('local', 132),
#  ('statistical', 131),
#  ('multiple', 131),
#  ('graphical', 130),
#  ('latent', 130),
#  ('hierarchical', 128),
#  ('object', 128),
#  ('active', 127),
#  ('bandit', 125),
#  ('search', 125),
#  ('distributed', 124),
#  ('control', 124),
#  ('policy', 124),
#  ('classifier', 121),
#  ('regularization', 121),
#  ('convergence', 121),
#  ('support', 120),
#  ('variable', 120),
#  ('neuron', 120),
#  ('distribution', 120),
#  ('space', 120),
#  ('tree', 119),
#  ('nonparametric', 117),
#  ('decision', 116),
#  ('minimization', 112),
#  ('unsupervised', 111),
#  ('nonlinear', 108),
#  ('approximate', 106),
#  ('field', 106),
#  ('complexity', 105),
#  ('generalization', 105),
#  ('descent', 104),
#  ('human', 103),
#  ('rate', 103),
#  ('spectral', 101),
#  ('theory', 101),
#  ('generative', 97),
#  ('generalized', 97),
#  ('framework', 96),
#  ('prior', 93),
#  ('continuous', 92),
#  ('propagation', 90),
#  ('set', 90),
#  ('error', 90),
#  ('component', 90),
#  ('memory', 89),
#  ('causal', 88),
#  ('natural', 87),
#  ('risk', 86),
#  ('adversarial', 85),
#  ('programming', 85),
#  ('loss', 85),
#  ('map', 84),
#  ('sample', 84),
#  ('hidden', 83),
#  ('semisupervised', 83),
#  ('maximum', 83),
#  ('speech', 81),
#  ('matching', 80),
#  ('metric', 80),
#  ('convolutional', 79),
#  ('ranking', 78),
#  ('density', 78),
#  ('pattern', 77),
#  ('boosting', 76),
#  ('game', 75),
#  ('largescale', 75),
#  ('temporal', 75),
#  ('regularized', 74),
#  ('constraint', 74),
#  ('highdimensional', 73),
#  ('manifold', 72),
#  ('margin', 71),
#  ('belief', 71),
#  ('scalable', 71),
#  ('reduction', 71),
#  ('sequential', 70),
#  ('conditional', 70),
#  ('binary', 70),
#  ('probability', 70),
#  ('coding', 69),
#  ('decomposition', 69),
#  ('multitask', 69),
#  ('rule', 69),
#  ('net', 68),
#  ('sequence', 68),
#  ('submodular', 67),
#  ('point', 67),
#  ('parallel', 66),
#  ('analog', 66),
#  ('tensor', 66),
#  ('noise', 65),
#  ('supervised', 65),
#  ('high', 64),
#  ('adaptation', 64),
#  ('state', 64),
#  ('comparison', 64),
#  ('spiking', 62),
#  ('general', 61),
#  ('embedding', 61),
#  ('multiclass', 61),
#  ('factorization', 61),
#  ('language', 61),
#  ('new', 60),
#  ('signal', 60),
#  ('vlsi', 60),
#  ('value', 59),
#  ('dimension', 58),
#  ('carlo', 58),
#  ('spike', 58),
#  ('maximization', 58),
#  ('discovery', 57),
#  ('domain', 57),
#  ('dynamical', 57),
#  ('parameter', 57),
#  ('pca', 57),
#  ('monte', 57),
#  ('code', 57),
#  ('discriminative', 57),
#  ('inverse', 56),
#  ('improved', 56),
#  ('population', 56),
#  ('effect', 56),
#  ('estimating', 56),
#  ('property', 56),
#  ('processing', 55),
#  ('sparsity', 55),
#  ('motion', 55),
#  ('entropy', 55),
#  ('brain', 55),
#  ('lowrank', 55),
#  ('distance', 55),
#  ('scene', 54),
#  ('computation', 54),
#  ('class', 54),
#  ('completion', 54),
#  ('projection', 54),
#  ('design', 54),
#  ('nonconvex', 54),
#  ('regret', 53),
#  ('global', 53),
#  ('architecture', 53),
#  ('source', 52),
#  ('scale', 52),
#  ('segmentation', 52),
#  ('label', 52),
#  ('factor', 52),
#  ('filtering', 51),
#  ('performance', 51),
#  ('measure', 51),
#  ('3d', 50),
#  ('discrete', 50),
#  ('minimax', 50),
#  ('likelihood', 50),
#  ('joint', 49),
#  ('transfer', 48),
#  ('variance', 47),
#  ('weight', 47),
#  ('task', 47),
#  ('covariance', 47),
#  ('recovery', 47),
#  ('family', 47),
#  ('connectionist', 47),
#  ('series', 46),
#  ('consistency', 46),
#  ('constrained', 46),
#  ('without', 46),
#  ('attention', 46),
#  ('separation', 46),
#  ('structural', 46),
#  ('action', 45),
#  ('estimator', 45),
#  ('noisy', 45),
#  ('similarity', 45),
#  ('dirichlet', 45),
#  ('topic', 45),
#  ('empirical', 45),
#  ('predictive', 45),
#  ('planning', 45),
#  ('implementation', 45),
#  ('bayes', 45),
#  ('identification', 45),
#  ('response', 45),
#  ('simple', 44),
#  ('program', 44),
#  ('rank', 44),
#  ('exploration', 44),
#  ('activity', 44),
#  ('independent', 44),
#  ('knowledge', 44),
#  ('ensemble', 44),
#  ('differential', 43),
#  ('principal', 43),
#  ('feedback', 42),
#  ('coordinate', 42),
#  ('embeddings', 42),
#  ('dimensional', 42),
#  ('multivariate', 42),
#  ('computational', 42),
#  ('towards', 42),
#  ('spatial', 42),
#  ('text', 42),
#  ('expert', 41),
#  ('environment', 41),
#  ('dimensionality', 41),
#  ('mean', 41),
#  ('study', 41),
#  ('group', 41),
#  ('cortex', 41),
#  ('dual', 41),
#  ('backpropagation', 41),
#  ('lasso', 40),
#  ('exponential', 40),
#  ('cell', 39),
#  ('improving', 39),
#  ('neuronal', 39),
#  ('relaxation', 39),
#  ('subspace', 39),
#  ('solution', 39),
#  ('blind', 39),
#  ('order', 39),
#  ('neighbor', 39),
#  ('pairwise', 39),
#  ('observation', 39),
#  ('tracking', 39),
#  ('extraction', 39),
#  ('iteration', 38),
#  ('boltzmann', 38),
#  ('cluster', 38),
#  ('greedy', 38),
#  ('single', 37),
#  ('finite', 37),
#  ('query', 37),
#  ('interaction', 37),
#  ('exact', 37),
#  ('functional', 37),
#  ('partial', 37),
#  ('infinite', 37),
#  ('complex', 37),
#  ('correlation', 37),
#  ('power', 36),
#  ('automatic', 36),
#  ('word', 36),
#  ('associative', 36),
#  ('filter', 36),
#  ('weighted', 36),
#  ('test', 36),
#  ('beyond', 35),
#  ('expectation', 35),
#  ('multiagent', 35),
#  ('dependency', 35),
#  ('technique', 35),
#  ('generation', 35),
#  ('curve', 35),
#  ('randomized', 35),
#  ('output', 35),
#  ('testing', 34),
#  ('missing', 34),
#  ('diffusion', 34),
#  ('strategy', 34),
#  ('polynomial', 34),
#  ('circuit', 34),
#  ('invariant', 34),
#  ('computer', 34),
#  ('computing', 34),
#  ('selective', 33),
#  ('iterative', 33),
#  ('evaluation', 33),
#  ('learn', 33),
#  ('hybrid', 33),
#  ('stability', 33),
#  ('uncertainty', 33),
#  ('chain', 33),
#  ('video', 33),
#  ('understanding', 33),
#  ('auditory', 32),
#  ('unified', 32),
#  ('cortical', 32),
#  ('svm', 32),
#  ('basis', 32),
#  ('recursive', 32),
#  ('relational', 32),
#  ('equation', 32),
#  ('mechanism', 32),
#  ('incremental', 31),
#  ('bias', 31),
#  ('shape', 31),
#  ('consistent', 31),
#  ('movement', 31),
#  ('synthesis', 31),
#  ('dependent', 31),
#  ('robustness', 31),
#  ('universal', 31),
#  ('guarantee', 31),
#  ('retrieval', 30),
#  ('partially', 30),
#  ('path', 30),
#  ('contextual', 30),
#  ('unknown', 30),
#  ('behavior', 30),
#  ('nonnegative', 30),
#  ('input', 30),
#  ('proximal', 30),
#  ('energy', 30),
#  ('plasticity', 30),
#  ('importance', 30),
#  ('phase', 30),
#  ('block', 30),
#  ('faster', 30),
#  ('size', 30),
#  ('least', 30),
#  ('minimum', 30),
#  ('em', 30),
#  ('transformation', 30),
#  ('realtime', 30),
#  ('geometric', 30),
#  ('semantic', 30),
#  ('quadratic', 29),
#  ('square', 29),
#  ('predicting', 29),
#  ('library', 29),
#  ('collaborative', 29),
#  ('practical', 29),
#  ('forest', 29),
#  ('asymptotic', 29),
#  ('face', 29),
#  ('lower', 29),
#  ('nearest', 29),
#  ('perception', 28),
#  ('multilayer', 28),
#  ('statistic', 28),
#  ('alternating', 28),
#  ('scaling', 28),
#  ('motor', 28),
#  ('product', 28),
#  ('streaming', 28),
#  ('estimate', 28),
#  ('decoding', 28),
#  ('direct', 28),
#  ('localization', 28),
#  ('compression', 28),
#  ('integration', 28),
#  ('criterion', 27),
#  ('alignment', 27),
#  ('private', 27),
#  ('posterior', 27),
#  ('svms', 27),
#  ('solving', 27),
#  ('discriminant', 27),
#  ('particle', 27),
#  ('mcmc', 27),
#  ('multilabel', 27),
#  ('case', 27),
#  ('connection', 26),
#  ('preference', 26),
#  ('experiment', 26),
#  ('mutual', 26),
#  ('making', 26),
#  ('pursuit', 26),
#  ('multiscale', 26),
#  ('reward', 26),
#  ('context', 26),
#  ('view', 26),
#  ('restricted', 26),
#  ('combining', 26),
#  ('principle', 26),
#  ('trajectory', 26),
#  ('synaptic', 25),
#  ('batch', 25),
#  ('flow', 25),
#  ('sensing', 25),
#  ('inferring', 25),
#  ('region', 25),
#  ('modelling', 25),
#  ('additive', 25),
#  ('combinatorial', 25),
#  ('example', 25),
#  ('result', 25),
#  ('perspective', 25),
#  ('accelerated', 25),
#  ('stimulus', 25),
#  ('finding', 25),
#  ('limit', 25),
#  ('simulation', 25),
#  ('autoencoders', 24),
#  ('averaging', 24),
#  ('flexible', 24),
#  ('grammar', 24),
#  ('pruning', 24),
#  ('implicit', 24),
#  ('spatiotemporal', 24),
#  ('low', 24),
#  ('artificial', 24),
#  ('exploiting', 24),
#  ('reasoning', 24),
#  ('social', 24),
#  ('locally', 24),
#  ('norm', 24),
#  ('sound', 24),
#  ('objective', 24),
#  ('semidefinite', 24),
#  ('stable', 24),
#  ('accuracy', 24),
#  ('correlated', 24),
#  ('message', 23),
#  ('privacy', 23),
#  ('multiarmed', 23),
#  ('mapping', 23),
#  ('symmetric', 23),
#  ('vision', 23),
#  ('gibbs', 23),
#  ('smooth', 23),
#  ('event', 23),
#  ('allocation', 23),
#  ('choice', 23),
#  ('translation', 23),
#  ('induction', 23),
#  ('labeling', 23),
#  ('multiplicative', 22),
#  ('hard', 22),
#  ('fisher', 22),
#  ('denoising', 22),
#  ('multidimensional', 22),
#  ('number', 22),
#  ('silicon', 22),
#  ('connectivity', 22),
#  ('perceptual', 22),
#  ('mdps', 22),
#  ('receptive', 22),
#  ('asynchronous', 22),
#  ('use', 22),
#  ('effective', 22),
#  ('chip', 22),
#  ('encoding', 21),
#  ('incomplete', 21),
#  ('divergence', 21),
#  ('link', 21),
#  ('hypothesis', 21),
#  ('parsing', 21),
#  ('direction', 21),
#  ('partition', 21),
#  ('extension', 21),
#  ('partitioning', 21),
#  ('normalization', 21),
#  ('one', 21),
#  ('multimodal', 21),
#  ('theoretical', 21),
#  ('toolbox', 21),
#  ('better', 21),
#  ('unlabeled', 21),
#  ('early', 21),
#  ('aggregation', 21),
#  ('logistic', 21),
#  ('unit', 21),
#  ('difference', 21),
#  ('train', 21),
#  ('poisson', 21),
#  ('nearoptimal', 21),
#  ('influence', 21),
#  ('hilbert', 20),
#  ('algorithmic', 20),
#  ('equivalence', 20),
#  ('feedforward', 20),
#  ('development', 20),
#  ('laplacian', 20),
#  ('confidence', 20),
#  ('independence', 20),
#  ('invariance', 20),
#  ('community', 20),
#  ('novel', 20),
#  ('analyzing', 20),
#  ('kmeans', 20),
#  ('transition', 20),
#  ('accurate', 20),
#  ('communication', 20),
#  ('operator', 20),
#  ('update', 19),
#  ('selforganizing', 19),
#  ('small', 19),
#  ('differentially', 19),
#  ('pomdps', 19),
#  ('theoretic', 19),
#  ('correspondence', 19),
#  ('concept', 19),
#  ('pose', 19),
#  ('identifying', 19),
#  ('categorization', 19),
#  ('crowdsourcing', 19),
#  ('orientation', 19),
#  ('marginal', 19),
#  ('setting', 19),
#  ('safe', 19),
#  ('experimental', 19),
#  ('cost', 19),
#  ('potential', 19),
#  ('python', 19),
#  ('tradeoff', 19),
#  ('positive', 19),
#  ('hierarchy', 19),
#  ('second', 18),
#  ('ica', 18),
#  ('hashing', 18),
#  ('combination', 18),
#  ('expression', 18),
#  ('characterization', 18),
#  ('unifying', 18),
#  ('optimistic', 18),
#  ('radial', 18),
#  ('observable', 18),
#  ('hebbian', 18),
#  ('threshold', 18),
#  ('robot', 18),
#  ('endtoend', 18),
#  ('optimizing', 18),
#  ('perceptron', 18),
#  ('limited', 18),
#  ('nonstationary', 18),
#  ('equilibrium', 18),
#  ('passing', 18),
#  ('parametric', 18),
#  ('two', 18),
#  ('dictionary', 18),
#  ('reconstruction', 18),
#  ('convolution', 18),
#  ('channel', 18),
#  ('relation', 18),
#  ('tight', 18),
#  ('provable', 17),
#  ('discrimination', 17),
#  ('score', 17),
#  ('acceleration', 17),
#  ('attractor', 17),
#  ('automated', 17),
#  ('real', 17),
#  ('approximating', 17),
#  ('recommendation', 17),
#  ('free', 17),
#  ('diverse', 17),
#  ('orthogonal', 17),
#  ('applied', 17),
#  ('modelbased', 17),
#  ('measurement', 17),
#  ('question', 17),
#  ('integrated', 17),
#  ('timevarying', 17),
#  ('thresholding', 17),
#  ('simultaneous', 17),
#  ('condition', 17),
#  ('imitation', 17),
#  ('level', 17),
#  ('bottleneck', 17),
#  ('attribute', 17),
#  ('contour', 17),
#  ('heterogeneous', 16),
#  ('interactive', 16),
#  ('mixed', 16),
#  ('fmri', 16),
#  ('intrinsic', 16),
#  ('competitive', 16),
#  ('agent', 16),
#  ('learned', 16),
#  ('interpretable', 16),
#  ('walk', 16),
#  ('composite', 16),
#  ('coupled', 16),
#  ('transport', 16),
#  ('generating', 16),
#  ('gans', 16),
#  ('uniform', 16),
#  ('rational', 16),
#  ('extracting', 16),
#  ('improve', 16),
#  ('perturbation', 16),
#  ('permutation', 16),
#  ('nonsmooth', 16),
#  ('sensory', 16),
#  ('penalty', 16),
#  ('protein', 16),
#  ('activation', 16),
#  ('scheme', 16),
#  ('construction', 16),
#  ('cascade', 16),
#  ('sgd', 15),
#  ('string', 15),
#  ('wasserstein', 15),
#  ('deterministic', 15),
#  ('document', 15),
#  ('autoregressive', 15),
#  ('gesture', 15),
#  ('smoothness', 15),
#  ('capacity', 15),
#  ('logic', 15),
#  ('fairness', 15),
#  ('precision', 15),
#  ('factored', 15),
#  ('crossvalidation', 15),
#  ('arbitrary', 15),
#  ('labeled', 15),
#  ('depth', 15),
#  ('eye', 15),
#  ('continuoustime', 15),
#  ('forecasting', 15),
#  ('saliency', 15),
#  ('role', 15),
#  ('measuring', 15),
#  ('qlearning', 15),
#  ('teaching', 15),
#  ('factorial', 15),
#  ('wavelet', 15),
#  ('relationship', 15),
#  ('surface', 15),
#  ('anomaly', 15),
#  ('relative', 15),
#  ('directed', 15),
#  ('synapsis', 15),
#  ('instance', 15),
#  ('procedure', 14),
#  ('tuning', 14),
#  ('synchronization', 14),
#  ('world', 14),
#  ('coupling', 14),
#  ('theorem', 14),
#  ('discovering', 14),
#  ('efficiency', 14),
#  ('reproducing', 14),
#  ('biological', 14),
#  ('provably', 14),
#  ('optical', 14),
#  ('hamiltonian', 14),
#  ('meet', 14),
#  ('compressed', 14),
#  ('optimality', 14),
#  ('relevance', 14),
#  ('dependence', 14),
#  ('convergent', 14),
#  ('constant', 14),
#  ('survey', 14),
#  ('symbolic', 14),
#  ('outlier', 14),
#  ('edge', 14),
#  ('learner', 14),
#  ('bounded', 14),
#  ('leastsquares', 14),
#  ('trace', 14),
#  ('handwritten', 14),
#  ('perceptrons', 14),
#  ('versus', 14),
#  ('deconvolution', 14),
#  ('genetic', 14),
#  ('category', 14),
#  ('compressive', 14),
#  ('bipartite', 14),
#  ('alternative', 14),
#  ('screening', 14),
#  ('pacbayes', 14),
#  ('reducing', 14),
#  ('v', 14),
#  ('improvement', 13),
#  ('bregman', 13),
#  ('average', 13),
#  ('offpolicy', 13),
#  ('geometry', 13),
#  ('overcomplete', 13),
#  ('related', 13),
#  ('tractable', 13),
#  ('strong', 13),
#  ('evidence', 13),
#  ('subset', 13),
#  ('shared', 13),
#  ('nongaussian', 13),
#  ('higherorder', 13),
#  ('music', 13),
#  ('secondorder', 13),
#  ('agnostic', 13),
#  ('informationtheoretic', 13),
#  ('mode', 13),
#  ('attentional', 13),
#  ('quantization', 13),
#  ('ridge', 13),
#  ('differentiable', 13),
#  ('pac', 13),
#  ('delay', 13),
#  ('fixed', 13),
#  ('among', 13),
#  ('change', 13),
#  ('minimal', 13),
#  ('interval', 13),
#  ('gaussians', 13),
#  ('switching', 13),
#  ('variation', 13),
#  ('monitoring', 13),
#  ('oracle', 13),
#  ('overlapping', 13),
#  ('moment', 13),
#  ('autonomous', 13),
#  ('navigation', 13),
#  ('smoothing', 13),
#  ('speed', 13),
#  ('arm', 13),
#  ('breaking', 13),
#  ('penalized', 13),
#  ('attack', 13),
#  ('area', 13),
#  ('answering', 13),
#  ('side', 13),
#  ('soft', 12),
#  ('annealing', 12),
#  ('multinomial', 12),
#  ('reduced', 12),
#  ('gap', 12),
#  ('interpretation', 12),
#  ('residual', 12),
#  ('learns', 12),
#  ('color', 12),
#  ('assignment', 12),
#  ('maxmargin', 12),
#  ('association', 12),
#  ('stream', 12),
#  ('gene', 12),
#  ('scoring', 12),
#  ('primaldual', 12),
#  ('localized', 12),
#  ('forward', 12),
#  ('langevin', 12),
#  ('landscape', 12),
#  ('selforganization', 12),
#  ('double', 12),
#  ('stopping', 12),
#  ('competition', 12),
#  ('acquisition', 12),
#  ('adversary', 12),
#  ('option', 12),
#  ('transductive', 12),
#  ('imaging', 12),
#  ('transform', 12),
#  ('thompson', 12),
#  ('riemannian', 12),
#  ('shift', 12),
#  ('different', 12),
#  ('physic', 12),
#  ('pacbayesian', 12),
#  ('count', 12),
#  ('surrogate', 12),
#  ('balanced', 12),
#  ('calibration', 12),
#  ('best', 12),
#  ('presence', 12),
#  ('interface', 12),
#  ('multiresolution', 12),
#  ('topology', 12),
#  ('extended', 12),
#  ('sensor', 12),
#  ('grouping', 12),
#  ('ising', 12),
#  ('shallow', 12),
#  ('line', 12),
#  ('character', 12),
#  ('ratio', 12),
#  ('decisionmaking', 12),
#  ('modulation', 12),
#  ('massive', 12),
#  ('minimizing', 12),
#  ('cross', 12),
#  ('determinantal', 12),
#  ('hippocampal', 12),
#  ('stationary', 12),
#  ('detecting', 12),
#  ('multiview', 12),
#  ('boundary', 12),
#  ('communicationefficient', 12),
#  ('part', 11),
#  ('actorcritic', 11),
#  ('mining', 11),
#  ('weighting', 11),
#  ('fully', 11),
#  ('monotonic', 11),
#  ('informative', 11),
#  ('quality', 11),
#  ('common', 11),
#  ('lateral', 11),
#  ('account', 11),
#  ('stein', 11),
#  ('disease', 11),
#  ('neuromorphic', 11),
#  ('profile', 11),
#  ('almost', 11),
#  ('softmax', 11),
#  ('audio', 11),
#  ('correction', 11),
#  ('dropout', 11),
#  ('software', 11),
#  ('predictor', 11),
#  ('braincomputer', 11),
#  ('learnability', 11),
#  ('shortterm', 11),
#  ('recording', 11),
#  ('maximizing', 11),
#  ('array', 11),
#  ('constructing', 11),
#  ('kernelbased', 11),
#  ('across', 11),
#  ('detector', 11),
#  ('emergence', 11),
#  ('near', 11),
#  ('hmms', 11),
#  ('bootstrap', 11),
#  ('assumption', 11),
#  ('content', 11),
#  ('recognizing', 11),
#  ('demonstration', 11),
#  ('auction', 11),
#  ('processor', 11),
#  ('abstraction', 11),
#  ('sketching', 11),
#  ('cyclic', 11),
#  ('fourier', 11),
#  ('integrating', 11),
#  ('work', 11),
#  ('worstcase', 11),
#  ('element', 11),
#  ('committee', 11),
#  ('rademacher', 11),
#  ('modular', 11),
#  ('firstorder', 11),
#  ('facial', 11),
#  ('inductive', 11),
#  ('toolkit', 11),
#  ('cause', 11),
#  ('spherical', 11),
#  ('many', 11),
#  ('weak', 11),
#  ('strategic', 11),
#  ('accelerating', 11),
#  ('cognitive', 10),
#  ('analytic', 10),
#  ('realistic', 10),
#  ('recovering', 10),
#  ('bounding', 10),
#  ('doubly', 10),
#  ('copula', 10),
#  ('singular', 10),
#  ('concentration', 10),
#  ('augmented', 10),
#  ('tangent', 10),
#  ('supervision', 10),
#  ('coefficient', 10),
#  ('slow', 10),
#  ('sensitive', 10),
#  ('resolution', 10),
#  ('dense', 10),
#  ('ordinal', 10),
#  ('novelty', 10),
#  ('oscillator', 10),
#  ('inequality', 10),
#  ('driven', 10),
#  ('extreme', 10),
#  ('derivative', 10),
#  ('trained', 10),
#  ('layer', 10),
#  ('speaker', 10),
#  ('hand', 10),
#  ('lifted', 10),
#  ('diagnosis', 10),
#  ('loopy', 10),
#  ('cooperative', 10),
#  ('budget', 10),
#  ('binding', 10),
#  ('splitting', 10),
#  ('montecarlo', 10),
#  ('column', 10),
#  ('coherence', 10),
#  ('storage', 10),
#  ('internal', 10),
#  ('dominance', 10),
#  ('convexity', 10),
#  ('formulation', 10),
#  ('expansion', 10),
#  ('hyperparameters', 10),
#  ('cover', 10),
#  ('undirected', 10),
#  ('individual', 10),
#  ('winnertakeall', 10),
#  ('acyclic', 10),
#  ('augmentation', 10),
#  ('compact', 10),
#  ('optimisation', 10),
#  ('type', 10),
#  ('inhibition', 10),
#  ('timing', 10),
#  ('canonical', 10),
#  ('truncated', 10),
#  ('retina', 10),
#  ('insight', 10),
#  ('conjugate', 10),
#  ('inversion', 10),
#  ('multistage', 10),
#  ('statespace', 10),
#  ('temporally', 10),
#  ('rapid', 10),
#  ('timeseries', 10),
#  ('bilinear', 10),
#  ('treatment', 10),
#  ('bidirectional', 9),
#  ('shrinkage', 9),
#  ('reliability', 9),
#  ('neighborhood', 9),
#  ('interpreting', 9),
#  ('compositional', 9),
#  ('controller', 9),
#  ('digit', 9),
#  ('globally', 9),
#  ('database', 9),
#  ('description', 9),
#  ('rotation', 9),
#  ('price', 9),
#  ('list', 9),
#  ('characteristic', 9),
#  ('primitive', 9),
#  ('good', 9),
#  ('kalman', 9),
#  ('market', 9),
#  ('cone', 9),
#  ('comparing', 9),
#  ('calcium', 9),
#  ('transforms', 9),
#  ('sensitivity', 9),
#  ('embedded', 9),
#  ('automaton', 9),
#  ('quantum', 9),
#  ('law', 9),
#  ('revisiting', 9),
#  ('sampler', 9),
#  ...]

# %% [markdown]
# # most popular pair of words used in title

# %%
articles.title_freq(ngrams_lst=[2])
# Out:
# [('neural network', 511),
#  ('reinforcement learning', 224),
#  ('gaussian process', 184),
#  ('graphical model', 110),
#  ('support vector', 103),
#  ('online learning', 94),
#  ('vector machine', 84),
#  ('active learning', 79),
#  ('gradient descent', 66),
#  ('machine learning', 63),
#  ('variational inference', 62),
#  ('component analysis', 62),
#  ('bayesian network', 60),
#  ('monte carlo', 57),
#  ('feature selection', 56),
#  ('stochastic gradient', 55),
#  ('deep learning', 53),
#  ('recurrent neural', 53),
#  ('learning algorithm', 51),
#  ('markov model', 48),
#  ('latent variable', 47),
#  ('semisupervised learning', 45),
#  ('model selection', 45),
#  ('deep neural', 44),
#  ('speech recognition', 44),
#  ('bayesian inference', 43),
#  ('hidden markov', 42),
#  ('kernel learning', 42),
#  ('unsupervised learning', 42),
#  ('random field', 41),
#  ('learning via', 41),
#  ('matrix factorization', 40),
#  ('mixture model', 40),
#  ('time series', 39),
#  ('convex optimization', 39),
#  ('decision process', 38),
#  ('matrix completion', 38),
#  ('belief propagation', 38),
#  ('markov decision', 38),
#  ('generative model', 37),
#  ('convolutional neural', 36),
#  ('risk minimization', 35),
#  ('variable model', 35),
#  ('principal component', 35),
#  ('density estimation', 34),
#  ('process regression', 34),
#  ('spiking neuron', 34),
#  ('approximate inference', 34),
#  ('high dimensional', 33),
#  ('dynamical system', 33),
#  ('large scale', 33),
#  ('neural net', 33),
#  ('learning using', 32),
#  ('function approximation', 31),
#  ('bayesian model', 31),
#  ('analog vlsi', 31),
#  ('supervised learning', 31),
#  ('boltzmann machine', 31),
#  ('natural image', 30),
#  ('sample complexity', 30),
#  ('structure learning', 29),
#  ('multitask learning', 29),
#  ('dimensionality reduction', 29),
#  ('nearest neighbor', 29),
#  ('deep network', 28),
#  ('structured prediction', 28),
#  ('large margin', 28),
#  ('gradient method', 28),
#  ('stochastic optimization', 28),
#  ('least square', 27),
#  ('dirichlet process', 26),
#  ('recurrent network', 26),
#  ('linear model', 26),
#  ('bayesian optimization', 26),
#  ('decision tree', 25),
#  ('learning multiple', 25),
#  ('domain adaptation', 25),
#  ('recognition using', 25),
#  ('object recognition', 25),
#  ('metric learning', 25),
#  ('network model', 25),
#  ('dynamic programming', 24),
#  ('independent component', 24),
#  ('maximum likelihood', 24),
#  ('point process', 24),
#  ('exponential family', 24),
#  ('topic model', 24),
#  ('spectral clustering', 24),
#  ('markov chain', 23),
#  ('associative memory', 23),
#  ('kernel method', 23),
#  ('policy gradient', 23),
#  ('sparse coding', 23),
#  ('empirical risk', 23),
#  ('multiarmed bandit', 23),
#  ('lower bound', 22),
#  ('learning sparse', 22),
#  ('value function', 22),
#  ('receptive field', 22),
#  ('probabilistic model', 22),
#  ('generative adversarial', 22),
#  ('linear regression', 21),
#  ('training deep', 21),
#  ('object detection', 21),
#  ('nonconvex optimization', 21),
#  ('basis function', 20),
#  ('causal inference', 20),
#  ('lowrank matrix', 20),
#  ('gaussian graphical', 20),
#  ('error bound', 20),
#  ('mutual information', 20),
#  ('variational bayesian', 20),
#  ('neural population', 20),
#  ('coordinate descent', 20),
#  ('deep reinforcement', 20),
#  ('transfer learning', 20),
#  ('gaussian mixture', 19),
#  ('learning deep', 19),
#  ('map inference', 19),
#  ('efficient learning', 19),
#  ('convergence rate', 19),
#  ('bayesian learning', 19),
#  ('data using', 19),
#  ('missing data', 19),
#  ('conditional random', 19),
#  ('classification using', 19),
#  ('learning approach', 18),
#  ('differentially private', 18),
#  ('regret bound', 18),
#  ('learning bayesian', 18),
#  ('multiple kernel', 18),
#  ('convolutional network', 18),
#  ('mean field', 18),
#  ('message passing', 18),
#  ('visual cortex', 18),
#  ('feature learning', 18),
#  ('logistic regression', 17),
#  ('restricted boltzmann', 17),
#  ('discriminant analysis', 17),
#  ('belief network', 17),
#  ('probabilistic inference', 17),
#  ('second order', 17),
#  ('3d object', 17),
#  ('decision making', 17),
#  ('submodular function', 17),
#  ('learning rate', 17),
#  ('markov random', 17),
#  ('policy iteration', 17),
#  ('policy search', 17),
#  ('hilbert space', 16),
#  ('maximum entropy', 16),
#  ('source separation', 16),
#  ('radial basis', 16),
#  ('em algorithm', 16),
#  ('tensor decomposition', 16),
#  ('process model', 16),
#  ('spike train', 16),
#  ('artificial neural', 16),
#  ('feature extraction', 16),
#  ('variable selection', 16),
#  ('nonnegative matrix', 16),
#  ('importance sampling', 16),
#  ('hierarchical clustering', 16),
#  ('model via', 16),
#  ('network using', 16),
#  ('convex relaxation', 15),
#  ('loss function', 15),
#  ('nonparametric bayesian', 15),
#  ('bayesian nonparametric', 15),
#  ('learning kernel', 15),
#  ('collaborative filtering', 15),
#  ('differential privacy', 15),
#  ('partially observable', 15),
#  ('markov network', 15),
#  ('generalization error', 15),
#  ('adversarial network', 15),
#  ('learning model', 15),
#  ('factor analysis', 15),
#  ('statistical model', 15),
#  ('latent dirichlet', 15),
#  ('random projection', 15),
#  ('information bottleneck', 15),
#  ('sparse pca', 15),
#  ('distance metric', 14),
#  ('reproducing kernel', 14),
#  ('dirichlet allocation', 14),
#  ('optimal algorithm', 14),
#  ('natural language', 14),
#  ('learning curve', 14),
#  ('learning linear', 14),
#  ('data set', 14),
#  ('linear programming', 14),
#  ('random walk', 14),
#  ('model human', 14),
#  ('model using', 14),
#  ('information theoretic', 14),
#  ('data analysis', 14),
#  ('learning theory', 14),
#  ('anomaly detection', 14),
#  ('learning gaussian', 14),
#  ('visual recognition', 14),
#  ('variance reduction', 14),
#  ('random forest', 14),
#  ('causal discovery', 13),
#  ('imitation learning', 13),
#  ('expectation propagation', 13),
#  ('network via', 13),
#  ('parameter estimation', 13),
#  ('manifold learning', 13),
#  ('temporal difference', 13),
#  ('optimization via', 13),
#  ('graph matching', 13),
#  ('sparse learning', 13),
#  ('inverse covariance', 13),
#  ('low rank', 13),
#  ('image segmentation', 13),
#  ('inverse reinforcement', 13),
#  ('model learning', 13),
#  ('optimal transport', 13),
#  ('maximum margin', 13),
#  ('neural model', 13),
#  ('efficient algorithm', 12),
#  ('learning stochastic', 12),
#  ('detection using', 12),
#  ('pattern recognition', 12),
#  ('question answering', 12),
#  ('unlabeled data', 12),
#  ('learning control', 12),
#  ('multilabel classification', 12),
#  ('spectral method', 12),
#  ('random feature', 12),
#  ('process prior', 12),
#  ('via convex', 12),
#  ('semidefinite programming', 12),
#  ('natural scene', 12),
#  ('using neural', 12),
#  ('connectionist model', 12),
#  ('clustering via', 12),
#  ('generalized linear', 12),
#  ('learning structured', 12),
#  ('sparse representation', 12),
#  ('gesture recognition', 12),
#  ('spectral learning', 12),
#  ('gradient algorithm', 12),
#  ('structured output', 12),
#  ('learning application', 12),
#  ('learning dynamic', 12),
#  ('tree search', 12),
#  ('distributed representation', 12),
#  ('local minimum', 12),
#  ('process mixture', 12),
#  ('kernel machine', 12),
#  ('sparse gaussian', 12),
#  ('high dimension', 12),
#  ('estimation using', 12),
#  ('representation learning', 12),
#  ('likelihood estimation', 12),
#  ('deep generative', 12),
#  ('generalization bound', 12),
#  ('structured sparsity', 11),
#  ('thompson sampling', 11),
#  ('subspace clustering', 11),
#  ('covariance estimation', 11),
#  ('mixture expert', 11),
#  ('contextual bandit', 11),
#  ('population code', 11),
#  ('spiking neural', 11),
#  ('learning latent', 11),
#  ('visual attention', 11),
#  ('information maximization', 11),
#  ('linear dynamical', 11),
#  ('submodular maximization', 11),
#  ('state space', 11),
#  ('learning rule', 11),
#  ('risk bound', 11),
#  ('action recognition', 11),
#  ('fast rate', 11),
#  ('nonparametric regression', 11),
#  ('blind source', 11),
#  ('hamiltonian monte', 11),
#  ('network spiking', 11),
#  ('robust pca', 11),
#  ('determinantal point', 11),
#  ('dimension reduction', 11),
#  ('training neural', 10),
#  ('differential equation', 10),
#  ('eye movement', 10),
#  ('block model', 10),
#  ('selection via', 10),
#  ('network application', 10),
#  ('matching pursuit', 10),
#  ('learning large', 10),
#  ('network structure', 10),
#  ('vlsi neural', 10),
#  ('variational bayes', 10),
#  ('neural code', 10),
#  ('side information', 10),
#  ('text classification', 10),
#  ('learning neural', 10),
#  ('distributed optimization', 10),
#  ('finite state', 10),
#  ('experimental design', 10),
#  ('learning continuous', 10),
#  ('sequential data', 10),
#  ('rate convergence', 10),
#  ('learning problem', 10),
#  ('descent method', 10),
#  ('ising model', 10),
#  ('multiple task', 10),
#  ('learning mixture', 10),
#  ('inference latent', 10),
#  ('algorithm learning', 10),
#  ('link prediction', 9),
#  ('boosting algorithm', 9),
#  ('hidden variable', 9),
#  ('hard thresholding', 9),
#  ('statistical learning', 9),
#  ('continuous speech', 9),
#  ('model visual', 9),
#  ('learning optimal', 9),
#  ('neighbor classification', 9),
#  ('language model', 9),
#  ('optimization problem', 9),
#  ('statistical analysis', 9),
#  ('tight bound', 9),
#  ('learning graph', 9),
#  ('ocular dominance', 9),
#  ('dictionary learning', 9),
#  ('case study', 9),
#  ('variational autoencoders', 9),
#  ('sparse inverse', 9),
#  ('sparse linear', 9),
#  ('regression classification', 9),
#  ('diffusion network', 9),
#  ('structural equation', 9),
#  ('regression via', 9),
#  ('feature space', 9),
#  ('bandit problem', 9),
#  ('face recognition', 9),
#  ('ridge regression', 9),
#  ('vlsi implementation', 9),
#  ('continuous time', 9),
#  ('incomplete data', 9),
#  ('inverse problem', 9),
#  ('using sparse', 9),
#  ('neural system', 9),
#  ('visual question', 9),
#  ('novelty detection', 9),
#  ('vector quantization', 9),
#  ('efficient online', 9),
#  ('analog neural', 9),
#  ('particle filter', 9),
#  ('using bayesian', 9),
#  ('kernel hilbert', 9),
#  ('value iteration', 9),
#  ('network classifier', 9),
#  ('community detection', 9),
#  ('learning nonlinear', 9),
#  ('deep convolutional', 9),
#  ('dynamic bayesian', 9),
#  ('selective attention', 9),
#  ('phase retrieval', 9),
#  ('matrix estimation', 9),
#  ('discriminative learning', 9),
#  ('higher order', 9),
#  ('social network', 9),
#  ('network learning', 9),
#  ('online optimization', 9),
#  ('learning efficient', 9),
#  ('stochastic block', 8),
#  ('algorithm online', 8),
#  ('metric space', 8),
#  ('linear convergence', 8),
#  ('hierarchical model', 8),
#  ('training set', 8),
#  ('system using', 8),
#  ('using deep', 8),
#  ('neuron model', 8),
#  ('estimation via', 8),
#  ('sequential monte', 8),
#  ('blind separation', 8),
#  ('lowrank tensor', 8),
#  ('barn owl', 8),
#  ('inference learning', 8),
#  ('efficient inference', 8),
#  ('binary classification', 8),
#  ('multilayer perceptrons', 8),
#  ('optimal control', 8),
#  ('online algorithm', 8),
#  ('free energy', 8),
#  ('phase transition', 8),
#  ('program synthesis', 8),
#  ('real time', 8),
#  ('regret minimization', 8),
#  ('alternating direction', 8),
#  ('hebbian learning', 8),
#  ('text categorization', 8),
#  ('multiple instance', 8),
#  ('analysis using', 8),
#  ('kernel regression', 8),
#  ('new algorithm', 8),
#  ('model application', 8),
#  ('multiagent reinforcement', 8),
#  ('recommender system', 8),
#  ('dimensional data', 8),
#  ('ensemble learning', 8),
#  ('learning visual', 8),
#  ('using random', 8),
#  ('langevin dynamic', 8),
#  ('stochastic learning', 8),
#  ('signal processing', 8),
#  ('gibbs sampling', 8),
#  ('mirror descent', 8),
#  ('bayesian approach', 8),
#  ('neural activity', 8),
#  ('difference learning', 8),
#  ('policy evaluation', 8),
#  ('single neuron', 8),
#  ('topic modeling', 8),
#  ('image representation', 8),
#  ('probability distribution', 8),
#  ('adaptive sampling', 8),
#  ('unsupervised feature', 8),
#  ('pose estimation', 8),
#  ('multilayer network', 8),
#  ('learning image', 8),
#  ('modelbased reinforcement', 8),
#  ('inference graphical', 8),
#  ('selection using', 8),
#  ('using local', 8),
#  ('learning decision', 8),
#  ('function network', 8),
#  ('highdimensional data', 8),
#  ('application neural', 8),
#  ('fast learning', 8),
#  ('fast algorithm', 8),
#  ('multiclass classification', 8),
#  ('process classification', 8),
#  ('network based', 8),
#  ('positive semidefinite', 7),
#  ('dantzig selector', 7),
#  ('direction method', 7),
#  ('decision problem', 7),
#  ('vector regression', 7),
#  ('compressed sensing', 7),
#  ('stochastic variational', 7),
#  ('learning network', 7),
#  ('approach learning', 7),
#  ('partial monitoring', 7),
#  ('recurrent model', 7),
#  ('complexity learning', 7),
#  ('information criterion', 7),
#  ('noise model', 7),
#  ('statistical mechanic', 7),
#  ('image using', 7),
#  ('feature model', 7),
#  ('sparse matrix', 7),
#  ('online convex', 7),
#  ('model neural', 7),
#  ('feedforward neural', 7),
#  ('block coordinate', 7),
#  ('roc curve', 7),
#  ('inference bayesian', 7),
#  ('data augmentation', 7),
#  ('multitask feature', 7),
#  ('optimization algorithm', 7),
#  ('computational model', 7),
#  ('learning probabilistic', 7),
#  ('optimal learning', 7),
#  ('learning method', 7),
#  ('efficient method', 7),
#  ('matrix decomposition', 7),
#  ('loopy belief', 7),
#  ('bayesian estimation', 7),
#  ('approximation algorithm', 7),
#  ('motor control', 7),
#  ('nonparametric model', 7),
#  ('distributionally robust', 7),
#  ('using gaussian', 7),
#  ('model based', 7),
#  ('genetic algorithm', 7),
#  ('stochastic approximation', 7),
#  ('complexity bound', 7),
#  ('screening rule', 7),
#  ('equation model', 7),
#  ('pca via', 7),
#  ('alternating minimization', 7),
#  ('singular value', 7),
#  ('neural spike', 7),
#  ('canonical correlation', 7),
#  ('factor graph', 7),
#  ('braincomputer interface', 7),
#  ('complex cell', 7),
#  ('subset selection', 7),
#  ('learning human', 7),
#  ('confidence interval', 7),
#  ('dynamic model', 7),
#  ('shortterm memory', 7),
#  ('proximal gradient', 7),
#  ('calcium imaging', 7),
#  ('buffet process', 7),
#  ('using hierarchical', 7),
#  ('selective sampling', 7),
#  ('learning without', 7),
#  ('method regularized', 7),
#  ('kernel principal', 7),
#  ('polynomial time', 7),
#  ('indian buffet', 7),
#  ('theoretical analysis', 7),
#  ('chain monte', 7),
#  ('causal structure', 7),
#  ('inner product', 7),
#  ('method sparse', 7),
#  ('matrix approximation', 7),
#  ('string kernel', 7),
#  ('learning causal', 7),
#  ('feature map', 7),
#  ('prior knowledge', 7),
#  ('orthogonal matching', 7),
#  ('outlier detection', 7),
#  ('sparse estimation', 7),
#  ('policy optimization', 7),
#  ('newton method', 7),
#  ('visual search', 7),
#  ('analysis via', 7),
#  ('greedy algorithm', 7),
#  ('deep belief', 7),
#  ('space model', 7),
#  ('correlation analysis', 7),
#  ('neural architecture', 6),
#  ('sparse regression', 6),
#  ('coordinate ascent', 6),
#  ('variance reduced', 6),
#  ('dependent plasticity', 6),
#  ('support recovery', 6),
#  ('learning partial', 6),
#  ('posterior sampling', 6),
#  ('general framework', 6),
#  ('linear function', 6),
#  ('learning distribution', 6),
#  ('rank minimization', 6),
#  ('hierarchical mixture', 6),
#  ('clustering application', 6),
#  ('agnostic active', 6),
#  ('matrix recovery', 6),
#  ('carlo method', 6),
#  ('inference continuous', 6),
#  ('multipleinstance learning', 6),
#  ('constraint satisfaction', 6),
#  ('prediction using', 6),
#  ('rbf network', 6),
#  ('method learning', 6),
#  ('analysis learning', 6),
#  ('graph representation', 6),
#  ('image compression', 6),
#  ('deep boltzmann', 6),
#  ('via adaptive', 6),
#  ('robust regression', 6),
#  ('learning function', 6),
#  ('expectation maximization', 6),
#  ('adversarial example', 6),
#  ('directed acyclic', 6),
#  ('regularization path', 6),
#  ('structured learning', 6),
#  ('sparse additive', 6),
#  ('clustering algorithm', 6),
#  ('primary visual', 6),
#  ('constrained optimization', 6),
#  ('instance learning', 6),
#  ('visual tracking', 6),
#  ('search via', 6),
#  ('hierarchical dirichlet', 6),
#  ('network classification', 6),
#  ('learning rank', 6),
#  ('rademacher complexity', 6),
#  ('learning hierarchical', 6),
#  ('pairwise comparison', 6),
#  ('hypothesis testing', 6),
#  ('causal graph', 6),
#  ('submodular minimization', 6),
#  ('pacbayes bound', 6),
#  ('inference via', 6),
#  ('representation using', 6),
#  ('sequential decision', 6),
#  ('face detection', 6),
#  ('algorithm sparse', 6),
#  ('dual averaging', 6),
#  ('attractor neural', 6),
#  ('bandit feedback', 6),
#  ('graph kernel', 6),
#  ('tree graphical', 6),
#  ('pattern classification', 6),
#  ('framework learning', 6),
#  ('hierarchical classification', 6),
#  ('spectral regularization', 6),
#  ('natural gradient', 6),
#  ('feedforward network', 6),
#  ('bayesian matrix', 6),
#  ('inference gaussian', 6),
#  ('bayesian method', 6),
#  ('time delay', 6),
#  ('multitask gaussian', 6),
#  ('stochastic variance', 6),
#  ('combinatorial optimization', 6),
#  ('series prediction', 6),
#  ('multiclass learning', 6),
#  ('relational data', 6),
#  ('empirical study', 6),
#  ('isotonic regression', 6),
#  ('markov blanket', 6),
#  ('data via', 6),
#  ('human motion', 6),
#  ('sparse bayesian', 6),
#  ('neural representation', 6),
#  ('linear time', 6),
#  ('network learns', 6),
#  ('actorcritic algorithm', 6),
#  ('covariance matrix', 6),
#  ('graph using', 6),
#  ('statistical inference', 6),
#  ('structure discovery', 6),
#  ('learning local', 6),
#  ('process bandit', 6),
#  ('convergence analysis', 6),
#  ('manifold regularization', 6),
#  ('gated recurrent', 6),
#  ('linear classification', 6),
#  ('information processing', 6),
#  ('observable markov', 6),
#  ('partition function', 6),
#  ('mixture gaussians', 6),
#  ('linear program', 6),
#  ('learning planning', 6),
#  ('vlsi model', 6),
#  ('visual motion', 6),
#  ('adaptive online', 6),
#  ('early stopping', 6),
#  ('model image', 6),
#  ('trace norm', 6),
#  ('learning hidden', 6),
#  ('norm regularization', 6),
#  ('neural response', 6),
#  ('diffusion process', 6),
#  ('motor learning', 6),
#  ('optimal neural', 6),
#  ('via gradient', 6),
#  ('fixed point', 6),
#  ('power method', 6),
#  ('statespace model', 6),
#  ('handwritten digit', 6),
#  ('predictive state', 6),
#  ('internal representation', 6),
#  ('linear response', 6),
#  ('model auditory', 6),
#  ('errorcorrecting code', 6),
#  ('factor model', 6),
#  ('labeled data', 6),
#  ('information retrieval', 6),
#  ('minimax optimal', 6),
#  ('highdimensional gaussian', 6),
#  ('bayesian framework', 6),
#  ('using multiple', 6),
#  ('multilabel learning', 6),
#  ('global optimization', 6),
#  ('regression using', 6),
#  ('error analysis', 6),
#  ('optimization method', 6),
#  ('sumproduct network', 6),
#  ('dual coordinate', 6),
#  ('latent structure', 6),
#  ('using convolutional', 6),
#  ('distributed learning', 6),
#  ('data clustering', 6),
#  ('computer vision', 6),
#  ('covariate shift', 5),
#  ('learning temporal', 5),
#  ('sparse recovery', 5),
#  ('temporaldifference learning', 5),
#  ('adversarial learning', 5),
#  ('sublinear time', 5),
#  ('conditional probability', 5),
#  ('partially labeled', 5),
#  ('algorithm application', 5),
#  ('brain computer', 5),
#  ('train data', 5),
#  ('human brain', 5),
#  ('theory algorithm', 5),
#  ('precision matrix', 5),
#  ('online linear', 5),
#  ('group sparse', 5),
#  ('partially observed', 5),
#  ('slice sampling', 5),
#  ('scene understanding', 5),
#  ('variational approach', 5),
#  ('prediction problem', 5),
#  ('learning trajectory', 5),
#  ('learning unknown', 5),
#  ('neural implementation', 5),
#  ('regularized kernel', 5),
#  ('linear system', 5),
#  ('svm training', 5),
#  ('machine translation', 5),
#  ('stein variational', 5),
#  ('shallow parsing', 5),
#  ('imagetoimage translation', 5),
#  ('sparse code', 5),
#  ('kernel based', 5),
#  ('compressive sensing', 5),
#  ('process dynamical', 5),
#  ('probability estimate', 5),
#  ('vestibuloocular reflex', 5),
#  ('back propagation', 5),
#  ('latent space', 5),
#  ('causal effect', 5),
#  ('latent gaussian', 5),
#  ('regression problem', 5),
#  ('false discovery', 5),
#  ('predictive model', 5),
#  ('learning feature', 5),
#  ('theoretic approach', 5),
#  ('noisy label', 5),
#  ('brain connectivity', 5),
#  ('probability estimation', 5),
#  ('graph clustering', 5),
#  ('learning halfspaces', 5),
#  ('learning tree', 5),
#  ('using optimal', 5),
#  ('regression application', 5),
#  ('observational data', 5),
#  ('using artificial', 5),
#  ('bayesian modeling', 5),
#  ('word embeddings', 5),
#  ('neural autoregressive', 5),
#  ('matrix inversion', 5),
#  ('multiclass boosting', 5),
#  ('function application', 5),
#  ('using mixture', 5),
#  ('efficient sampling', 5),
#  ('moment matching', 5),
#  ('learning game', 5),
#  ('finite sample', 5),
#  ('invariant feature', 5),
#  ('latent feature', 5),
#  ('probability measure', 5),
#  ('fast convergence', 5),
#  ('network analysis', 5),
#  ('group lasso', 5),
#  ('network dynamic', 5),
#  ('hidden unit', 5),
#  ('spike timing', 5),
#  ('bandit learning', 5),
#  ('gradient estimation', 5),
#  ('margin classifier', 5),
#  ('learning nonparametric', 5),
#  ('using kernel', 5),
#  ('image denoising', 5),
#  ('single image', 5),
#  ('decomposable submodular', 5),
#  ('nash equilibrium', 5),
#  ('additive noise', 5),
#  ('asynchronous parallel', 5),
#  ('programming approach', 5),
#  ('slow feature', 5),
#  ('sequence learning', 5),
#  ('inference using', 5),
#  ('accelerated gradient', 5),
#  ('estimation neural', 5),
#  ('approximate dynamic', 5),
#  ('tensor factorization', 5),
#  ('detection via', 5),
#  ('variational information', 5),
#  ('mechanism design', 5),
#  ('learning invariant', 5),
#  ('via linear', 5),
#  ('backpropagation network', 5),
#  ('learning computer', 5),
#  ('regression model', 5),
#  ('scalable algorithm', 5),
#  ('entropy discrimination', 5),
#  ('kmeans clustering', 5),
#  ('learning agent', 5),
#  ('kernel function', 5),
#  ('learning noisy', 5),
#  ('learning parameter', 5),
#  ('binary data', 5),
#  ('approximate policy', 5),
#  ('pac learning', 5),
#  ('learning markov', 5),
#  ('lowrank approximation', 5),
#  ('adversarial net', 5),
#  ('dynamical model', 5),
#  ('dynamic system', 5),
#  ('preference learning', 5),
#  ('optimal bayesian', 5),
#  ('selforganizing map', 5),
#  ('fast accurate', 5),
#  ('kernel feature', 5),
#  ('prediction market', 5),
#  ('online classification', 5),
#  ('global convergence', 5),
#  ('strong convexity', 5),
#  ('single trial', 5),
#  ('prior probability', 5),
#  ('spike data', 5),
#  ('uniform convergence', 5),
#  ('convex loss', 5),
#  ('kernel pca', 5),
#  ('character recognition', 5),
#  ('image region', 5),
#  ('minimax estimation', 5),
#  ('exponentiated gradient', 5),
#  ('variational approximation', 5),
#  ('via reinforcement', 5),
#  ('projection onto', 5),
#  ('prediction via', 5),
#  ('acyclic graph', 5),
#  ('sample compression', 5),
#  ('survival analysis', 5),
#  ('dynamic environment', 5),
#  ('learning recurrent', 5),
#  ('adaptive neural', 5),
#  ('continuous variable', 5),
#  ('twosample test', 5),
#  ('communicationefficient distributed', 5),
#  ('method neural', 5),
#  ('variational autoencoder', 5),
#  ('conditional gradient', 5),
#  ('classification ranking', 5),
#  ('bayesian policy', 5),
#  ('online prediction', 5),
#  ('stochastic bandit', 5),
#  ('kernel approximation', 5),
#  ('silicon retina', 5),
#  ('total variation', 5),
#  ('apprenticeship learning', 5),
#  ('neuronal network', 5),
#  ('learning bound', 5),
#  ('minimax rate', 5),
#  ('margin bound', 5),
#  ('model averaging', 5),
#  ('selective classification', 5),
#  ('theory practice', 5),
#  ('dueling bandit', 5),
#  ('optimal rate', 5),
#  ('synaptic plasticity', 5),
#  ('blind deconvolution', 5),
#  ('adaptive network', 5),
#  ('entropy estimation', 5),
#  ('montecarlo tree', 5),
#  ('multivariate regression', 5),
#  ('ranking using', 5),
#  ('gradient boosting', 5),
#  ('stochastic convex', 5),
#  ('kernel matrix', 5),
#  ('dynamic network', 5),
#  ('kernel fisher', 5),
#  ('learning machine', 5),
#  ('convex programming', 5),
#  ('natural actorcritic', 5),
#  ('structured sparse', 5),
#  ('inference neural', 5),
#  ('neural circuit', 5),
#  ('learning partially', 5),
#  ('majority vote', 5),
#  ('submodular cover', 5),
#  ('efficient neural', 5),
#  ('probabilistic modeling', 5),
#  ('exact inference', 5),
#  ('relational learning', 5),
#  ('multilayer neural', 5),
#  ('doubly stochastic', 5),
#  ('image restoration', 5),
#  ('optimization framework', 5),
#  ('inference structured', 5),
#  ('efficient coding', 5),
#  ('algorithm largescale', 5),
#  ('analysis distributed', 5),
#  ('loss minimization', 5),
#  ('carlo sampling', 5),
#  ('ideal observer', 5),
#  ('massive data', 5),
#  ('recognition system', 5),
#  ('decision list', 5),
#  ('approximate bayesian', 5),
#  ('feature analysis', 5),
#  ('classification pairwise', 5),
#  ('learning object', 5),
#  ('variational gaussian', 5),
#  ('via stochastic', 5),
#  ('multiple source', 5),
#  ('hawkes process', 5),
#  ('graph via', 5),
#  ('linear classifier', 5),
#  ('objective function', 5),
#  ('surrogate loss', 5),
#  ('method convex', 5),
#  ('sound localization', 5),
#  ('learning system', 5),
#  ('learning random', 5),
#  ('causal model', 5),
#  ('curve gaussian', 5),
#  ('saddle point', 5),
#  ('unsupervised domain', 5),
#  ('human visual', 5),
#  ('quantile regression', 5),
#  ('open source', 5),
#  ('via sequential', 5),
#  ('factorization machine', 5),
#  ('linear learning', 5),
#  ('streaming data', 5),
#  ('system identification', 5),
#  ('learning convex', 5),
#  ('approximation using', 5),
#  ('local learning', 5),
#  ('distributed stochastic', 5),
#  ('query complexity', 5),
#  ('process inference', 5),
#  ('divisive normalization', 5),
#  ('modeling human', 5),
#  ('discrete distribution', 5),
#  ('approximation method', 5),
#  ('distribution matching', 5),
#  ('bayesian sampling', 4),
#  ('index model', 4),
#  ('probabilistic grammar', 4),
#  ('sparsity constraint', 4),
#  ('probabilistic programming', 4),
#  ('forward model', 4),
#  ('robust optimization', 4),
#  ('statistical optimization', 4),
#  ('via truncated', 4),
#  ('statistic natural', 4),
#  ('backpropagation training', 4),
#  ('mixture gaussian', 4),
#  ('winnertakeall network', 4),
#  ('sparse graph', 4),
#  ('biologically plausible', 4),
#  ('restaurant process', 4),
#  ('concept learning', 4),
#  ('spiketimingdependent plasticity', 4),
#  ('selection bias', 4),
#  ('visual system', 4),
#  ('ranking pairwise', 4),
#  ('linear quadratic', 4),
#  ('product search', 4),
#  ('graph laplacian', 4),
#  ('method stochastic', 4),
#  ('maximum inner', 4),
#  ('label ranking', 4),
#  ('scalable inference', 4),
#  ('learning finite', 4),
#  ('upper bound', 4),
#  ('factored mdps', 4),
#  ('object segmentation', 4),
#  ('zeroshot learning', 4),
#  ('endtoend learning', 4),
#  ('fewshot learning', 4),
#  ('spike sorting', 4),
#  ('factorial learning', 4),
#  ('approximation learning', 4),
#  ('sparse principal', 4),
#  ('bregman divergence', 4),
#  ('algorithm linear', 4),
#  ('alzheimers disease', 4),
#  ('neuronal population', 4),
#  ('backpropagation algorithm', 4),
#  ('network flow', 4),
#  ('learning applied', 4),
#  ('learning recursive', 4),
#  ('logic programming', 4),
#  ('source localization', 4),
#  ('margin learning', 4),
#  ('digit recognition', 4),
#  ('classification method', 4),
#  ('machine classification', 4),
#  ('online variational', 4),
#  ('via deep', 4),
#  ('hyperparameter optimization', 4),
#  ('neuroimaging data', 4),
#  ('attractor network', 4),
#  ('algorithm stochastic', 4),
#  ('network image', 4),
#  ('safe reinforcement', 4),
#  ('algorithm neural', 4),
#  ('best arm', 4),
#  ('learning weakly', 4),
#  ('competitive learning', 4),
#  ('estimation discrete', 4),
#  ('nonparametric approach', 4),
#  ('local model', 4),
#  ('category learning', 4),
#  ('cone programming', 4),
#  ('learning adaptive', 4),
#  ('parallel stochastic', 4),
#  ('detection adversarial', 4),
#  ('unknown dynamic', 4),
#  ('estimation graphical', 4),
#  ('persistence diagram', 4),
#  ('wisdom crowd', 4),
#  ('particle filtering', 4),
#  ...]

# %% [markdown]
# # most popular triplets of words used in title

# %%
articles.title_freq(ngrams_lst=[3])
# Out:
# [('support vector machine', 73),
#  ('recurrent neural network', 50),
#  ('deep neural network', 43),
#  ('hidden markov model', 39),
#  ('convolutional neural network', 35),
#  ('gaussian process regression', 34),
#  ('markov decision process', 33),
#  ('latent variable model', 33),
#  ('principal component analysis', 26),
#  ('stochastic gradient descent', 25),
#  ('independent component analysis', 21),
#  ('empirical risk minimization', 20),
#  ('deep reinforcement learning', 20),
#  ('gaussian graphical model', 19),
#  ('restricted boltzmann machine', 17),
#  ('conditional random field', 17),
#  ('neural network model', 16),
#  ('markov random field', 16),
#  ('radial basis function', 16),
#  ('artificial neural network', 14),
#  ('nonnegative matrix factorization', 14),
#  ('latent dirichlet allocation', 14),
#  ('generative adversarial network', 13),
#  ('multiple kernel learning', 13),
#  ('learning bayesian network', 12),
#  ('inverse reinforcement learning', 12),
#  ('maximum likelihood estimation', 12),
#  ('value function approximation', 11),
#  ('dirichlet process mixture', 11),
#  ('blind source separation', 11),
#  ('hamiltonian monte carlo', 11),
#  ('network spiking neuron', 11),
#  ('determinantal point process', 11),
#  ('training neural network', 10),
#  ('vlsi neural network', 10),
#  ('linear dynamical system', 10),
#  ('visual question answering', 9),
#  ('kernel hilbert space', 9),
#  ('learning multiple task', 9),
#  ('gaussian process model', 9),
#  ('using neural network', 9),
#  ('inverse covariance estimation', 9),
#  ('continuous speech recognition', 9),
#  ('reproducing kernel hilbert', 9),
#  ('sparse inverse covariance', 9),
#  ('training deep neural', 9),
#  ('sparse gaussian process', 9),
#  ('stochastic gradient method', 9),
#  ('dynamic bayesian network', 8),
#  ('gaussian process classification', 8),
#  ('inference graphical model', 8),
#  ('generalized linear model', 8),
#  ('modelbased reinforcement learning', 8),
#  ('deep generative model', 8),
#  ('learning gaussian process', 8),
#  ('multiagent reinforcement learning', 8),
#  ('sequential monte carlo', 8),
#  ('nearest neighbor classification', 8),
#  ('basis function network', 8),
#  ('temporal difference learning', 8),
#  ('stochastic block model', 8),
#  ('distance metric learning', 8),
#  ('feedforward neural network', 7),
#  ('loopy belief propagation', 7),
#  ('learning latent variable', 7),
#  ('reinforcement learning using', 7),
#  ('high dimensional data', 7),
#  ('support vector regression', 7),
#  ('indian buffet process', 7),
#  ('kernel principal component', 7),
#  ('spiking neural network', 7),
#  ('orthogonal matching pursuit', 7),
#  ('markov chain monte', 7),
#  ('chain monte carlo', 7),
#  ('structural equation model', 7),
#  ('hierarchical dirichlet process', 6),
#  ('gaussian process prior', 6),
#  ('attractor neural network', 6),
#  ('alternating direction method', 6),
#  ('bayesian matrix factorization', 6),
#  ('multitask feature learning', 6),
#  ('neural network based', 6),
#  ('state space model', 6),
#  ('online convex optimization', 6),
#  ('graphical model selection', 6),
#  ('canonical correlation analysis', 6),
#  ('learning neural network', 6),
#  ('neural network classifier', 6),
#  ('machine learning approach', 6),
#  ('multitask gaussian process', 6),
#  ('gaussian mixture model', 6),
#  ('stochastic variational inference', 6),
#  ('lowrank matrix completion', 6),
#  ('3d object recognition', 6),
#  ('neural network via', 6),
#  ('observable markov decision', 6),
#  ('time series prediction', 6),
#  ('learning function approximation', 6),
#  ('primary visual cortex', 6),
#  ('partially observable markov', 6),
#  ('monte carlo method', 6),
#  ('tree graphical model', 6),
#  ('deep boltzmann machine', 6),
#  ('reinforcement learning via', 6),
#  ('multiple instance learning', 6),
#  ('online learning via', 6),
#  ('training deep network', 6),
#  ('generalization error bound', 6),
#  ('bayesian network structure', 6),
#  ('multilayer neural network', 5),
#  ('neural network application', 5),
#  ('bayesian nonparametric model', 5),
#  ('directed acyclic graph', 5),
#  ('decomposable submodular function', 5),
#  ('active learning algorithm', 5),
#  ('information theoretic approach', 5),
#  ('gaussian process dynamical', 5),
#  ('using gaussian process', 5),
#  ('stochastic convex optimization', 5),
#  ('gaussian process bandit', 5),
#  ('spike train data', 5),
#  ('graphical model via', 5),
#  ('monte carlo sampling', 5),
#  ('coordinate descent method', 5),
#  ('analog vlsi neural', 5),
#  ('montecarlo tree search', 5),
#  ('using artificial neural', 5),
#  ('speech recognition using', 5),
#  ('process mixture model', 5),
#  ('generative adversarial net', 5),
#  ('analog vlsi model', 5),
#  ('approximate dynamic programming', 5),
#  ('curve gaussian process', 5),
#  ('point process model', 5),
#  ('analog neural network', 5),
#  ('additive noise model', 5),
#  ('via reinforcement learning', 5),
#  ('agnostic active learning', 5),
#  ('learning curve gaussian', 5),
#  ('dual coordinate ascent', 5),
#  ('via convex optimization', 5),
#  ('neural network using', 5),
#  ('maximum entropy discrimination', 5),
#  ('online learning algorithm', 5),
#  ('using random projection', 4),
#  ('inner product search', 4),
#  ('anomaly detection using', 4),
#  ('speech recognition system', 4),
#  ('minimax probability machine', 4),
#  ('neural network chip', 4),
#  ('fast similarity search', 4),
#  ('area roc curve', 4),
#  ('adaptive online learning', 4),
#  ('gradient langevin dynamic', 4),
#  ('submodular function minimization', 4),
#  ('temporal restricted boltzmann', 4),
#  ('linear support vector', 4),
#  ('singular value decomposition', 4),
#  ('using reinforcement learning', 4),
#  ('algorithm neural network', 4),
#  ('nonlinear dimensionality reduction', 4),
#  ('positive semidefinite matrix', 4),
#  ('undirected graphical model', 4),
#  ('network structure learning', 4),
#  ('variational inference bayesian', 4),
#  ('kernel ridge regression', 4),
#  ('factorial hidden markov', 4),
#  ('multitask reinforcement learning', 4),
#  ('auditory scene analysis', 4),
#  ('partially observable environment', 4),
#  ('chinese restaurant process', 4),
#  ('kernel learning algorithm', 4),
#  ('safe screening rule', 4),
#  ('structural risk minimization', 4),
#  ('gaussian process inference', 4),
#  ('direction method multiplier', 4),
#  ('hierarchical reinforcement learning', 4),
#  ('single trial eeg', 4),
#  ('estimation high dimensional', 4),
#  ('support vector method', 4),
#  ('block coordinate descent', 4),
#  ('nearest neighbor algorithm', 4),
#  ('false discovery rate', 4),
#  ('neural network regression', 4),
#  ('variational gaussian process', 4),
#  ('markov decision problem', 4),
#  ('fisher discriminant analysis', 4),
#  ('sample complexity learning', 4),
#  ('multioutput gaussian process', 4),
#  ('process latent variable', 4),
#  ('accelerated gradient method', 4),
#  ('hierarchical mixture expert', 4),
#  ('slow feature analysis', 4),
#  ('best arm identification', 4),
#  ('estimation graphical model', 4),
#  ('stochastic gradient langevin', 4),
#  ('matrix completion noisy', 4),
#  ('local differential privacy', 4),
#  ('causal structure learning', 4),
#  ('dual averaging method', 4),
#  ('policy gradient method', 4),
#  ('mixture gaussian process', 4),
#  ('using support vector', 4),
#  ('linear function approximation', 4),
#  ('inference latent dirichlet', 4),
#  ('sparse principal component', 4),
#  ('feature selection via', 4),
#  ('process dynamical system', 4),
#  ('stein variational gradient', 4),
#  ('optimal learning rate', 4),
#  ('supervised topic model', 4),
#  ('variational bayesian learning', 4),
#  ('deep convolutional neural', 4),
#  ('competitive neural network', 4),
#  ('latent feature model', 4),
#  ('robust principal component', 4),
#  ('finite state machine', 4),
#  ('via adaptive sampling', 4),
#  ('ocular dominance column', 4),
#  ('via convex programming', 4),
#  ('learning deep generative', 4),
#  ('safe reinforcement learning', 4),
#  ('nonparametric bayesian model', 4),
#  ('variational gradient descent', 4),
#  ('spiketiming dependent plasticity', 4),
#  ('generalization neural network', 4),
#  ('robust pca via', 4),
#  ('large margin learning', 4),
#  ('dirichlet process prior', 4),
#  ('kernel density estimation', 4),
#  ('maximum inner product', 4),
#  ('probabilistic graphical model', 4),
#  ('unsupervised domain adaptation', 4),
#  ('kernel twosample test', 3),
#  ('analog vlsi chip', 3),
#  ('network binary weight', 3),
#  ('feature extraction using', 3),
#  ('correction approximate inference', 3),
#  ('variance reduction stochastic', 3),
#  ('convex relaxation sparse', 3),
#  ('neural information processing', 3),
#  ('learning partially observable', 3),
#  ('based reinforcement learning', 3),
#  ('time sample complexity', 3),
#  ('completion noisy entry', 3),
#  ('feature selection classification', 3),
#  ('online reinforcement learning', 3),
#  ('classification pairwise coupling', 3),
#  ('training support vector', 3),
#  ('machine learning research', 3),
#  ('variational message passing', 3),
#  ('optimal algorithm crowdsourcing', 3),
#  ('inference latent variable', 3),
#  ('approximate gaussian process', 3),
#  ('handwritten digit recognition', 3),
#  ('time series classification', 3),
#  ('margin semisupervised learning', 3),
#  ('finite state automaton', 3),
#  ('neural network time', 3),
#  ('learning algorithm neural', 3),
#  ('constraint satisfaction problem', 3),
#  ('neural network learns', 3),
#  ('sparse additive model', 3),
#  ('learning decision list', 3),
#  ('brain computer interface', 3),
#  ('selection support vector', 3),
#  ('temporally asymmetric hebbian', 3),
#  ('inference determinantal point', 3),
#  ('robust markov decision', 3),
#  ('regularized kernel method', 3),
#  ('chordal markov network', 3),
#  ('using dirichlet process', 3),
#  ('least square regression', 3),
#  ('time series using', 3),
#  ('neural network learn', 3),
#  ('reinforcement learning algorithm', 3),
#  ('via stein lemma', 3),
#  ('learning restricted training', 3),
#  ('gaussian process approximation', 3),
#  ('neural network control', 3),
#  ('via semidefinite programming', 3),
#  ('online variational inference', 3),
#  ('exploration multiarmed bandit', 3),
#  ('multiclass support vector', 3),
#  ('model sequential data', 3),
#  ('structure learning bayesian', 3),
#  ('latent gaussian model', 3),
#  ('approximate policy iteration', 3),
#  ('principal component regression', 3),
#  ('face recognition using', 3),
#  ('topological data analysis', 3),
#  ('optimization machine learning', 3),
#  ('exponential family pca', 3),
#  ('learning sparse representation', 3),
#  ('lowrank tensor regression', 3),
#  ('differential dynamic programming', 3),
#  ('nearest neighbor search', 3),
#  ('probabilistic lowrank matrix', 3),
#  ('semisupervised support vector', 3),
#  ('holistic scene understanding', 3),
#  ('reduction stochastic gradient', 3),
#  ('speech motor control', 3),
#  ('machine learning algorithm', 3),
#  ('approximation gaussian process', 3),
#  ('order cone programming', 3),
#  ('learning multiple kernel', 3),
#  ('regularized empirical risk', 3),
#  ('bayesian network using', 3),
#  ('vector machine classification', 3),
#  ('stochastic neural network', 3),
#  ('fast svm training', 3),
#  ('method machine learning', 3),
#  ('saccadic eye movement', 3),
#  ('convex risk minimization', 3),
#  ('single index model', 3),
#  ('bayesian model selection', 3),
#  ('nonsmooth nonconvex optimization', 3),
#  ('bayesian inference posterior', 3),
#  ('reinforcement learning continuous', 3),
#  ('markov jump process', 3),
#  ('neural population code', 3),
#  ('predictive state representation', 3),
#  ('informationtheoretic lower bound', 3),
#  ('gaussian process method', 3),
#  ('auction strategic buyer', 3),
#  ('stochastic variance reduced', 3),
#  ('gaussian bayesian network', 3),
#  ('dynamic social network', 3),
#  ('confidence interval hypothesis', 3),
#  ('discrete graphical model', 3),
#  ('combinatorial multiarmed bandit', 3),
#  ('local metric learning', 3),
#  ('leverage score sampling', 3),
#  ('gaussian process expert', 3),
#  ('boosting decision tree', 3),
#  ('finite training set', 3),
#  ('variational bayesian inference', 3),
#  ('model visual attention', 3),
#  ('black box variational', 3),
#  ('second order cone', 3),
#  ('high dimensional linear', 3),
#  ('map inference graphical', 3),
#  ('data analysis using', 3),
#  ('neural network approach', 3),
#  ('gaussian process kernel', 3),
#  ('sparse pca via', 3),
#  ('large data set', 3),
#  ('comparison neural network', 3),
#  ('robust speech recognition', 3),
#  ('process regression large', 3),
#  ('maxmargin markov network', 3),
#  ('sample complexity bound', 3),
#  ('optimization online learning', 3),
#  ('structured output prediction', 3),
#  ('mixture model via', 3),
#  ('linear discriminant analysis', 3),
#  ('tensor decomposition via', 3),
#  ('low rank matrix', 3),
#  ('neural network training', 3),
#  ('neural network analysis', 3),
#  ('deep belief net', 3),
#  ('policy search via', 3),
#  ('function approximation using', 3),
#  ('adversarial imitation learning', 3),
#  ('method convex optimization', 3),
#  ('online learning kernel', 3),
#  ('nonlinear system identification', 3),
#  ('mean field theory', 3),
#  ('adaptive nearest neighbor', 3),
#  ('high dimensional variable', 3),
#  ('reinforcement learning approach', 3),
#  ('adaptive importance sampling', 3),
#  ('error bound condition', 3),
#  ('clustering hidden markov', 3),
#  ('electronic neural network', 3),
#  ('learning computer vision', 3),
#  ('neural spike train', 3),
#  ('learning chordal markov', 3),
#  ('kernel feature space', 3),
#  ('maximum margin clustering', 3),
#  ('motivated reinforcement learning', 3),
#  ('optimal brain surgeon', 3),
#  ('optimal sample complexity', 3),
#  ('associative memory function', 3),
#  ('discrete bayesian network', 3),
#  ('greedy coordinate descent', 3),
#  ('neural network implementation', 3),
#  ('integrated segmentation recognition', 3),
#  ('sparse linear regression', 3),
#  ('bayesian reinforcement learning', 3),
#  ('structured output learning', 3),
#  ('deep kernel learning', 3),
#  ('crowdsourced labeling task', 3),
#  ('automatic speech recognition', 3),
#  ('averaging method regularized', 3),
#  ('stochastic variance reduction', 3),
#  ('efficient reinforcement learning', 3),
#  ('collaborative pac learning', 3),
#  ('sparse online learning', 3),
#  ('adaptive neural network', 3),
#  ('support vector learning', 3),
#  ('stochastic dual coordinate', 3),
#  ('gradient descent learning', 3),
#  ('convolutional sparse coding', 3),
#  ('sparse bayesian learning', 3),
#  ('nonparametric hidden markov', 3),
#  ('gap safe screening', 3),
#  ('multivariate time series', 3),
#  ('set covering machine', 3),
#  ('neural machine translation', 3),
#  ('dependent dirichlet process', 3),
#  ('lifted map inference', 3),
#  ('restricted training set', 3),
#  ('inverse covariance matrix', 3),
#  ('deep learning model', 3),
#  ('efficient high dimensional', 3),
#  ('bayesian network classifier', 3),
#  ('switching linear dynamical', 3),
#  ('unsupervised feature learning', 3),
#  ('continuoustime diffusion network', 3),
#  ('memorybased reinforcement learning', 3),
#  ('large scale online', 3),
#  ('langevin monte carlo', 3),
#  ('learning vector quantization', 3),
#  ('method regularized empirical', 3),
#  ('support vector classification', 3),
#  ('message passing inference', 3),
#  ('inference gaussian process', 3),
#  ('reinforcement learning agent', 3),
#  ('stochastic gradient mcmc', 3),
#  ('deep belief network', 3),
#  ('calcium imaging data', 3),
#  ('multidimensional recurrent neural', 3),
#  ('deep recurrent neural', 3),
#  ('process bandit optimization', 3),
#  ('learning graphical model', 3),
#  ('sample selection bias', 3),
#  ('optimal bayesian network', 3),
#  ('semisupervised learning using', 3),
#  ('constrained gaussian process', 3),
#  ('method neural network', 3),
#  ('sigmoid belief network', 3),
#  ('algorithm partially observable', 3),
#  ('natural image using', 3),
#  ('proximal gradient method', 3),
#  ('approximate message passing', 3),
#  ('multimodal gesture recognition', 3),
#  ('mean field variational', 3),
#  ('visual speech recognition', 3),
#  ('generative adversarial imitation', 3),
#  ('object recognition using', 3),
#  ('neural autoregressive distribution', 3),
#  ('early visual processing', 3),
#  ('neural population activity', 3),
#  ('nonlinear dynamical system', 3),
#  ('variational bayesian matrix', 3),
#  ('algorithm statistical optimization', 3),
#  ('regularized least square', 3),
#  ('cur matrix decomposition', 3),
#  ('based neural network', 3),
#  ('unsupervised feature selection', 3),
#  ('box variational inference', 3),
#  ('online linear regression', 3),
#  ('nonparametric bayesian inference', 3),
#  ('learning ising model', 3),
#  ('model speech recognition', 3),
#  ('learning causal graph', 3),
#  ('maximum entropy model', 3),
#  ('fast learning rate', 3),
#  ('deep gaussian process', 3),
#  ('bethe free energy', 2),
#  ('scale online learning', 2),
#  ('collapsed variational bayes', 2),
#  ('minimax optimal algorithm', 2),
#  ('latent tree graphical', 2),
#  ('vector machine fast', 2),
#  ('function neural network', 2),
#  ('finite state controller', 2),
#  ('ranking using seriation', 2),
#  ('switching cost adaptive', 2),
#  ('blanket induction causal', 2),
#  ('guided policy search', 2),
#  ('complexity neural network', 2),
#  ('unsupervised learning object', 2),
#  ('linear neural network', 2),
#  ('stochastic kinetic model', 2),
#  ('time bayesian network', 2),
#  ('hierarchical bayesian inference', 2),
#  ('learning online optimization', 2),
#  ('convex calibrated surrogate', 2),
#  ('causal markov blanket', 2),
#  ('deep poisson factor', 2),
#  ('hard thresholding pursuit', 2),
#  ('multinomial logistic regression', 2),
#  ('density ratio estimation', 2),
#  ('environment limited experiment', 2),
#  ('large spatial data', 2),
#  ('private empirical risk', 2),
#  ('multiple environment limited', 2),
#  ('reinforcement learning multiple', 2),
#  ('planning large pomdps', 2),
#  ('pacbayes risk bound', 2),
#  ('neural network structured', 2),
#  ('natural actorcritic algorithm', 2),
#  ('update online learning', 2),
#  ('graph convolutional network', 2),
#  ('nonstationary dynamic bayesian', 2),
#  ('entire regularization path', 2),
#  ('human motor learning', 2),
#  ('working set selection', 2),
#  ('learning symbolic representation', 2),
#  ('object class detection', 2),
#  ('proximal gradient descent', 2),
#  ('multiple task using', 2),
#  ('line search stochastic', 2),
#  ('spikeandslab sparse coding', 2),
#  ('exponentiated gradient algorithm', 2),
#  ('random field highorder', 2),
#  ('cardiovascular event using', 2),
#  ('property natural image', 2),
#  ('delay neural network', 2),
#  ('estimation neural network', 2),
#  ('relevance vector machine', 2),
#  ('implicit bias gradient', 2),
#  ('independent cascade model', 2),
#  ('inductive logic programming', 2),
#  ('bias multiarmed bandit', 2),
#  ('treewidth bayesian network', 2),
#  ('reinforcement learning efficient', 2),
#  ('augmented lagrangian algorithm', 2),
#  ('multiple reward function', 2),
#  ('learning deep boltzmann', 2),
#  ('selforganizing feature map', 2),
#  ('expectation propagation gaussian', 2),
#  ('characterization family solution', 2),
#  ('bound area roc', 2),
#  ('neural spike data', 2),
#  ('algorithm recurrent neural', 2),
#  ('new approximate maximal', 2),
#  ('spectral regularization algorithm', 2),
#  ('using monte carlo', 2),
#  ('dynamic mode decomposition', 2),
#  ('predictive uncertainty estimation', 2),
#  ('algorithm asynchronous distributed', 2),
#  ('using convolutional neural', 2),
#  ('latent class model', 2),
#  ('interaction network learning', 2),
#  ('core vector machine', 2),
#  ('automated machine learning', 2),
#  ('modeling partially ranked', 2),
#  ('classification using string', 2),
#  ('learning nearest neighbor', 2),
#  ('stochastic neighbor embedding', 2),
#  ('communicationefficient algorithm statistical', 2),
#  ('growing cell structure', 2),
#  ('finite sum optimization', 2),
#  ('belief propagation gaussian', 2),
#  ('learning nonlinear dynamical', 2),
#  ('lowrank matrix approximation', 2),
#  ('problem neural network', 2),
#  ('pairwise preference almost', 2),
#  ('power method sparse', 2),
#  ('margin supervised topic', 2),
#  ('using independent component', 2),
#  ('mahalanobis distance metric', 2),
#  ('online passiveaggressive algorithm', 2),
#  ('complexity empirical risk', 2),
#  ('using kernel method', 2),
#  ('topic model identifiable', 2),
#  ('pruning deep neural', 2),
#  ('gesture recognition using', 2),
#  ('via linear programming', 2),
#  ('neural network recognize', 2),
#  ('extreme multilabel classification', 2),
#  ('unsupervised feature extraction', 2),
#  ('analogue vlsi neural', 2),
#  ('large margin classification', 2),
#  ('stationary time series', 2),
#  ('dimensional variable selection', 2),
#  ('natural scene edge', 2),
#  ('learning via truncated', 2),
#  ('distributionally robust optimization', 2),
#  ('kanervas sparse distributed', 2),
#  ('convex loss function', 2),
#  ('learning algorithm recurrent', 2),
#  ('recursive neural network', 2),
#  ('screening rule sparse', 2),
#  ('global analytic solution', 2),
#  ('neural network bayesian', 2),
#  ('ideal observer model', 2),
#  ('machine learning toolkit', 2),
#  ('efficient anomaly detection', 2),
#  ('warped gaussian process', 2),
#  ('reinforcement learning stochastic', 2),
#  ('estimation gradient line', 2),
#  ('online batch learning', 2),
#  ('data neural network', 2),
#  ('conditional random sampling', 2),
#  ('positive definite matrix', 2),
#  ('local rademacher complexity', 2),
#  ('selection classification part', 2),
#  ('method reinforcement learning', 2),
#  ('model auditory scene', 2),
#  ('efficient coding natural', 2),
#  ('monte carlo tree', 2),
#  ('neural language model', 2),
#  ('stochastic optimization via', 2),
#  ('gradient descent general', 2),
#  ('learning algorithm partially', 2),
#  ('escaping saddle point', 2),
#  ('recognition neural net', 2),
#  ('simple decision heuristic', 2),
#  ('embedding cooccurrence data', 2),
#  ('neural network nonlinear', 2),
#  ('multistage multitask feature', 2),
#  ('algorithm robust pca', 2),
#  ('generalized dantzig selector', 2),
#  ('detection neural network', 2),
#  ('stochastic neuron model', 2),
#  ('dimensionality recovery variational', 2),
#  ('double nothing multiplicative', 2),
#  ('ultrahigh dimensional feature', 2),
#  ('using belief propagation', 2),
#  ('model human action', 2),
#  ('learning image segmentation', 2),
#  ('probabilistically triggered arm', 2),
#  ('learning sparse image', 2),
#  ('learning nonparametric mixture', 2),
#  ('stochastic control problem', 2),
#  ('anomaly detection via', 2),
#  ('magnetic resonance image', 2),
#  ('supervised learning restricted', 2),
#  ('step size adaptation', 2),
#  ('reinforcement learning model', 2),
#  ('approximate inference layered', 2),
#  ('computation heading direction', 2),
#  ('bayesian policy gradient', 2),
#  ('online learning bregman', 2),
#  ('sequential decision making', 2),
#  ('nonlinear blind source', 2),
#  ('dynamic neural network', 2),
#  ('group sparse coding', 2),
#  ('semidefinite metric learning', 2),
#  ('accelerating stochastic composition', 2),
#  ('analysis semisupervised learning', 2),
#  ('overcomplete topic model', 2),
#  ('nongaussian structural equation', 2),
#  ('vertex nomination scheme', 2),
#  ('binary gaussian process', 2),
#  ('continuous attractor neural', 2),
#  ('inference neural activity', 2),
#  ('multiparty differential privacy', 2),
#  ('analysis competing risk', 2),
#  ('large deviation bound', 2),
#  ('fast alternating least', 2),
#  ('learning gaussian graphical', 2),
#  ('regeneration eyebrain map', 2),
#  ('extremal mechanism local', 2),
#  ('estimating conditional probability', 2),
#  ('image restoration using', 2),
#  ('planar ising model', 2),
#  ('greedy importance sampling', 2),
#  ('process regression random', 2),
#  ('regularized loss minimization', 2),
#  ('classifier multiple data', 2),
#  ('learning radial basis', 2),
#  ('regularized optimal transport', 2),
#  ('penalized least square', 2),
#  ('magnetic resonance imaging', 2),
#  ('efficient global optimization', 2),
#  ('representation barn owl', 2),
#  ('distributed machine learning', 2),
#  ('nonlinear support vector', 2),
#  ('clustering signed network', 2),
#  ('gated recurrent unit', 2),
#  ('transductive support vector', 2),
#  ('gradient descent linear', 2),
#  ('optical character recognition', 2),
#  ('nearest neighbor based', 2),
#  ('hidden semimarkov model', 2),
#  ('metric learning large', 2),
#  ('large margin semisupervised', 2),
#  ('algorithm sparse learning', 2),
#  ('tandem mass spectrum', 2),
#  ('via supervised learning', 2),
#  ('clustered multitask learning', 2),
#  ('without learning rate', 2),
#  ('recognition using neural', 2),
#  ('using radial basis', 2),
#  ('fast gaussian process', 2),
#  ('kernel kmeans clustering', 2),
#  ('partially labeled data', 2),
#  ('using pairwise comparison', 2),
#  ('gradient descent gradient', 2),
#  ('modeling nesterovs accelerated', 2),
#  ('algorithm large scale', 2),
#  ('learning minimum volume', 2),
#  ('prior probability shift', 2),
#  ('hardness result parallel', 2),
#  ('knowledgebased neural network', 2),
#  ('optimization decision tree', 2),
#  ('learning program synthesis', 2),
#  ('sparse lowrank tensor', 2),
#  ('recursive teaching dimension', 2),
#  ('sensitive silicon retina', 2),
#  ('policy gradient algorithm', 2),
#  ('efficient convolutional neural', 2),
#  ('set interpretable classification', 2),
#  ('markov blanket induction', 2),
#  ('protein classification using', 2),
#  ('rate active learning', 2),
#  ('mestimators nonconvexity statistical', 2),
#  ('kernel bayes rule', 2),
#  ('network thousand variable', 2),
#  ('network conventional pattern', 2),
#  ('neural network learning', 2),
#  ('learning dynamic environment', 2),
#  ('prediction graph autoregressive', 2),
#  ('sparse linear model', 2),
#  ('distributed variational inference', 2),
#  ('bayesian monte carlo', 2),
#  ('random spanning tree', 2),
#  ('predictive representation state', 2),
#  ('learning graph based', 2),
#  ('via deep learning', 2),
#  ('dyadic classification tree', 2),
#  ('structured sparse regression', 2),
#  ('communicationefficient distributed optimization', 2),
#  ('completely random measure', 2),
#  ('model biological neuron', 2),
#  ('online portfolio selection', 2),
#  ('spam filtering based', 2),
#  ('algorithm latent dirichlet', 2),
#  ('application blind source', 2),
#  ('nonparametric density estimation', 2),
#  ('local kernel machine', 2),
#  ('online mechanism design', 2),
#  ('parallel large margin', 2),
#  ('large scale distributed', 2),
#  ('deep convolutional representation', 2),
#  ('spatial representation parietal', 2),
#  ('cumulative distribution network', 2),
#  ('method regularized stochastic', 2),
#  ('analysis thompson sampling', 2),
#  ('general stochastic block', 2),
#  ('minimization structured prediction', 2),
#  ('halfspaces malicious noise', 2),
#  ('statistical comparison classifier', 2),
#  ('efficient multiple kernel', 2),
#  ('learning partial label', 2),
#  ('machine learning applied', 2),
#  ('solution fullyobserved variational', 2),
#  ('mean field annealing', 2),
#  ('bayesian inference learning', 2),
#  ('maximal margin classification', 2),
#  ('operatorvalued kernel learning', 2),
#  ('reinforcement learning dynamic', 2),
#  ('statistical topological data', 2),
#  ('mutual information estimation', 2),
#  ('conditional mutual information', 2),
#  ('coordinate descent algorithm', 2),
#  ('communicationefficient distributed learning', 2),
#  ('general reinforcement learning', 2),
#  ('multiclass object detection', 2),
#  ('graphical lasso thresholding', 2),
#  ('algorithm community detection', 2),
#  ('motor imagery braincomputer', 2),
#  ('receptive field deep', 2),
#  ('variance kfold crossvalidation', 2),
#  ('gated recurrent neural', 2),
#  ('model neural network', 2),
#  ('spiking neuron model', 2),
#  ('lowrank matrix recovery', 2),
#  ('improved move truncated', 2),
#  ('carlo tree search', 2),
#  ('minimum description length', 2),
#  ('model correlated error', 2),
#  ('reinforcement learning factored', 2),
#  ('quadratic system equation', 2),
#  ('stochastic gradient algorithm', 2),
#  ('continuoustime bayesian network', 2),
#  ('conditional image generation', 2),
#  ('matrix rank minimization', 2),
#  ('information theoretic measure', 2),
#  ('regularization path support', 2),
#  ('bayesian deep learning', 2),
#  ('precision matrix estimation', 2),
#  ('sparse blind deconvolution', 2),
#  ('correcting sample selection', 2),
#  ('optimal transport metric', 2),
#  ('learning deep neural', 2),
#  ('spiketriggered covariance analysis', 2),
#  ('blind signal separation', 2),
#  ('model auditory streaming', 2),
#  ('linearly constrained gaussian', 2),
#  ('efficient robust feature', 2),
#  ('multiarmed bandit problem', 2),
#  ('policy iteration algorithm', 2),
#  ('semiparametric exponential family', 2),
#  ('multiplicative multitask feature', 2),
#  ('family graphical model', 2),
#  ('joint sparsity constraint', 2),
#  ('clustering bregman divergence', 2),
#  ('spike timingdependent plasticity', 2),
#  ('highdimensional graphical model', 2),
#  ('time series forecasting', 2),
#  ('active nearestneighbor learning', 2),
#  ('probabilistic population code', 2),
#  ('data large margin', 2),
#  ('constraint set regularity', 2),
#  ('regression application neural', 2),
#  ('occlusive component analysis', 2),
#  ('partially labeled classification', 2),
#  ('1norm support vector', 2),
#  ('trace norm regularization', 2),
#  ('fast mcmc sampling', 2),
#  ('protein structure prediction', 2),
#  ('generalized binary search', 2),
#  ('method meet em', 2),
#  ('multilabel prediction via', 2),
#  ('variance reduced gradient', 2),
#  ('structure continuous variable', 2),
#  ('lateral geniculate nucleus', 2),
#  ('representation parietal cortex', 2),
#  ('model selection application', 2),
#  ('map inference determinantal', 2),
#  ('multistate time delay', 2),
#  ('exact stable recovery', 2),
#  ('using simultaneous projection', 2),
#  ('screening rule via', 2),
#  ('recurrent temporal restricted', 2),
#  ('intransitive likelihoodratio classifier', 2),
#  ('approximate newton method', 2),
#  ('modeling gaussian process', 2),
#  ('via spectral filtering', 2),
#  ('matrix factorization using', 2),
#  ('active learning misspecified', 2),
#  ('method sparse inverse', 2),
#  ('shallow parsing using', 2),
#  ('path support vector', 2),
#  ('analysis deep network', 2),
#  ('human pose estimation', 2),
#  ('microarray expression data', 2),
#  ('nothing multiplicative incentive', 2),
#  ('reinforcement learning partially', 2),
#  ('application neural network', 2),
#  ('model human motor', 2),
#  ('following leader fast', 2),
#  ('method glms via', 2),
#  ('coding natural image', 2),
#  ('bound domain adaptation', 2),
#  ('graph autoregressive feature', 2),
#  ('using mean field', 2),
#  ('asymmetric hebbian learning', 2),
#  ('gamma belief network', 2),
#  ('convex neural network', 2),
#  ('online independent component', 2),
#  ('extension slow feature', 2),
#  ('locally linear latent', 2),
#  ('regret bound undiscounted', 2),
#  ('regularized linear function', 2),
#  ('fullyobserved variational bayesian', 2),
#  ('task specification demonstration', 2),
#  ('estimate multiclass classification', 2),
#  ('nonlinear time series', 2),
#  ('orientation ocular dominance', 2),
#  ('infinite mixture gaussian', 2),
#  ('adaptive stimulus selection', 2),
#  ('approximate inference latent', 2),
#  ('maximum entropy density', 2),
#  ('mean field approximation', 2),
#  ('nonlinear dimension reduction', 2),
#  ('learning via convex', 2),
#  ('direct importance estimation', 2),
#  ('bottleneck gaussian variable', 2),
#  ('learning invariant representation', 2),
#  ('probabilistic neural network', 2),
#  ('active learning via', 2),
#  ('prediction expert advice', 2),
#  ('cyclic block coordinate', 2),
#  ('regularized stochastic learning', 2),
#  ('video object segmentation', 2),
#  ('reinforcement learning method', 2),
#  ('massive online analysis', 2),
#  ('information bottleneck gaussian', 2),
#  ('generalized bradleyterry model', 2),
#  ('mixture natural image', 2),
#  ('regularized mestimators nonconvexity', 2),
#  ('composite multiclass loss', 2),
#  ('graphical model arbitrary', 2),
#  ('learning mixture tree', 2),
#  ('stochastic optimization algorithm', 2),
#  ('method nonconvex optimization', 2),
#  ('learning multiagent system', 2),
#  ('regression covariate shift', 2),
#  ('process statespace model', 2),
#  ('scene edge filter', 2),
#  ('feature selection pattern', 2),
#  ('reduction supervised learning', 2),
#  ('releasing smooth query', 2),
#  ('field variational bayes', 2),
#  ('theory local optimum', 2),
#  ('euclidean embedding cooccurrence', 2),
#  ('graphical model inference', 2),
#  ('entropy policy search', 2),
#  ('neural network classification', 2),
#  ('adaptive submodular maximization', 2),
#  ('learning using local', 2),
#  ('hierarchical clustering via', 2),
#  ('dependent chinese restaurant', 2),
#  ('variational inference gaussian', 2),
#  ('proximal gradient algorithm', 2),
#  ('covariance matrix estimation', 2),
#  ('mean squared error', 2),
#  ('practical bayesian optimization', 2),
#  ('monte carlo inference', 2),
#  ('learning environment unknown', 2),
#  ('adaptive stochastic optimization', 2),
#  ('move truncated convex', 2),
#  ('distributed submodular cover', 2),
#  ('generative model discriminative', 2),
#  ('partially ranked data', 2),
#  ('overcoming catastrophic forgetting', 2),
#  ('nested chinese restaurant', 2),
#  ('bayes point machine', 2),
#  ('dimensionality reduction data', 2),
#  ('multipass stochastic gradient', 2),
#  ('linear value function', 2),
#  ('reduction iid learning', 2),
#  ('link prediction graph', 2),
#  ('path integral control', 2),
#  ('transportability multiple environment', 2),
#  ('contrast sensitive silicon', 2),
#  ('fast neural network', 2),
#  ('latent source model', 2),
#  ('spectral method meet', 2),
#  ('bayesian network thousand', 2),
#  ('discovery bayesian network', 2),
#  ('graphical model application', 2),
#  ('practical characteristic neural', 2),
#  ('probability density stochastic', 2),
#  ('mechanism local differential', 2),
#  ('maximumweight independent set', 2),
#  ('fast variational inference', 2),
#  ('online learning finite', 2),
#  ('learning large margin', 2),
#  ('sequential decision problem', 2),
#  ('multiplicative incentive mechanism', 2),
#  ('via gradient descent', 2),
#  ('gaussian process statespace', 2),
#  ('output gaussian process', 2),
#  ('nonconvex finitesum optimization', 2),
#  ('attend infer repeat', 2),
#  ('inference dirichlet process', 2),
#  ('weight space probability', 2),
#  ('clustering via spreading', 2),
#  ('gaussian latent variable', 2),
#  ('entropy density estimation', 2),
#  ('descent method learning', 2),
#  ('consistency meanshift algorithm', 2),
#  ('matrix completion via', 2),
#  ('mixed membership stochastic', 2),
#  ('silicon growth cone', 2),
#  ('cone programming formulation', 2),
#  ('agnostic selective classification', 2),
#  ('series prediction using', 2),
#  ('static prediction game', 2),
#  ('probabilistic line search', 2),
#  ('factorization missing data', 2),
#  ('distributed statistical estimation', 2),
#  ('learning switching cost', 2),
#  ('continuous time bayesian', 2),
#  ('exploratory data analysis', 2),
#  ('informationtheoretic analysis thompson', 2),
#  ('group factor analysis', 2),
#  ('nonparametric belief propagation', 2),
#  ('interpreting neural network', 2),
#  ('natural gradient descent', 2),
#  ('structured prediction theory', 2),
#  ('gradient hard thresholding', 2),
#  ('univariate exponential family', 2),
#  ('unsupervised supervised learning', 2),
#  ('neural network graph', 2),
#  ('identifiable uniqueness tensor', 2),
#  ('linear latent variable', 2),
#  ('curved constraint set', 2),
#  ('inference spiking neuron', 2),
#  ('estimation model selection', 2),
#  ('recognizing handwritten digit', 2),
#  ('traveling salesman problem', 2),
#  ('noisy spiking neuron', 2),
#  ('gradient estimate reinforcement', 2),
#  ('via univariate exponential', 2),
#  ('polynomial time algorithm', 2),
#  ('variable selection method', 2),
#  ('online submodular minimization', 2),
#  ('probabilistic matrix factorization', 2),
#  ('using markov random', 2),
#  ('using neural net', 2),
#  ('primaldual splitting method', 2),
#  ...]

# %% [markdown]
#  # extract citations from google scholar using Selenium

# %%
# create an object of class SeleniumWrapper, show path to chromedriver
filepath_chrome = 'C:/Users/tsyurmasto/Documents/Python Scripts/articles/chromedriver.exe'
seleniumwrapper = SeleniumWrapper('proxies.txt',filepath_chrome)

# %%
title_citations, authors = seleniumwrapper.selenium_parse(title_lst[:6000])
# Out:
# title_counter=1,run_counter=1,proxy=['192.169.197.146'],response=200
# title_counter=1,run_counter=1,proxy=['190.152.180.58'],response=200
# title_counter=1,run_counter=3,proxy=['134.249.141.155'],response=200
# title_counter=1,run_counter=5,proxy=['190.103.31.177'],response=200
# title_counter=2,run_counter=7,proxy=['185.52.117.38'],response=200
# title_counter=2,run_counter=7,proxy=['186.249.208.223'],response=200
# title_counter=2,run_counter=9,proxy=['166.62.83.128'],response=200
# title_counter=2,run_counter=11,proxy=['131.0.234.82'],response=200
# title_counter=3,run_counter=13,proxy=['128.199.217.139'],response=200
# title_counter=3,run_counter=13,proxy=['85.206.57.202'],response=200
# title_counter=3,run_counter=15,proxy=['85.111.9.81'],response=200
# title_counter=3,run_counter=17,proxy=['109.110.29.89'],response=200
# title_counter=3,run_counter=19,proxy=['85.248.6.41'],response=200
# title_counter=4,run_counter=21,proxy=['85.94.167.73'],response=200
# title_counter=4,run_counter=21,proxy=['212.42.113.49'],response=200
# title_counter=5,run_counter=23,proxy=['177.87.215.206'],response=200
# title_counter=6,run_counter=23,proxy=['177.136.32.190'],response=200
# title_counter=6,run_counter=23,proxy=['186.42.124.130'],response=200
# title_counter=7,run_counter=25,proxy=['185.206.132.18'],response=200
# title_counter=7,run_counter=25,proxy=['89.148.196.249'],response=200
# title_counter=7,run_counter=27,proxy=['193.171.122.20'],response=200
# title_counter=7,run_counter=29,proxy=['43.224.33.123'],response=200
# title_counter=8,run_counter=31,proxy=['190.152.12.54'],response=200
# title_counter=8,run_counter=31,proxy=['81.30.217.55'],response=200
# title_counter=9,run_counter=33,proxy=['77.37.208.119'],response=200
# title_counter=9,run_counter=33,proxy=['168.70.27.182'],response=200
# title_counter=10,run_counter=35,proxy=['206.189.216.18'],response=200
# title_counter=10,run_counter=35,proxy=['185.206.132.18'],response=200
# title_counter=10,run_counter=37,proxy=['78.108.245.211'],response=200
# title_counter=11,run_counter=39,proxy=['201.182.90.108'],response=200
# title_counter=11,run_counter=39,proxy=['81.3.154.235'],response=200
# title_counter=11,run_counter=41,proxy=['85.117.61.186'],response=200
# title_counter=12,run_counter=43,proxy=['92.248.163.16'],response=200
# title_counter=12,run_counter=43,proxy=['86.57.175.61'],response=200
# title_counter=12,run_counter=45,proxy=['157.230.173.224'],response=200
# title_counter=12,run_counter=47,proxy=['165.22.37.167'],response=200
# title_counter=12,run_counter=49,proxy=['177.12.113.103'],response=200
# title_counter=13,run_counter=51,proxy=['185.162.143.193'],response=200
# title_counter=13,run_counter=51,proxy=['46.160.237.93'],response=200
# title_counter=13,run_counter=53,proxy=['5.59.143.43'],response=200
# title_counter=13,run_counter=55,proxy=['187.111.192.33'],response=200
# title_counter=13,run_counter=57,proxy=['89.216.23.40'],response=200
# title_counter=14,run_counter=59,proxy=['46.101.167.43'],response=200
# title_counter=14,run_counter=59,proxy=['178.130.35.187'],response=200
# title_counter=14,run_counter=61,proxy=['103.105.48.16'],response=200
# title_counter=15,run_counter=63,proxy=['163.172.170.15'],response=200
# title_counter=15,run_counter=63,proxy=['185.82.96.164'],response=200
# title_counter=15,run_counter=65,proxy=['178.252.167.90'],response=200
# title_counter=16,run_counter=67,proxy=['212.243.175.126'],response=200
# title_counter=16,run_counter=67,proxy=['82.142.147.174'],response=200
# title_counter=16,run_counter=69,proxy=['78.139.200.51'],response=200
# title_counter=17,run_counter=71,proxy=['81.163.38.60'],response=200
# title_counter=17,run_counter=71,proxy=['181.209.86.170'],response=200
# title_counter=17,run_counter=73,proxy=['12.7.109.254'],response=200
# title_counter=17,run_counter=75,proxy=['168.90.123.46'],response=200
# title_counter=18,run_counter=77,proxy=['195.81.20.71'],response=200
# title_counter=18,run_counter=77,proxy=['201.59.201.92'],response=200
# title_counter=18,run_counter=79,proxy=['204.186.238.70'],response=200
# title_counter=19,run_counter=81,proxy=['178.150.245.245'],response=200
# title_counter=19,run_counter=81,proxy=['93.189.221.253'],response=200
# title_counter=20,run_counter=83,proxy=['168.227.158.49'],response=200
# title_counter=20,run_counter=83,proxy=['140.82.59.139'],response=200
# title_counter=20,run_counter=85,proxy=['188.115.187.117'],response=200
# title_counter=20,run_counter=87,proxy=['66.25.110.179'],response=200
# title_counter=21,run_counter=89,proxy=['195.29.92.22'],response=200
# title_counter=21,run_counter=89,proxy=['12.132.115.26'],response=200
# title_counter=22,run_counter=91,proxy=['90.188.16.246'],response=200
# title_counter=22,run_counter=91,proxy=['168.121.97.67'],response=200
# list index out of range
# title_counter=22,run_counter=94,proxy=['192.99.207.23'],response=200
# title_counter=23,run_counter=96,proxy=['176.124.128.97'],response=200
# title_counter=23,run_counter=96,proxy=['46.10.230.84'],response=200
# title_counter=23,run_counter=98,proxy=['186.42.98.74'],response=200
# title_counter=24,run_counter=100,proxy=['186.5.207.1'],response=200
# title_counter=24,run_counter=100,proxy=['181.129.32.52'],response=200
# title_counter=24,run_counter=102,proxy=['178.128.173.71'],response=200
# title_counter=25,run_counter=104,proxy=['177.190.145.81'],response=200
# title_counter=25,run_counter=104,proxy=['158.58.133.32'],response=200
# title_counter=25,run_counter=106,proxy=['163.172.182.35'],response=200
# title_counter=25,run_counter=108,proxy=['85.111.9.81'],response=200
# title_counter=26,run_counter=110,proxy=['50.27.184.225'],response=200
# title_counter=26,run_counter=110,proxy=['181.129.47.162'],response=200
# title_counter=26,run_counter=112,proxy=['212.91.116.22'],response=200
# title_counter=26,run_counter=114,proxy=['66.208.117.227'],response=200
# title_counter=27,run_counter=116,proxy=['177.10.140.105'],response=200
# title_counter=27,run_counter=116,proxy=['12.7.109.254'],response=200
# title_counter=28,run_counter=118,proxy=['176.36.210.201'],response=200
# title_counter=28,run_counter=118,proxy=['62.152.43.152'],response=200
# title_counter=28,run_counter=120,proxy=['24.229.120.65'],response=200
# title_counter=29,run_counter=122,proxy=['95.170.118.79'],response=200
# title_counter=29,run_counter=122,proxy=['50.7.106.240'],response=200
# title_counter=29,run_counter=124,proxy=['122.201.18.152'],response=200
# title_counter=29,run_counter=126,proxy=['37.235.28.42'],response=200
# title_counter=30,run_counter=128,proxy=['89.233.183.64'],response=200
# title_counter=30,run_counter=128,proxy=['63.151.9.74'],response=200
# title_counter=30,run_counter=130,proxy=['88.99.246.248'],response=200
# title_counter=30,run_counter=132,proxy=['177.84.109.10'],response=200
# title_counter=30,run_counter=134,proxy=['170.79.123.100'],response=200
# title_counter=31,run_counter=136,proxy=['164.132.28.67'],response=200
# title_counter=31,run_counter=136,proxy=['80.95.105.148'],response=200
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@class="gs_in_txt gs_in_ac"]"}
#   (Session info: chrome=75.0.3770.90)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# title_counter=32,run_counter=140,proxy=['62.168.57.109'],response=200
# title_counter=33,run_counter=142,proxy=['159.149.129.204'],response=200
# title_counter=33,run_counter=142,proxy=['178.214.71.114'],response=200
# title_counter=33,run_counter=144,proxy=['178.216.2.229'],response=200
# title_counter=33,run_counter=146,proxy=['205.240.205.100'],response=200
# title_counter=34,run_counter=148,proxy=['72.139.29.114'],response=200
# title_counter=34,run_counter=148,proxy=['79.106.35.59'],response=200
# title_counter=34,run_counter=150,proxy=['194.54.183.82'],response=200
# title_counter=34,run_counter=152,proxy=['35.221.170.161'],response=200
# title_counter=35,run_counter=154,proxy=['41.73.15.130'],response=200
# ('Connection aborted.', OSError("(10060, 'WSAETIMEDOUT')",))
# title_counter=35,run_counter=155,proxy=['185.82.96.164'],response=200
# title_counter=35,run_counter=157,proxy=['157.119.188.22'],response=200
# title_counter=36,run_counter=159,proxy=['190.122.135.54'],response=200
# title_counter=36,run_counter=159,proxy=['186.159.1.97'],response=200
# title_counter=36,run_counter=161,proxy=['181.113.66.146'],response=200
# title_counter=36,run_counter=163,proxy=['185.29.11.251'],response=200
# title_counter=37,run_counter=165,proxy=['195.9.80.22'],response=200
# title_counter=37,run_counter=165,proxy=['109.233.212.105'],response=200
# title_counter=37,run_counter=167,proxy=['37.0.94.190'],response=200
# title_counter=37,run_counter=169,proxy=['199.247.16.23'],response=200
# name 'np' is not defined
# title_counter=38,run_counter=171,proxy=['95.158.248.97'],response=200
# title_counter=38,run_counter=173,proxy=['85.236.179.164'],response=200
# title_counter=38,run_counter=175,proxy=['31.13.15.94'],response=200
# name 'np' is not defined
# title_counter=39,run_counter=177,proxy=['186.232.195.24'],response=200
# title_counter=39,run_counter=179,proxy=['178.62.207.67'],response=200
# title_counter=39,run_counter=181,proxy=['138.68.17.62'],response=200
# name 'np' is not defined
# title_counter=40,run_counter=183,proxy=['163.172.187.113'],response=200
# title_counter=40,run_counter=185,proxy=['176.124.128.97'],response=200
# title_counter=40,run_counter=187,proxy=['95.31.22.157'],response=200
# name 'np' is not defined
# title_counter=41,run_counter=189,proxy=['85.26.163.177'],response=200
# title_counter=41,run_counter=191,proxy=['40.70.129.174'],response=200
# title_counter=41,run_counter=193,proxy=['193.187.82.74'],response=200
# name 'np' is not defined
# title_counter=42,run_counter=195,proxy=['165.22.52.10'],response=200
# title_counter=42,run_counter=197,proxy=['87.120.129.82'],response=200
# title_counter=42,run_counter=199,proxy=['177.104.193.144'],response=200
# name 'np' is not defined
# title_counter=43,run_counter=201,proxy=['185.152.12.42'],response=200
# title_counter=43,run_counter=203,proxy=['95.47.116.129'],response=200
# title_counter=43,run_counter=205,proxy=['176.124.96.14'],response=200
# name 'np' is not defined
# title_counter=44,run_counter=207,proxy=['138.117.36.155'],response=200
# title_counter=44,run_counter=209,proxy=['88.119.128.181'],response=200
# title_counter=44,run_counter=211,proxy=['187.19.203.194'],response=200
# name 'np' is not defined
# title_counter=45,run_counter=213,proxy=['185.7.169.41'],response=200
# title_counter=45,run_counter=215,proxy=['189.69.242.227'],response=200
# title_counter=45,run_counter=217,proxy=['50.244.9.1'],response=200
# name 'np' is not defined
# title_counter=46,run_counter=219,proxy=['45.65.227.74'],response=200
# title_counter=46,run_counter=221,proxy=['176.113.126.127'],response=200
# title_counter=46,run_counter=223,proxy=['123.108.200.137'],response=200
# name 'np' is not defined
# title_counter=47,run_counter=225,proxy=['31.41.175.83'],response=200
# title_counter=47,run_counter=227,proxy=['86.62.120.68'],response=200
# title_counter=47,run_counter=229,proxy=['128.140.225.41'],response=200
# name 'np' is not defined
# title_counter=48,run_counter=231,proxy=['164.132.28.67'],response=200
# title_counter=48,run_counter=233,proxy=['103.25.168.22'],response=200
# title_counter=48,run_counter=235,proxy=['86.57.175.61'],response=200
# name 'np' is not defined
# title_counter=49,run_counter=237,proxy=['68.183.216.78'],response=200
# title_counter=49,run_counter=239,proxy=['51.15.212.13'],response=200
# title_counter=49,run_counter=241,proxy=['193.107.221.176'],response=200
# name 'np' is not defined
# title_counter=50,run_counter=243,proxy=['92.255.195.228'],response=200
# title_counter=50,run_counter=245,proxy=['178.128.151.27'],response=200
# title_counter=50,run_counter=247,proxy=['50.62.35.225'],response=200
# name 'np' is not defined
# title_counter=51,run_counter=249,proxy=['187.86.153.254'],response=200
# title_counter=51,run_counter=251,proxy=['176.106.186.99'],response=200
# title_counter=51,run_counter=253,proxy=['220.135.2.247'],response=200
# name 'np' is not defined
# title_counter=52,run_counter=255,proxy=['84.47.145.54'],response=200
# title_counter=52,run_counter=257,proxy=['35.221.155.254'],response=200
# title_counter=52,run_counter=259,proxy=['177.128.209.58'],response=200
# name 'np' is not defined
# title_counter=53,run_counter=261,proxy=['178.79.63.4'],response=200
# title_counter=53,run_counter=263,proxy=['91.220.166.148'],response=200
# title_counter=53,run_counter=265,proxy=['109.194.175.108'],response=200
# name 'np' is not defined
# title_counter=54,run_counter=267,proxy=['54.38.195.161'],response=200
# title_counter=54,run_counter=269,proxy=['197.211.38.187'],response=200
# title_counter=54,run_counter=271,proxy=['207.189.214.154'],response=200
# name 'np' is not defined
# title_counter=55,run_counter=273,proxy=['201.7.216.225'],response=200
# title_counter=55,run_counter=275,proxy=['95.72.7.20'],response=200
# title_counter=55,run_counter=277,proxy=['212.156.86.226'],response=200
# name 'np' is not defined
# title_counter=56,run_counter=279,proxy=['200.54.218.82'],response=200
# title_counter=56,run_counter=281,proxy=['202.138.236.35'],response=200
# title_counter=56,run_counter=283,proxy=['131.221.217.130'],response=200
# name 'np' is not defined
# title_counter=57,run_counter=285,proxy=['208.117.223.101'],response=200
# title_counter=57,run_counter=287,proxy=['96.89.102.21'],response=200
# title_counter=57,run_counter=289,proxy=['167.250.160.150'],response=200
# name 'np' is not defined
# title_counter=58,run_counter=291,proxy=['5.39.165.20'],response=200
# title_counter=58,run_counter=293,proxy=['213.59.155.225'],response=200
# title_counter=58,run_counter=295,proxy=['54.179.155.51'],response=200
# name 'np' is not defined
# title_counter=59,run_counter=297,proxy=['177.23.138.252'],response=200
# title_counter=59,run_counter=299,proxy=['176.196.84.138'],response=200
# title_counter=59,run_counter=301,proxy=['109.110.29.89'],response=200
# name 'np' is not defined
# title_counter=60,run_counter=303,proxy=['83.171.98.47'],response=200
# title_counter=60,run_counter=305,proxy=['190.64.147.19'],response=200
# title_counter=60,run_counter=307,proxy=['79.106.35.247'],response=200
# name 'np' is not defined
# title_counter=61,run_counter=309,proxy=['80.50.141.118'],response=200
# title_counter=61,run_counter=311,proxy=['45.71.113.202'],response=200
# title_counter=61,run_counter=313,proxy=['176.112.108.58'],response=200
# name 'np' is not defined
# title_counter=62,run_counter=315,proxy=['67.205.171.99'],response=200
# title_counter=62,run_counter=317,proxy=['31.135.125.253'],response=200
# title_counter=62,run_counter=319,proxy=['201.184.135.154'],response=200
# name 'np' is not defined
# title_counter=63,run_counter=321,proxy=['12.227.46.80'],response=200
# title_counter=63,run_counter=323,proxy=['190.94.132.151'],response=200
# title_counter=63,run_counter=325,proxy=['79.137.254.51'],response=200
# name 'np' is not defined
# title_counter=64,run_counter=327,proxy=['191.240.28.25'],response=200
# title_counter=64,run_counter=329,proxy=['199.119.158.2'],response=200
# title_counter=64,run_counter=331,proxy=['94.198.132.106'],response=200
# name 'np' is not defined
# title_counter=65,run_counter=333,proxy=['89.233.183.64'],response=200
# title_counter=65,run_counter=335,proxy=['93.99.104.121'],response=200
# title_counter=65,run_counter=337,proxy=['31.173.138.204'],response=200
# name 'np' is not defined
# title_counter=66,run_counter=339,proxy=['95.47.116.133'],response=200
# title_counter=66,run_counter=341,proxy=['178.128.55.206'],response=200
# title_counter=66,run_counter=343,proxy=['187.32.175.203'],response=200
# name 'np' is not defined
# title_counter=67,run_counter=345,proxy=['3.81.161.216'],response=200
# title_counter=67,run_counter=347,proxy=['138.186.20.70'],response=200
# title_counter=67,run_counter=349,proxy=['165.22.59.64'],response=200
# name 'np' is not defined
# title_counter=68,run_counter=351,proxy=['186.183.159.82'],response=200
# title_counter=68,run_counter=353,proxy=['200.10.69.194'],response=200
# title_counter=68,run_counter=355,proxy=['176.221.116.10'],response=200
# name 'np' is not defined
# title_counter=69,run_counter=357,proxy=['95.78.160.156'],response=200
# title_counter=69,run_counter=359,proxy=['58.162.229.173'],response=200
# title_counter=69,run_counter=361,proxy=['163.172.167.29'],response=200
# name 'np' is not defined
# title_counter=70,run_counter=363,proxy=['66.42.107.87'],response=200
# title_counter=70,run_counter=365,proxy=['130.0.27.18'],response=200
# title_counter=70,run_counter=367,proxy=['200.69.65.186'],response=200
# name 'np' is not defined
# title_counter=71,run_counter=369,proxy=['177.238.248.104'],response=200
# title_counter=71,run_counter=371,proxy=['163.172.179.205'],response=200
# title_counter=71,run_counter=373,proxy=['194.0.140.138'],response=200
# name 'np' is not defined
# title_counter=72,run_counter=375,proxy=['95.179.181.1'],response=200
# title_counter=72,run_counter=377,proxy=['78.29.45.176'],response=200
# title_counter=72,run_counter=379,proxy=['138.68.93.249'],response=200
# name 'np' is not defined
# title_counter=73,run_counter=381,proxy=['170.84.156.198'],response=200
# title_counter=73,run_counter=383,proxy=['200.35.49.65'],response=200
# title_counter=73,run_counter=385,proxy=['200.33.143.75'],response=200
# name 'np' is not defined
# title_counter=74,run_counter=387,proxy=['216.176.132.20'],response=200
# title_counter=74,run_counter=389,proxy=['213.81.182.29'],response=200
# title_counter=74,run_counter=391,proxy=['89.46.204.81'],response=200
# name 'np' is not defined
# title_counter=75,run_counter=393,proxy=['203.246.112.133'],response=200
# title_counter=75,run_counter=395,proxy=['186.219.112.76'],response=200
# title_counter=75,run_counter=397,proxy=['64.235.204.107'],response=200
# name 'np' is not defined
# title_counter=76,run_counter=399,proxy=['78.36.202.9'],response=200
# title_counter=76,run_counter=401,proxy=['186.248.163.130'],response=200
# title_counter=76,run_counter=403,proxy=['177.72.84.6'],response=200
# name 'np' is not defined
# title_counter=77,run_counter=405,proxy=['185.49.93.101'],response=200
# title_counter=77,run_counter=407,proxy=['177.128.228.192'],response=200
# title_counter=77,run_counter=409,proxy=['190.7.141.42'],response=200
# name 'np' is not defined
# title_counter=78,run_counter=411,proxy=['93.78.247.20'],response=200
# title_counter=78,run_counter=413,proxy=['186.86.247.169'],response=200
# title_counter=78,run_counter=415,proxy=['46.63.96.133'],response=200
# name 'np' is not defined
# title_counter=79,run_counter=417,proxy=['91.225.123.3'],response=200
# title_counter=79,run_counter=419,proxy=['82.114.81.129'],response=200
# title_counter=79,run_counter=421,proxy=['96.89.102.21'],response=200
# name 'np' is not defined
# title_counter=80,run_counter=423,proxy=['37.57.40.167'],response=200
# title_counter=80,run_counter=425,proxy=['177.8.247.60'],response=200
# title_counter=80,run_counter=427,proxy=['212.47.233.30'],response=200
# name 'np' is not defined
# title_counter=81,run_counter=429,proxy=['208.113.182.208'],response=200
# title_counter=81,run_counter=431,proxy=['69.65.65.178'],response=200
# title_counter=81,run_counter=433,proxy=['177.8.242.79'],response=200
# name 'np' is not defined
# title_counter=82,run_counter=435,proxy=['82.114.81.129'],response=200
# title_counter=82,run_counter=437,proxy=['212.42.113.49'],response=200
# title_counter=82,run_counter=439,proxy=['80.50.141.118'],response=200
# name 'np' is not defined
# title_counter=83,run_counter=441,proxy=['88.129.82.241'],response=200
# title_counter=83,run_counter=443,proxy=['181.49.130.99'],response=200
# title_counter=83,run_counter=445,proxy=['165.22.37.167'],response=200
# name 'np' is not defined
# title_counter=84,run_counter=447,proxy=['206.189.89.139'],response=200
# title_counter=84,run_counter=449,proxy=['200.111.120.84'],response=200
# title_counter=84,run_counter=451,proxy=['131.196.4.98'],response=200
# name 'np' is not defined
# title_counter=85,run_counter=453,proxy=['83.171.114.92'],response=200
# title_counter=85,run_counter=455,proxy=['207.190.85.244'],response=200
# title_counter=85,run_counter=457,proxy=['123.108.200.137'],response=200
# name 'np' is not defined
# title_counter=86,run_counter=459,proxy=['186.211.110.129'],response=200
# title_counter=86,run_counter=461,proxy=['110.78.208.11'],response=200
# title_counter=86,run_counter=463,proxy=['170.249.176.38'],response=200
# name 'np' is not defined
# title_counter=87,run_counter=465,proxy=['200.5.254.154'],response=200
# title_counter=87,run_counter=467,proxy=['185.162.141.236'],response=200
# title_counter=87,run_counter=469,proxy=['195.88.26.9'],response=200
# name 'np' is not defined
# title_counter=88,run_counter=471,proxy=['5.206.236.45'],response=200
# title_counter=88,run_counter=473,proxy=['181.112.147.170'],response=200
# title_counter=88,run_counter=475,proxy=['138.185.236.226'],response=200
# name 'np' is not defined
# title_counter=89,run_counter=477,proxy=['77.120.137.9'],response=200
# title_counter=89,run_counter=479,proxy=['197.211.38.187'],response=200
# title_counter=89,run_counter=481,proxy=['93.99.104.121'],response=200
# name 'np' is not defined
# title_counter=90,run_counter=483,proxy=['71.43.24.76'],response=200
# title_counter=90,run_counter=485,proxy=['31.129.162.158'],response=200
# title_counter=90,run_counter=487,proxy=['177.136.123.147'],response=200
# name 'np' is not defined
# title_counter=91,run_counter=489,proxy=['192.140.113.130'],response=200
# title_counter=91,run_counter=491,proxy=['85.206.57.202'],response=200
# title_counter=91,run_counter=493,proxy=['5.58.167.58'],response=200
# name 'np' is not defined
# title_counter=92,run_counter=495,proxy=['194.44.230.115'],response=200
# title_counter=92,run_counter=497,proxy=['178.150.89.13'],response=200
# title_counter=92,run_counter=499,proxy=['192.140.113.130'],response=200
# name 'np' is not defined
# title_counter=93,run_counter=501,proxy=['177.54.195.139'],response=200
# title_counter=93,run_counter=503,proxy=['168.227.158.17'],response=200
# title_counter=93,run_counter=505,proxy=['200.146.236.217'],response=200
# name 'np' is not defined
# title_counter=94,run_counter=507,proxy=['177.75.1.37'],response=200
# title_counter=94,run_counter=509,proxy=['195.46.20.146'],response=200
# title_counter=94,run_counter=511,proxy=['96.82.74.129'],response=200
# name 'np' is not defined
# title_counter=95,run_counter=513,proxy=['177.124.225.106'],response=200
# title_counter=95,run_counter=515,proxy=['159.65.0.132'],response=200
# title_counter=95,run_counter=517,proxy=['151.80.58.175'],response=200
# name 'np' is not defined
# title_counter=96,run_counter=519,proxy=['91.202.144.204'],response=200
# title_counter=96,run_counter=521,proxy=['45.71.31.4'],response=200
# title_counter=96,run_counter=523,proxy=['85.236.179.164'],response=200
# name 'np' is not defined
# title_counter=97,run_counter=525,proxy=['89.28.57.25'],response=200
# title_counter=97,run_counter=527,proxy=['200.35.75.34'],response=200
# title_counter=97,run_counter=529,proxy=['185.82.96.164'],response=200
# name 'np' is not defined
# title_counter=98,run_counter=531,proxy=['186.219.58.121'],response=200
# title_counter=98,run_counter=533,proxy=['181.211.101.90'],response=200
# title_counter=98,run_counter=535,proxy=['70.133.242.9'],response=200
# name 'np' is not defined
# title_counter=99,run_counter=537,proxy=['84.51.33.98'],response=200
# title_counter=99,run_counter=539,proxy=['181.211.252.186'],response=200
# title_counter=99,run_counter=541,proxy=['188.75.188.26'],response=200
# name 'np' is not defined
# title_counter=100,run_counter=543,proxy=['149.34.3.176'],response=200
# title_counter=100,run_counter=545,proxy=['201.219.213.149'],response=200
# title_counter=100,run_counter=547,proxy=['185.238.239.106'],response=200
# name 'np' is not defined
# title_counter=101,run_counter=549,proxy=['89.134.84.225'],response=200
# title_counter=101,run_counter=551,proxy=['212.156.86.226'],response=200
# title_counter=101,run_counter=553,proxy=['78.36.16.214'],response=200
# name 'np' is not defined
# title_counter=102,run_counter=555,proxy=['202.143.121.245'],response=200
# title_counter=102,run_counter=557,proxy=['213.79.68.70'],response=200
# title_counter=102,run_counter=559,proxy=['166.62.89.69'],response=200
# name 'np' is not defined
# title_counter=103,run_counter=561,proxy=['186.96.125.115'],response=200
# title_counter=103,run_counter=563,proxy=['92.207.253.226'],response=200
# title_counter=103,run_counter=565,proxy=['134.209.20.60'],response=200
# name 'np' is not defined
# title_counter=104,run_counter=567,proxy=['149.34.3.176'],response=200
# title_counter=104,run_counter=569,proxy=['187.11.232.71'],response=200
# title_counter=104,run_counter=571,proxy=['168.195.196.18'],response=200
# name 'np' is not defined
# title_counter=105,run_counter=573,proxy=['201.202.246.162'],response=200
# title_counter=105,run_counter=575,proxy=['186.211.199.118'],response=200
# title_counter=105,run_counter=577,proxy=['186.211.110.129'],response=200
# name 'np' is not defined
# title_counter=106,run_counter=579,proxy=['176.118.48.138'],response=200
# title_counter=106,run_counter=581,proxy=['88.199.21.74'],response=200
# title_counter=106,run_counter=583,proxy=['92.242.240.34'],response=200
# name 'np' is not defined
# title_counter=107,run_counter=585,proxy=['78.85.38.101'],response=200
# title_counter=107,run_counter=587,proxy=['168.232.198.179'],response=200
# title_counter=107,run_counter=589,proxy=['162.243.173.250'],response=200
# name 'np' is not defined
# title_counter=108,run_counter=591,proxy=['69.171.68.90'],response=200
# title_counter=108,run_counter=593,proxy=['51.15.198.91'],response=200
# title_counter=108,run_counter=595,proxy=['163.172.183.191'],response=200
# name 'np' is not defined
# title_counter=109,run_counter=597,proxy=['31.173.89.209'],response=200
# title_counter=109,run_counter=599,proxy=['83.136.114.10'],response=200
# title_counter=109,run_counter=601,proxy=['186.237.223.203'],response=200
# name 'np' is not defined
# title_counter=110,run_counter=603,proxy=['77.242.29.158'],response=200
# title_counter=110,run_counter=605,proxy=['66.97.38.58'],response=200
# title_counter=110,run_counter=607,proxy=['185.17.127.164'],response=200
# name 'np' is not defined
# title_counter=111,run_counter=609,proxy=['122.116.1.83'],response=200
# title_counter=111,run_counter=611,proxy=['45.226.80.178'],response=200
# title_counter=111,run_counter=613,proxy=['185.150.232.98'],response=200
# name 'np' is not defined
# title_counter=112,run_counter=615,proxy=['38.133.200.94'],response=200
# title_counter=112,run_counter=617,proxy=['191.252.185.161'],response=200
# title_counter=112,run_counter=619,proxy=['67.60.137.219'],response=200
# name 'np' is not defined
# title_counter=113,run_counter=621,proxy=['54.39.16.26'],response=200
# title_counter=113,run_counter=623,proxy=['213.57.125.152'],response=200
# title_counter=113,run_counter=625,proxy=['189.109.43.58'],response=200
# name 'np' is not defined
# title_counter=114,run_counter=627,proxy=['187.63.215.194'],response=200
# title_counter=114,run_counter=629,proxy=['176.197.145.162'],response=200
# title_counter=114,run_counter=631,proxy=['187.95.82.93'],response=200
# name 'np' is not defined
# title_counter=115,run_counter=633,proxy=['131.221.217.130'],response=200
# title_counter=115,run_counter=635,proxy=['151.80.100.147'],response=200
# title_counter=115,run_counter=637,proxy=['94.140.208.190'],response=200
# name 'np' is not defined
# title_counter=116,run_counter=639,proxy=['200.10.69.196'],response=200
# title_counter=116,run_counter=641,proxy=['200.146.236.217'],response=200
# title_counter=116,run_counter=643,proxy=['162.243.173.67'],response=200
# name 'np' is not defined
# title_counter=117,run_counter=645,proxy=['95.86.206.65'],response=200
# title_counter=117,run_counter=647,proxy=['109.233.212.105'],response=200
# title_counter=117,run_counter=649,proxy=['89.108.135.130'],response=200
# name 'np' is not defined
# title_counter=118,run_counter=651,proxy=['81.183.132.225'],response=200
# title_counter=118,run_counter=653,proxy=['132.148.130.46'],response=200
# title_counter=118,run_counter=655,proxy=['91.222.171.246'],response=200
# name 'np' is not defined
# title_counter=119,run_counter=657,proxy=['185.112.35.27'],response=200
# title_counter=119,run_counter=659,proxy=['149.56.133.165'],response=200
# title_counter=119,run_counter=661,proxy=['132.148.16.123'],response=200
# name 'np' is not defined
# title_counter=120,run_counter=663,proxy=['178.150.84.139'],response=200
# title_counter=120,run_counter=665,proxy=['176.118.146.161'],response=200
# title_counter=120,run_counter=667,proxy=['46.160.17.224'],response=200
# name 'np' is not defined
# title_counter=121,run_counter=669,proxy=['162.243.159.46'],response=200
# title_counter=121,run_counter=671,proxy=['170.80.91.1'],response=200
# title_counter=121,run_counter=673,proxy=['93.116.185.57'],response=200
# name 'np' is not defined
# title_counter=122,run_counter=675,proxy=['185.23.82.39'],response=200
# title_counter=122,run_counter=677,proxy=['177.8.242.65'],response=200
# title_counter=122,run_counter=679,proxy=['200.9.67.200'],response=200
# name 'np' is not defined
# title_counter=123,run_counter=681,proxy=['45.4.116.234'],response=200
# title_counter=123,run_counter=683,proxy=['134.209.109.139'],response=200
# title_counter=123,run_counter=685,proxy=['109.101.139.106'],response=200
# name 'np' is not defined
# title_counter=124,run_counter=687,proxy=['89.200.150.35'],response=200
# title_counter=124,run_counter=689,proxy=['186.219.210.70'],response=200
# title_counter=124,run_counter=691,proxy=['92.255.195.228'],response=200
# name 'np' is not defined
# title_counter=125,run_counter=693,proxy=['36.255.86.242'],response=200
# title_counter=125,run_counter=695,proxy=['142.93.181.2'],response=200
# title_counter=125,run_counter=697,proxy=['185.7.169.41'],response=200
# name 'np' is not defined
# title_counter=126,run_counter=699,proxy=['209.13.96.166'],response=200
# title_counter=126,run_counter=701,proxy=['207.164.119.213'],response=200
# title_counter=126,run_counter=703,proxy=['103.25.168.22'],response=200
# name 'np' is not defined
# title_counter=127,run_counter=705,proxy=['131.196.143.212'],response=200
# title_counter=127,run_counter=707,proxy=['185.17.127.164'],response=200
# title_counter=127,run_counter=709,proxy=['83.150.10.201'],response=200
# name 'np' is not defined
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# title_counter=128,run_counter=713,proxy=['80.211.137.76'],response=200
# name 'np' is not defined
# title_counter=129,run_counter=715,proxy=['176.106.186.99'],response=200
# title_counter=129,run_counter=717,proxy=['12.251.81.106'],response=200
# title_counter=129,run_counter=719,proxy=['31.43.63.70'],response=200
# name 'np' is not defined
# title_counter=130,run_counter=721,proxy=['206.189.231.226'],response=200
# title_counter=130,run_counter=723,proxy=['176.99.225.121'],response=200
# title_counter=130,run_counter=725,proxy=['186.237.223.203'],response=200
# name 'np' is not defined
# title_counter=131,run_counter=727,proxy=['50.224.238.78'],response=200
# title_counter=131,run_counter=729,proxy=['81.163.48.150'],response=200
# title_counter=131,run_counter=731,proxy=['72.89.133.41'],response=200
# name 'np' is not defined
# title_counter=132,run_counter=733,proxy=['92.87.8.192'],response=200
# title_counter=132,run_counter=735,proxy=['188.241.45.61'],response=200
# title_counter=132,run_counter=737,proxy=['5.20.151.152'],response=200
# name 'np' is not defined
# title_counter=133,run_counter=739,proxy=['177.73.45.193'],response=200
# title_counter=133,run_counter=741,proxy=['85.206.108.197'],response=200
# title_counter=133,run_counter=743,proxy=['37.60.35.4'],response=200
# name 'np' is not defined
# title_counter=134,run_counter=745,proxy=['185.101.238.130'],response=200
# title_counter=134,run_counter=747,proxy=['50.247.72.33'],response=200
# title_counter=134,run_counter=749,proxy=['220.135.2.247'],response=200
# name 'np' is not defined
# title_counter=135,run_counter=751,proxy=['128.199.201.67'],response=200
# title_counter=135,run_counter=753,proxy=['45.225.87.138'],response=200
# title_counter=135,run_counter=755,proxy=['50.234.76.70'],response=200
# name 'np' is not defined
# title_counter=136,run_counter=757,proxy=['5.59.143.78'],response=200
# title_counter=136,run_counter=759,proxy=['195.234.215.81'],response=200
# title_counter=136,run_counter=761,proxy=['89.102.15.205'],response=200
# name 'np' is not defined
# title_counter=137,run_counter=763,proxy=['108.160.129.94'],response=200
# title_counter=137,run_counter=765,proxy=['190.13.146.85'],response=200
# title_counter=137,run_counter=767,proxy=['181.211.6.34'],response=200
# name 'np' is not defined
# title_counter=138,run_counter=769,proxy=['84.245.104.164'],response=200
# title_counter=138,run_counter=771,proxy=['86.34.157.3'],response=200
# title_counter=138,run_counter=773,proxy=['195.218.130.50'],response=200
# name 'np' is not defined
# title_counter=139,run_counter=775,proxy=['91.205.131.55'],response=200
# title_counter=139,run_counter=777,proxy=['187.19.114.1'],response=200
# title_counter=139,run_counter=779,proxy=['131.0.234.82'],response=200
# name 'np' is not defined
# title_counter=140,run_counter=781,proxy=['45.65.227.74'],response=200
# title_counter=140,run_counter=783,proxy=['178.252.167.90'],response=200
# title_counter=140,run_counter=785,proxy=['188.93.238.17'],response=200
# name 'np' is not defined
# title_counter=141,run_counter=787,proxy=['190.149.7.211'],response=200
# title_counter=141,run_counter=789,proxy=['82.135.248.243'],response=200
# title_counter=141,run_counter=791,proxy=['193.93.49.193'],response=200
# name 'np' is not defined
# title_counter=142,run_counter=793,proxy=['138.94.48.62'],response=200
# title_counter=142,run_counter=795,proxy=['46.55.161.219'],response=200
# title_counter=142,run_counter=797,proxy=['78.133.163.190'],response=200
# name 'np' is not defined
# title_counter=143,run_counter=799,proxy=['163.172.209.92'],response=200
# title_counter=143,run_counter=801,proxy=['195.81.20.71'],response=200
# title_counter=143,run_counter=803,proxy=['163.172.179.42'],response=200
# name 'np' is not defined
# title_counter=144,run_counter=805,proxy=['191.252.191.48'],response=200
# title_counter=144,run_counter=807,proxy=['104.139.74.25'],response=200
# title_counter=144,run_counter=809,proxy=['212.47.232.191'],response=200
# name 'np' is not defined
# title_counter=145,run_counter=811,proxy=['66.33.212.227'],response=200
# title_counter=145,run_counter=813,proxy=['187.73.48.182'],response=200
# title_counter=145,run_counter=815,proxy=['185.105.185.6'],response=200
# name 'np' is not defined
# title_counter=146,run_counter=817,proxy=['177.72.84.6'],response=200
# title_counter=146,run_counter=819,proxy=['94.228.253.51'],response=200
# title_counter=146,run_counter=821,proxy=['38.142.63.146'],response=200
# name 'np' is not defined
# title_counter=147,run_counter=823,proxy=['94.140.208.190'],response=200
# title_counter=147,run_counter=825,proxy=['197.157.219.169'],response=200
# title_counter=147,run_counter=827,proxy=['168.90.65.30'],response=200
# name 'np' is not defined
# title_counter=148,run_counter=829,proxy=['222.124.145.94'],response=200
# title_counter=148,run_counter=831,proxy=['104.248.156.229'],response=200
# title_counter=148,run_counter=833,proxy=['83.96.109.247'],response=200
# name 'np' is not defined
# title_counter=149,run_counter=835,proxy=['181.143.94.58'],response=200
# title_counter=149,run_counter=837,proxy=['176.112.108.58'],response=200
# title_counter=149,run_counter=839,proxy=['91.203.115.21'],response=200
# name 'np' is not defined
# title_counter=150,run_counter=841,proxy=['187.33.79.61'],response=200
# title_counter=150,run_counter=843,proxy=['185.76.71.247'],response=200
# title_counter=150,run_counter=845,proxy=['191.37.16.127'],response=200
# name 'np' is not defined
# title_counter=151,run_counter=847,proxy=['31.182.13.17'],response=200
# title_counter=151,run_counter=849,proxy=['217.64.25.34'],response=200
# title_counter=151,run_counter=851,proxy=['92.52.134.150'],response=200
# name 'np' is not defined
# title_counter=152,run_counter=853,proxy=['95.172.36.84'],response=200
# title_counter=152,run_counter=855,proxy=['173.217.255.36'],response=200
# title_counter=152,run_counter=857,proxy=['186.101.255.146'],response=200
# name 'np' is not defined
# title_counter=153,run_counter=859,proxy=['46.33.253.29'],response=200
# title_counter=153,run_counter=861,proxy=['84.47.135.132'],response=200
# title_counter=153,run_counter=863,proxy=['85.117.56.73'],response=200
# name 'np' is not defined
# title_counter=154,run_counter=865,proxy=['200.24.80.2'],response=200
# title_counter=154,run_counter=867,proxy=['89.205.5.98'],response=200
# title_counter=154,run_counter=869,proxy=['84.47.145.54'],response=200
# name 'np' is not defined
# title_counter=155,run_counter=871,proxy=['190.52.193.97'],response=200
# title_counter=155,run_counter=873,proxy=['103.12.48.238'],response=200
# title_counter=155,run_counter=875,proxy=['79.98.1.32'],response=200
# name 'np' is not defined
# title_counter=156,run_counter=877,proxy=['12.251.81.106'],response=200
# title_counter=156,run_counter=879,proxy=['185.214.187.38'],response=200
# title_counter=156,run_counter=881,proxy=['79.106.35.201'],response=200
# name 'np' is not defined
# title_counter=157,run_counter=883,proxy=['82.117.254.201'],response=200
# title_counter=157,run_counter=885,proxy=['195.29.92.22'],response=200
# title_counter=157,run_counter=887,proxy=['91.105.152.168'],response=200
# name 'np' is not defined
# title_counter=158,run_counter=889,proxy=['82.114.78.82'],response=200
# title_counter=158,run_counter=891,proxy=['195.22.253.234'],response=200
# title_counter=158,run_counter=893,proxy=['41.50.87.52'],response=200
# name 'np' is not defined
# title_counter=159,run_counter=895,proxy=['159.65.0.132'],response=200
# title_counter=159,run_counter=897,proxy=['85.236.8.74'],response=200
# title_counter=159,run_counter=899,proxy=['181.129.30.22'],response=200
# name 'np' is not defined
# title_counter=160,run_counter=901,proxy=['195.138.76.148'],response=200
# title_counter=160,run_counter=903,proxy=['213.97.242.43'],response=200
# title_counter=160,run_counter=905,proxy=['163.172.189.26'],response=200
# name 'np' is not defined
# title_counter=161,run_counter=907,proxy=['212.91.116.22'],response=200
# title_counter=161,run_counter=909,proxy=['170.80.91.6'],response=200
# title_counter=161,run_counter=911,proxy=['178.215.163.218'],response=200
# name 'np' is not defined
# title_counter=162,run_counter=913,proxy=['176.214.81.78'],response=200
# title_counter=162,run_counter=915,proxy=['46.10.241.140'],response=200
# title_counter=162,run_counter=917,proxy=['52.53.254.36'],response=200
# name 'np' is not defined
# title_counter=163,run_counter=919,proxy=['109.238.208.138'],response=200
# title_counter=163,run_counter=921,proxy=['159.224.169.115'],response=200
# title_counter=163,run_counter=923,proxy=['159.203.186.168'],response=200
# name 'np' is not defined
# title_counter=164,run_counter=925,proxy=['165.16.49.54'],response=200
# title_counter=164,run_counter=927,proxy=['37.26.86.206'],response=200
# title_counter=164,run_counter=929,proxy=['177.104.193.144'],response=200
# name 'np' is not defined
# title_counter=165,run_counter=931,proxy=['41.73.15.246'],response=200
# title_counter=165,run_counter=933,proxy=['167.250.160.150'],response=200
# title_counter=165,run_counter=935,proxy=['162.243.173.91'],response=200
# name 'np' is not defined
# title_counter=166,run_counter=937,proxy=['166.62.80.198'],response=200
# title_counter=166,run_counter=939,proxy=['188.241.45.61'],response=200
# title_counter=166,run_counter=941,proxy=['188.115.187.117'],response=200
# name 'np' is not defined
# title_counter=167,run_counter=943,proxy=['200.69.86.195'],response=200
# title_counter=167,run_counter=945,proxy=['185.15.90.82'],response=200
# title_counter=167,run_counter=947,proxy=['163.172.178.59'],response=200
# name 'np' is not defined
# title_counter=168,run_counter=949,proxy=['190.107.27.162'],response=200
# title_counter=168,run_counter=951,proxy=['165.22.14.234'],response=200
# title_counter=168,run_counter=953,proxy=['195.9.148.150'],response=200
# name 'np' is not defined
# title_counter=169,run_counter=955,proxy=['51.15.141.226'],response=200
# title_counter=169,run_counter=957,proxy=['181.225.65.106'],response=200
# title_counter=169,run_counter=959,proxy=['24.104.47.13'],response=200
# name 'np' is not defined
# title_counter=170,run_counter=961,proxy=['131.221.178.220'],response=200
# title_counter=170,run_counter=963,proxy=['109.74.130.129'],response=200
# title_counter=170,run_counter=965,proxy=['177.241.244.219'],response=200
# name 'np' is not defined
# title_counter=171,run_counter=967,proxy=['94.253.39.7'],response=200
# title_counter=171,run_counter=969,proxy=['131.0.234.82'],response=200
# title_counter=171,run_counter=971,proxy=['186.148.172.19'],response=200
# name 'np' is not defined
# title_counter=172,run_counter=973,proxy=['108.61.194.71'],response=200
# title_counter=172,run_counter=975,proxy=['142.93.181.2'],response=200
# title_counter=172,run_counter=977,proxy=['93.183.203.185'],response=200
# name 'np' is not defined
# title_counter=173,run_counter=979,proxy=['93.123.98.238'],response=200
# title_counter=173,run_counter=981,proxy=['176.112.108.58'],response=200
# title_counter=173,run_counter=983,proxy=['185.61.92.178'],response=200
# name 'np' is not defined
# title_counter=174,run_counter=985,proxy=['86.62.120.68'],response=200
# title_counter=174,run_counter=987,proxy=['212.90.59.242'],response=200
# title_counter=174,run_counter=989,proxy=['177.128.209.58'],response=200
# name 'np' is not defined
# title_counter=175,run_counter=991,proxy=['190.63.144.29'],response=200
# title_counter=175,run_counter=993,proxy=['84.1.150.59'],response=200
# title_counter=175,run_counter=995,proxy=['212.243.175.126'],response=200
# name 'np' is not defined
# title_counter=176,run_counter=997,proxy=['94.253.39.7'],response=200
# title_counter=176,run_counter=999,proxy=['46.160.84.179'],response=200
# title_counter=176,run_counter=1001,proxy=['185.175.94.44'],response=200
# name 'np' is not defined
# title_counter=177,run_counter=1003,proxy=['190.109.164.105'],response=200
# title_counter=177,run_counter=1005,proxy=['187.177.30.154'],response=200
# title_counter=177,run_counter=1007,proxy=['163.172.177.129'],response=200
# name 'np' is not defined
# title_counter=178,run_counter=1009,proxy=['186.219.210.70'],response=200
# title_counter=178,run_counter=1011,proxy=['202.179.7.182'],response=200
# title_counter=178,run_counter=1013,proxy=['114.108.181.130'],response=200
# name 'np' is not defined
# title_counter=179,run_counter=1015,proxy=['50.246.23.229'],response=200
# title_counter=179,run_counter=1017,proxy=['186.219.3.218'],response=200
# title_counter=179,run_counter=1019,proxy=['95.188.71.19'],response=200
# name 'np' is not defined
# title_counter=180,run_counter=1021,proxy=['128.199.201.67'],response=200
# title_counter=180,run_counter=1023,proxy=['195.9.25.42'],response=200
# title_counter=180,run_counter=1025,proxy=['185.248.128.6'],response=200
# name 'np' is not defined
# title_counter=181,run_counter=1027,proxy=['209.250.250.80'],response=200
# title_counter=181,run_counter=1029,proxy=['168.181.121.195'],response=200
# title_counter=181,run_counter=1031,proxy=['81.3.154.235'],response=200
# name 'np' is not defined
# title_counter=182,run_counter=1033,proxy=['67.205.191.90'],response=200
# title_counter=182,run_counter=1035,proxy=['159.203.87.130'],response=200
# title_counter=182,run_counter=1037,proxy=['185.69.200.2'],response=200
# name 'np' is not defined
# title_counter=183,run_counter=1039,proxy=['91.213.119.246'],response=200
# title_counter=183,run_counter=1041,proxy=['168.194.102.2'],response=200
# title_counter=183,run_counter=1043,proxy=['185.47.161.124'],response=200
# name 'np' is not defined
# title_counter=184,run_counter=1045,proxy=['149.202.41.191'],response=200
# title_counter=184,run_counter=1047,proxy=['212.96.201.184'],response=200
# title_counter=184,run_counter=1049,proxy=['190.155.135.138'],response=200
# name 'np' is not defined
# title_counter=185,run_counter=1051,proxy=['106.105.212.69'],response=200
# title_counter=185,run_counter=1053,proxy=['200.35.75.34'],response=200
# title_counter=185,run_counter=1055,proxy=['51.15.141.226'],response=200
# name 'np' is not defined
# title_counter=186,run_counter=1057,proxy=['180.183.127.49'],response=200
# title_counter=186,run_counter=1059,proxy=['112.161.211.65'],response=200
# title_counter=186,run_counter=1061,proxy=['189.28.167.19'],response=200
# name 'np' is not defined
# title_counter=187,run_counter=1063,proxy=['72.11.148.222'],response=200
# title_counter=187,run_counter=1065,proxy=['165.22.7.138'],response=200
# title_counter=187,run_counter=1067,proxy=['46.22.49.41'],response=200
# name 'np' is not defined
# title_counter=188,run_counter=1069,proxy=['176.112.108.58'],response=200
# title_counter=188,run_counter=1071,proxy=['212.91.121.114'],response=200
# title_counter=188,run_counter=1073,proxy=['88.99.246.248'],response=200
# name 'np' is not defined
# title_counter=189,run_counter=1075,proxy=['193.105.62.11'],response=200
# title_counter=189,run_counter=1077,proxy=['91.225.165.4'],response=200
# title_counter=189,run_counter=1079,proxy=['187.177.139.7'],response=200
# name 'np' is not defined
# title_counter=190,run_counter=1081,proxy=['195.81.112.162'],response=200
# title_counter=190,run_counter=1083,proxy=['179.108.196.48'],response=200
# title_counter=190,run_counter=1085,proxy=['212.42.113.49'],response=200
# name 'np' is not defined
# title_counter=191,run_counter=1087,proxy=['51.38.66.6'],response=200
# title_counter=191,run_counter=1089,proxy=['186.248.163.130'],response=200
# title_counter=191,run_counter=1091,proxy=['177.10.140.105'],response=200
# name 'np' is not defined
# title_counter=192,run_counter=1093,proxy=['167.99.66.94'],response=200
# title_counter=192,run_counter=1095,proxy=['217.153.241.204'],response=200
# title_counter=192,run_counter=1097,proxy=['103.25.168.22'],response=200
# name 'np' is not defined
# title_counter=193,run_counter=1099,proxy=['193.105.62.11'],response=200
# title_counter=193,run_counter=1101,proxy=['79.145.147.96'],response=200
# title_counter=193,run_counter=1103,proxy=['164.52.42.6'],response=200
# name 'np' is not defined
# title_counter=194,run_counter=1105,proxy=['177.38.33.42'],response=200
# title_counter=194,run_counter=1107,proxy=['189.51.127.1'],response=200
# title_counter=194,run_counter=1109,proxy=['176.10.43.195'],response=200
# name 'np' is not defined
# title_counter=195,run_counter=1111,proxy=['93.123.98.238'],response=200
# title_counter=195,run_counter=1113,proxy=['78.139.50.233'],response=200
# title_counter=195,run_counter=1115,proxy=['134.19.218.94'],response=200
# name 'np' is not defined
# title_counter=196,run_counter=1117,proxy=['181.211.244.66'],response=200
# title_counter=196,run_counter=1119,proxy=['170.84.50.193'],response=200
# title_counter=196,run_counter=1121,proxy=['89.216.49.25'],response=200
# name 'np' is not defined
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# title_counter=197,run_counter=1124,proxy=['93.175.203.124'],response=200
# title_counter=197,run_counter=1126,proxy=['168.194.102.2'],response=200
# name 'np' is not defined
# title_counter=198,run_counter=1128,proxy=['186.96.127.220'],response=200
# title_counter=198,run_counter=1130,proxy=['157.230.173.224'],response=200
# title_counter=198,run_counter=1132,proxy=['159.255.167.89'],response=200
# name 'np' is not defined
# title_counter=199,run_counter=1134,proxy=['31.135.125.253'],response=200
# title_counter=199,run_counter=1136,proxy=['170.249.176.38'],response=200
# title_counter=199,run_counter=1138,proxy=['163.172.187.113'],response=200
# name 'np' is not defined
# title_counter=200,run_counter=1140,proxy=['190.214.19.29'],response=200
# title_counter=200,run_counter=1142,proxy=['82.146.236.38'],response=200
# title_counter=200,run_counter=1144,proxy=['77.85.168.253'],response=200
# name 'np' is not defined
# title_counter=201,run_counter=1146,proxy=['164.163.21.10'],response=200
# title_counter=201,run_counter=1148,proxy=['195.158.109.248'],response=200
# ...
# name 'np' is not defined
# title_counter=207,run_counter=1182,proxy=['76.76.76.154'],response=200
# title_counter=207,run_counter=1184,proxy=['109.75.46.23'],response=200
# title_counter=207,run_counter=1186,proxy=['188.165.138.11'],response=200
# name 'np' is not defined
# title_counter=208,run_counter=1188,proxy=['188.241.45.85'],response=200
# title_counter=208,run_counter=1190,proxy=['77.37.240.23'],response=200
# title_counter=208,run_counter=1192,proxy=['177.38.33.42'],response=200
# name 'np' is not defined
# title_counter=209,run_counter=1194,proxy=['37.57.40.167'],response=200
# title_counter=209,run_counter=1196,proxy=['177.231.249.218'],response=200
# title_counter=209,run_counter=1198,proxy=['181.129.55.44'],response=200
# name 'np' is not defined
# title_counter=210,run_counter=1200,proxy=['178.218.58.234'],response=200
# title_counter=210,run_counter=1202,proxy=['163.172.209.92'],response=200
# title_counter=210,run_counter=1204,proxy=['186.224.138.82'],response=200
# name 'np' is not defined
# title_counter=211,run_counter=1206,proxy=['45.4.57.207'],response=200
# title_counter=211,run_counter=1208,proxy=['89.23.0.2'],response=200
# title_counter=211,run_counter=1210,proxy=['181.112.159.58'],response=200
# name 'np' is not defined
# title_counter=212,run_counter=1212,proxy=['187.130.139.197'],response=200
# title_counter=212,run_counter=1214,proxy=['168.227.158.49'],response=200
# title_counter=212,run_counter=1216,proxy=['187.177.139.7'],response=200
# name 'np' is not defined
# title_counter=213,run_counter=1218,proxy=['194.0.140.138'],response=200
# title_counter=213,run_counter=1220,proxy=['138.94.48.62'],response=200
# title_counter=213,run_counter=1222,proxy=['170.80.91.8'],response=200
# name 'np' is not defined
# title_counter=214,run_counter=1224,proxy=['78.81.11.216'],response=200
# title_counter=214,run_counter=1226,proxy=['72.11.148.222'],response=200
# title_counter=214,run_counter=1228,proxy=['185.61.92.178'],response=200
# name 'np' is not defined
# title_counter=215,run_counter=1230,proxy=['165.227.71.172'],response=200
# title_counter=215,run_counter=1232,proxy=['51.38.71.101'],response=200
# title_counter=215,run_counter=1234,proxy=['176.62.185.72'],response=200
# name 'np' is not defined
# title_counter=216,run_counter=1236,proxy=['151.80.58.175'],response=200
# title_counter=216,run_counter=1238,proxy=['159.65.1.26'],response=200
# title_counter=216,run_counter=1240,proxy=['200.69.65.186'],response=200
# name 'np' is not defined
# title_counter=217,run_counter=1242,proxy=['194.167.44.91'],response=200
# title_counter=217,run_counter=1244,proxy=['170.84.156.180'],response=200
# title_counter=217,run_counter=1246,proxy=['190.14.229.196'],response=200
# name 'np' is not defined
# title_counter=218,run_counter=1248,proxy=['177.8.242.79'],response=200
# title_counter=218,run_counter=1250,proxy=['212.58.208.235'],response=200
# title_counter=218,run_counter=1252,proxy=['185.116.254.18'],response=200
# name 'np' is not defined
# title_counter=219,run_counter=1254,proxy=['31.40.179.109'],response=200
# title_counter=219,run_counter=1256,proxy=['67.78.120.18'],response=200
# title_counter=219,run_counter=1258,proxy=['90.188.16.246'],response=200
# name 'np' is not defined
# title_counter=220,run_counter=1260,proxy=['24.198.153.105'],response=200
# title_counter=220,run_counter=1262,proxy=['195.201.183.156'],response=200
# title_counter=220,run_counter=1264,proxy=['187.19.114.2'],response=200
# name 'np' is not defined
# title_counter=221,run_counter=1266,proxy=['96.3.212.158'],response=200
# title_counter=221,run_counter=1268,proxy=['217.77.171.114'],response=200
# title_counter=221,run_counter=1270,proxy=['85.172.126.218'],response=200
# name 'np' is not defined
# title_counter=222,run_counter=1272,proxy=['45.77.57.244'],response=200
# title_counter=222,run_counter=1274,proxy=['178.151.177.243'],response=200
# title_counter=222,run_counter=1276,proxy=['165.22.114.4'],response=200
# name 'np' is not defined
# title_counter=223,run_counter=1278,proxy=['64.207.93.1'],response=200
# title_counter=223,run_counter=1280,proxy=['177.184.202.218'],response=200
# title_counter=223,run_counter=1282,proxy=['67.205.191.251'],response=200
# name 'np' is not defined
# title_counter=224,run_counter=1284,proxy=['168.121.97.67'],response=200
# title_counter=224,run_counter=1286,proxy=['178.254.216.101'],response=200
# title_counter=224,run_counter=1288,proxy=['186.72.74.70'],response=200
# name 'np' is not defined
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@id="gsc_prf_in"]"}
#   (Session info: chrome=75.0.3770.90)
#
# title_counter=225,run_counter=1292,proxy=['192.169.193.54'],response=200
# name 'np' is not defined
# title_counter=226,run_counter=1294,proxy=['195.210.172.42'],response=200
# title_counter=226,run_counter=1296,proxy=['194.44.20.22'],response=200
# title_counter=226,run_counter=1298,proxy=['51.15.139.253'],response=200
# name 'np' is not defined
# title_counter=227,run_counter=1300,proxy=['177.184.202.218'],response=200
# title_counter=227,run_counter=1302,proxy=['147.91.111.133'],response=200
# title_counter=227,run_counter=1304,proxy=['91.200.126.174'],response=200
# name 'np' is not defined
# title_counter=228,run_counter=1306,proxy=['185.162.141.236'],response=200
# title_counter=228,run_counter=1308,proxy=['77.120.137.9'],response=200
# title_counter=228,run_counter=1310,proxy=['190.11.31.118'],response=200
# name 'np' is not defined
# title_counter=229,run_counter=1312,proxy=['200.85.169.18'],response=200
# title_counter=229,run_counter=1314,proxy=['35.198.35.92'],response=200
# title_counter=229,run_counter=1316,proxy=['181.113.25.146'],response=200
# name 'np' is not defined
# title_counter=230,run_counter=1318,proxy=['185.122.54.20'],response=200
# title_counter=230,run_counter=1320,proxy=['168.195.171.114'],response=200
# title_counter=230,run_counter=1322,proxy=['177.107.37.136'],response=200
# name 'np' is not defined
# title_counter=231,run_counter=1324,proxy=['209.97.173.141'],response=200
# title_counter=231,run_counter=1326,proxy=['50.205.151.218'],response=200
# title_counter=231,run_counter=1328,proxy=['46.201.219.126'],response=200
# name 'np' is not defined
# title_counter=232,run_counter=1330,proxy=['3.112.189.121'],response=200
# title_counter=232,run_counter=1332,proxy=['138.94.11.245'],response=200
# title_counter=232,run_counter=1334,proxy=['177.12.113.103'],response=200
# name 'np' is not defined
# title_counter=233,run_counter=1336,proxy=['46.105.87.103'],response=200
# title_counter=233,run_counter=1338,proxy=['185.94.218.57'],response=200
# title_counter=233,run_counter=1340,proxy=['128.199.61.141'],response=200
# name 'np' is not defined
# title_counter=234,run_counter=1342,proxy=['188.237.135.3'],response=200
# title_counter=234,run_counter=1344,proxy=['170.84.93.73'],response=200
# title_counter=234,run_counter=1346,proxy=['24.231.109.39'],response=200
# name 'np' is not defined
# title_counter=235,run_counter=1348,proxy=['181.211.6.34'],response=200
# title_counter=235,run_counter=1350,proxy=['5.178.217.227'],response=200
# title_counter=235,run_counter=1352,proxy=['92.248.163.16'],response=200
# name 'np' is not defined
# title_counter=236,run_counter=1354,proxy=['220.135.2.247'],response=200
# title_counter=236,run_counter=1356,proxy=['186.251.247.58'],response=200
# title_counter=236,run_counter=1358,proxy=['144.48.176.38'],response=200
# name 'np' is not defined
# title_counter=237,run_counter=1360,proxy=['78.139.200.51'],response=200
# title_counter=237,run_counter=1362,proxy=['187.73.48.182'],response=200
# title_counter=237,run_counter=1364,proxy=['50.7.106.240'],response=200
# name 'np' is not defined
# title_counter=238,run_counter=1366,proxy=['187.216.83.184'],response=200
# title_counter=238,run_counter=1368,proxy=['86.101.129.2'],response=200
# title_counter=238,run_counter=1370,proxy=['205.240.205.100'],response=200
# name 'np' is not defined
# title_counter=239,run_counter=1372,proxy=['88.84.222.208'],response=200
# title_counter=239,run_counter=1374,proxy=['80.32.122.118'],response=200
# title_counter=239,run_counter=1376,proxy=['213.81.144.253'],response=200
# name 'np' is not defined
# title_counter=240,run_counter=1378,proxy=['140.227.235.194'],response=200
# title_counter=240,run_counter=1380,proxy=['177.73.188.95'],response=200
# title_counter=240,run_counter=1382,proxy=['88.147.142.103'],response=200
# name 'np' is not defined
# title_counter=241,run_counter=1384,proxy=['47.244.136.33'],response=200
# title_counter=241,run_counter=1386,proxy=['109.194.162.249'],response=200
# title_counter=241,run_counter=1388,proxy=['157.230.164.220'],response=200
# name 'np' is not defined
# title_counter=242,run_counter=1390,proxy=['62.14.178.3'],response=200
# title_counter=242,run_counter=1392,proxy=['177.69.37.22'],response=200
# title_counter=242,run_counter=1394,proxy=['114.32.10.182'],response=200
# name 'np' is not defined
# title_counter=243,run_counter=1396,proxy=['45.65.227.17'],response=200
# title_counter=243,run_counter=1398,proxy=['61.28.228.38'],response=200
# title_counter=243,run_counter=1400,proxy=['72.252.161.224'],response=200
# name 'np' is not defined
# title_counter=244,run_counter=1402,proxy=['1.163.7.178'],response=200
# title_counter=244,run_counter=1404,proxy=['217.153.241.204'],response=200
# title_counter=244,run_counter=1406,proxy=['181.119.69.36'],response=200
# name 'np' is not defined
# title_counter=245,run_counter=1408,proxy=['181.112.159.58'],response=200
# title_counter=245,run_counter=1410,proxy=['181.211.252.74'],response=200
# title_counter=245,run_counter=1412,proxy=['108.160.129.94'],response=200
# name 'np' is not defined
# title_counter=246,run_counter=1414,proxy=['191.100.129.36'],response=200
# title_counter=246,run_counter=1416,proxy=['145.255.28.122'],response=200
# title_counter=246,run_counter=1418,proxy=['201.202.246.162'],response=200
# name 'np' is not defined
# title_counter=247,run_counter=1420,proxy=['200.6.169.250'],response=200
# title_counter=247,run_counter=1422,proxy=['85.28.142.142'],response=200
# title_counter=247,run_counter=1424,proxy=['12.132.115.40'],response=200
# name 'np' is not defined
# title_counter=248,run_counter=1426,proxy=['50.63.3.131'],response=200
# title_counter=248,run_counter=1428,proxy=['50.255.192.73'],response=200
# title_counter=248,run_counter=1430,proxy=['190.13.146.85'],response=200
# name 'np' is not defined
# title_counter=249,run_counter=1432,proxy=['213.222.47.202'],response=200
# title_counter=249,run_counter=1434,proxy=['199.247.16.220'],response=200
# title_counter=249,run_counter=1436,proxy=['212.200.101.22'],response=200
# name 'np' is not defined
# title_counter=250,run_counter=1438,proxy=['132.148.130.46'],response=200
# title_counter=250,run_counter=1440,proxy=['163.172.174.122'],response=200
# title_counter=250,run_counter=1442,proxy=['3.91.241.220'],response=200
# name 'np' is not defined
# title_counter=251,run_counter=1444,proxy=['200.110.176.121'],response=200
# title_counter=251,run_counter=1446,proxy=['181.113.229.122'],response=200
# title_counter=251,run_counter=1448,proxy=['186.232.168.5'],response=200
# name 'np' is not defined
# title_counter=252,run_counter=1450,proxy=['179.184.161.209'],response=200
# title_counter=252,run_counter=1452,proxy=['91.214.179.43'],response=200
# title_counter=252,run_counter=1454,proxy=['191.102.82.91'],response=200
# name 'np' is not defined
# title_counter=253,run_counter=1456,proxy=['95.216.224.183'],response=200
# title_counter=253,run_counter=1458,proxy=['91.200.126.174'],response=200
# title_counter=253,run_counter=1460,proxy=['78.139.50.233'],response=200
# name 'np' is not defined
# title_counter=254,run_counter=1462,proxy=['94.138.96.150'],response=200
# title_counter=254,run_counter=1464,proxy=['122.116.113.203'],response=200
# title_counter=254,run_counter=1466,proxy=['176.112.108.58'],response=200
# name 'np' is not defined
# title_counter=255,run_counter=1468,proxy=['177.190.145.203'],response=200
# title_counter=255,run_counter=1470,proxy=['54.183.68.84'],response=200
# title_counter=255,run_counter=1472,proxy=['186.219.3.228'],response=200
# name 'np' is not defined
# title_counter=256,run_counter=1474,proxy=['181.129.30.22'],response=200
# title_counter=256,run_counter=1476,proxy=['190.152.180.58'],response=200
# title_counter=256,run_counter=1478,proxy=['109.238.208.138'],response=200
# name 'np' is not defined
# title_counter=257,run_counter=1480,proxy=['177.84.109.10'],response=200
# title_counter=257,run_counter=1482,proxy=['79.106.35.59'],response=200
# title_counter=257,run_counter=1484,proxy=['138.68.17.62'],response=200
# name 'np' is not defined
# title_counter=258,run_counter=1486,proxy=['165.227.160.139'],response=200
# title_counter=258,run_counter=1488,proxy=['179.184.161.209'],response=200
# title_counter=258,run_counter=1490,proxy=['79.157.117.101'],response=200
# name 'np' is not defined
# title_counter=259,run_counter=1492,proxy=['95.169.92.3'],response=200
# title_counter=259,run_counter=1494,proxy=['208.67.29.49'],response=200
# title_counter=259,run_counter=1496,proxy=['91.205.131.55'],response=200
# name 'np' is not defined
# title_counter=260,run_counter=1498,proxy=['79.104.28.46'],response=200
# title_counter=260,run_counter=1500,proxy=['159.65.1.26'],response=200
# title_counter=260,run_counter=1502,proxy=['181.211.252.74'],response=200
# name 'np' is not defined
# title_counter=261,run_counter=1504,proxy=['176.235.99.15'],response=200
# title_counter=261,run_counter=1506,proxy=['185.132.228.217'],response=200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-9b0a8d2ba433> in <module>()
# ----> 1 title_citations, authors = seleniumwrapper.selenium_parse(title_lst[:6000])
#
# ~\Documents\Python Scripts\articles\selenium_wrapper.py in selenium_parse(self, title_lst)
#      89                                 # configure a driver by randomly selecting an ip_address from a list of proxies
#      90                                 ip_address = random.sample(self.__proxies_lst,1)
# ---> 91                                 driver = self.configure_driver(ip_address)
#      92                                 # for each url parse the author's page
#      93                                 try:
#
# ~\Documents\Python Scripts\articles\selenium_wrapper.py in configure_driver(self, ip_address)
#      20                 options.Proxy = proxy
#      21                 options.add_argument("ignore-certificate-errors")
# ---> 22                 driver = webdriver.Chrome(self.__filepath_chrome,chrome_options=options)
#      23                 return(driver)
#      24
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\chrome\webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options)
#      66             service_args=service_args,
#      67             log_path=service_log_path)
# ---> 68         self.service.start()
#      69
#      70         try:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      97         while True:
#      98             self.assert_process_still_running()
# ---> 99             if self.is_connectable():
#     100                 break
#     101             count += 1
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\service.py in is_connectable(self)
#     113
#     114     def is_connectable(self):
# --> 115         return utils.is_connectable(self.port)
#     116
#     117     def send_remote_shutdown_command(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\common\utils.py in is_connectable(port, host)
#     104     socket_ = None
#     105     try:
# --> 106         socket_ = socket.create_connection((host, port), 1)
#     107         result = True
#     108     except socket.error:
#
# ~\Anaconda3\lib\socket.py in create_connection(address, timeout, source_address)
#     711             if source_address:
#     712                 sock.bind(source_address)
# --> 713             sock.connect(sa)
#     714             # Break explicitly a reference cycle
#     715             err = None
#
# KeyboardInterrupt:
